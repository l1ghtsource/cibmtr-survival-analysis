# %%
# !pip install -q /kaggle/input/pytabkit/*.whl --no-deps

# %%
# !pip install -q /kaggle/input/pip-install-lifelines/autograd-1.7.0-py3-none-any.whl
# !pip install -q /kaggle/input/pip-install-lifelines/autograd-gamma-0.5.0.tar.gz
# !pip install -q /kaggle/input/pip-install-lifelines/interface_meta-1.3.0-py3-none-any.whl
# !pip install -q /kaggle/input/pip-install-lifelines/formulaic-1.0.2-py3-none-any.whl
# !pip install -q /kaggle/input/pip-install-lifelines/lifelines-0.30.0-py3-none-any.whl
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for autograd-gamma (setup.py) ... done

# %%
#!pip install -q /kaggle/input/faiss-cpu-173/faiss_cpu-1.7.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl

# %%
# !pip install /kaggle/input/faiss-gpu-173-python310/faiss_gpu-1.7.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Out:
# Processing /kaggle/input/faiss-gpu-173-python310/faiss_gpu-1.7.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Installing collected packages: faiss-gpu
# Successfully installed faiss-gpu-1.7.2

# %%
import pandas as pd
import pandas.api.types
import numpy as np
from lifelines.utils import concordance_index


class ParticipantVisibleError(Exception):
    pass


def score(solution: pd.DataFrame, submission: pd.DataFrame, row_id_column_name: str) -> float:
    del solution[row_id_column_name]
    del submission[row_id_column_name]
    
    event_label = 'efs'
    interval_label = 'efs_time'
    prediction_label = 'prediction'
    
    for col in submission.columns:
        if not pandas.api.types.is_numeric_dtype(submission[col]):
            raise ParticipantVisibleError(f'Submission column {col} must be a number')
            
    merged_df = pd.concat([solution, submission], axis=1)
    merged_df.reset_index(inplace=True)
    merged_df_race_dict = dict(merged_df.groupby(['race_group']).groups)
    
    metric_list = []
    for race in merged_df_race_dict.keys():
        indices = sorted(merged_df_race_dict[race])
        merged_df_race = merged_df.iloc[indices]
        c_index_race = concordance_index(
            merged_df_race[interval_label],
            -merged_df_race[prediction_label],
            merged_df_race[event_label]
        )
        metric_list.append(c_index_race)
        
    return float(np.mean(metric_list) - np.sqrt(np.var(metric_list)))

# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_csv('/kaggle/input/equity-post-HCT-survival-predictions/train.csv')
test = pd.read_csv('/kaggle/input/equity-post-HCT-survival-predictions/test.csv')

# %%
from lifelines import KaplanMeierFitter
from sklearn.model_selection import KFold

def create_fold_specific_target(data, time_col='efs_time', event_col='efs'):
    cv = KFold(n_splits=10, shuffle=True, random_state=52)
    target = np.zeros(len(data))

    for train_index, valid_index in cv.split(data):
        train_data = data.iloc[train_index]
        valid_data = data.iloc[valid_index]

        kmf = KaplanMeierFitter()
        kmf.fit(durations=train_data[time_col], event_observed=train_data[event_col])
        target[valid_index] = kmf.survival_function_at_times(valid_data[time_col]).values
        
    data['y'] = target
    
    return data

# %%
train = create_fold_specific_target(train, time_col='efs_time', event_col='efs')

# %%
combined = pd.concat([train, test], axis=0)

RMV = ["ID", "efs", "efs_time", "y"]
FEATURES = [c for c in train.columns if not c in RMV]

# %%
CATS = []
for c in FEATURES:
    if combined[c].dtype == 'object':
        CATS.append(c)
        train[c] = train[c].fillna('nan')
        test[c] = test[c].fillna('nan')

NUMS = [c for c in FEATURES if not c in CATS]

# %%
for c in NUMS:
    combined[c] = combined[c].fillna(combined[c].mean())

train = combined.iloc[:len(train)].copy()
test = combined.iloc[len(train):].reset_index(drop=True).copy()

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
train[NUMS] = scaler.fit_transform(train[NUMS])
test[NUMS] = scaler.transform(test[NUMS])

# %%
from pytabkit.models.sklearn.sklearn_interfaces import (
    RealMLP_TD_Regressor,
    MLP_RTDL_D_Regressor,
    Resnet_RTDL_D_Regressor,
    FTT_D_Regressor,
    MLP_PLR_D_Regressor,
    # TabR_S_D_Regressor,
    # RealTabR_D_Regressor,
    TabM_D_Regressor
)

# %%
import os
import joblib

# %%
# %%time
FOLDS = 10
kf = KFold(n_splits=FOLDS, shuffle=True, random_state=52)
    
oof_realmlp = np.zeros(len(train))
pred_realmlp = np.zeros(len(test))

for i, (train_index, test_index) in enumerate(kf.split(train)):
    print("#" * 25)
    print(f"### Fold {i + 1}")
    print("#" * 25)
    
    X_train = train.loc[train_index, FEATURES].copy()
    y_train = train.loc[train_index, "y"]
    X_valid = train.loc[test_index, FEATURES].copy()
    y_valid = train.loc[test_index, "y"]
    X_test = test[FEATURES].copy()

    model_realmlp = RealMLP_TD_Regressor(
        n_cv=5,
        use_early_stopping=True,
        early_stopping_additive_patience=20,
        random_state=52, 
        verbosity=2
    )
    model_realmlp.fit(
        X_train, y_train,
        X_valid, y_valid
    )
    os.makedirs('/kaggle/working/realmlp', exist_ok=True)
    joblib.dump(model_realmlp, f'/kaggle/working/realmlp/realmlp_fold_{i}.pkl')

    oof_realmlp[test_index] = model_realmlp.predict(X_valid)
    pred_realmlp += model_realmlp.predict(X_test)

pred_realmlp /= FOLDS
# Out:
# #########################
# ### Fold 1
# #########################
# Columns classified as continuous: ['hla_match_c_high', 'hla_high_res_8', 'hla_low_res_6', 'hla_high_res_6', 'hla_high_res_10', 'hla_match_dqb1_high', 'hla_nmdp_6', 'hla_match_c_low', 'hla_match_drb1_low', 'hla_match_dqb1_low', 'year_hct', 'hla_match_a_high', 'donor_age', 'hla_match_b_low', 'age_at_hct', 'hla_match_a_low', 'hla_match_b_high', 'comorbidity_score', 'karnofsky_score', 'hla_low_res_8', 'hla_match_drb1_high', 'hla_low_res_10']
# Columns classified as categorical: ['dri_score', 'psych_disturb', 'cyto_score', 'diabetes', 'tbi_status', 'arrhythmia', 'graft_type', 'vent_hist', 'renal_issue', 'pulm_severe', 'prim_disease_hct', 'cmv_status', 'tce_imm_match', 'rituximab', 'prod_type', 'cyto_score_detail', 'conditioning_intensity', 'ethnicity', 'obesity', 'mrd_hct', 'in_vivo_tcd', 'tce_match', 'hepatic_severe', 'prior_tumor', 'peptic_ulcer', 'gvhd_proph', 'rheum_issue', 'sex_match', 'race_group', 'hepatic_mild', 'tce_div_match', 'donor_related', 'melphalan_dose', 'cardiac', 'pulm_moderate']
# Epoch 1/256: val rmse = 0.166015
# Epoch 2/256: val rmse = 0.167044
# Epoch 3/256: val rmse = 0.163110
# Epoch 4/256: val rmse = 0.163124
# Epoch 5/256: val rmse = 0.163550
# Epoch 6/256: val rmse = 0.165538
# Epoch 7/256: val rmse = 0.165297
# Epoch 8/256: val rmse = 0.164386
# Epoch 9/256: val rmse = 0.164403
# Epoch 10/256: val rmse = 0.162105
# Epoch 11/256: val rmse = 0.162547
# Epoch 12/256: val rmse = 0.160240
# Epoch 13/256: val rmse = 0.159684
# Epoch 14/256: val rmse = 0.159755
# Epoch 15/256: val rmse = 0.159282
# Epoch 16/256: val rmse = 0.159198
# Epoch 17/256: val rmse = 0.159820
# Epoch 18/256: val rmse = 0.160280
# Epoch 19/256: val rmse = 0.160756
# Epoch 20/256: val rmse = 0.161523
# Epoch 21/256: val rmse = 0.161869
# Epoch 22/256: val rmse = 0.161041
# Epoch 23/256: val rmse = 0.162258
# Epoch 24/256: val rmse = 0.162367
# Epoch 25/256: val rmse = 0.161387
# Epoch 26/256: val rmse = 0.162196
# Epoch 27/256: val rmse = 0.163287
# Epoch 28/256: val rmse = 0.163765
# Epoch 29/256: val rmse = 0.162821
# Epoch 30/256: val rmse = 0.163353
# Epoch 31/256: val rmse = 0.162326
# Epoch 32/256: val rmse = 0.165698
# Epoch 33/256: val rmse = 0.162840
# Epoch 34/256: val rmse = 0.162245
# Epoch 35/256: val rmse = 0.162852
# Epoch 36/256: val rmse = 0.162784
# Epoch 37/256: val rmse = 0.162905
# Epoch 38/256: val rmse = 0.163112
# Epoch 39/256: val rmse = 0.161245
# Epoch 40/256: val rmse = 0.162004
# Epoch 41/256: val rmse = 0.161704
# Epoch 42/256: val rmse = 0.160920
# Epoch 43/256: val rmse = 0.160534
# Epoch 44/256: val rmse = 0.160987
# Epoch 45/256: val rmse = 0.161016
# Epoch 46/256: val rmse = 0.162246
# Epoch 47/256: val rmse = 0.164908
# Epoch 48/256: val rmse = 0.165518
# Epoch 49/256: val rmse = 0.167253
# Epoch 50/256: val rmse = 0.167343
# Epoch 51/256: val rmse = 0.168156
# Epoch 52/256: val rmse = 0.168291
# Epoch 53/256: val rmse = 0.168319
# Epoch 54/256: val rmse = 0.169576
# Epoch 55/256: val rmse = 0.168410
# Epoch 56/256: val rmse = 0.169925
# Epoch 57/256: val rmse = 0.169843
# Epoch 58/256: val rmse = 0.169224
# Epoch 59/256: val rmse = 0.168646
# Epoch 60/256: val rmse = 0.168923
# Epoch 61/256: val rmse = 0.167949
# Epoch 62/256: val rmse = 0.165736
# Epoch 63/256: val rmse = 0.163553
# Epoch 64/256: val rmse = 0.162528
# Epoch 65/256: val rmse = 0.162017
# Epoch 66/256: val rmse = 0.162030
# Epoch 67/256: val rmse = 0.162295
# Epoch 68/256: val rmse = 0.161358
# Epoch 69/256: val rmse = 0.162080
# Epoch 70/256: val rmse = 0.162296
# Epoch 71/256: val rmse = 0.161894
# Epoch 72/256: val rmse = 0.163214
# Epoch 73/256: val rmse = 0.162942
# Epoch 74/256: val rmse = 0.163201
# Epoch 75/256: val rmse = 0.162494
# Epoch 76/256: val rmse = 0.163748
# Epoch 77/256: val rmse = 0.163180
# Epoch 78/256: val rmse = 0.161554
# Epoch 79/256: val rmse = 0.161940
# Epoch 80/256: val rmse = 0.163566
# Epoch 81/256: val rmse = 0.163531
# Epoch 82/256: val rmse = 0.163032
# Epoch 83/256: val rmse = 0.161763
# Epoch 84/256: val rmse = 0.162124
# Epoch 85/256: val rmse = 0.161715
# Epoch 86/256: val rmse = 0.162107
# Epoch 87/256: val rmse = 0.162826
# Epoch 88/256: val rmse = 0.161275
# Epoch 89/256: val rmse = 0.161932
# Epoch 90/256: val rmse = 0.161837
# Epoch 91/256: val rmse = 0.161661
# Epoch 92/256: val rmse = 0.161346
# Epoch 93/256: val rmse = 0.160988
# Epoch 94/256: val rmse = 0.160695
# Epoch 95/256: val rmse = 0.160533
# Epoch 96/256: val rmse = 0.162160
# Epoch 97/256: val rmse = 0.160877
# Epoch 98/256: val rmse = 0.160657
# Epoch 99/256: val rmse = 0.160082
# Epoch 100/256: val rmse = 0.159782
# Epoch 101/256: val rmse = 0.160647
# Epoch 102/256: val rmse = 0.160613
# Epoch 103/256: val rmse = 0.161368
# Epoch 104/256: val rmse = 0.162301
# Epoch 105/256: val rmse = 0.164742
# Epoch 106/256: val rmse = 0.164485
# Epoch 107/256: val rmse = 0.168922
# #########################
# ### Fold 2
# #########################
# Columns classified as continuous: ['hla_match_c_high', 'hla_high_res_8', 'hla_low_res_6', 'hla_high_res_6', 'hla_high_res_10', 'hla_match_dqb1_high', 'hla_nmdp_6', 'hla_match_c_low', 'hla_match_drb1_low', 'hla_match_dqb1_low', 'year_hct', 'hla_match_a_high', 'donor_age', 'hla_match_b_low', 'age_at_hct', 'hla_match_a_low', 'hla_match_b_high', 'comorbidity_score', 'karnofsky_score', 'hla_low_res_8', 'hla_match_drb1_high', 'hla_low_res_10']
# Columns classified as categorical: ['dri_score', 'psych_disturb', 'cyto_score', 'diabetes', 'tbi_status', 'arrhythmia', 'graft_type', 'vent_hist', 'renal_issue', 'pulm_severe', 'prim_disease_hct', 'cmv_status', 'tce_imm_match', 'rituximab', 'prod_type', 'cyto_score_detail', 'conditioning_intensity', 'ethnicity', 'obesity', 'mrd_hct', 'in_vivo_tcd', 'tce_match', 'hepatic_severe', 'prior_tumor', 'peptic_ulcer', 'gvhd_proph', 'rheum_issue', 'sex_match', 'race_group', 'hepatic_mild', 'tce_div_match', 'donor_related', 'melphalan_dose', 'cardiac', 'pulm_moderate']
# Epoch 1/256: val rmse = 0.166514
# Epoch 2/256: val rmse = 0.163813
# Epoch 3/256: val rmse = 0.160770
# Epoch 4/256: val rmse = 0.161667
# Epoch 5/256: val rmse = 0.161185
# Epoch 6/256: val rmse = 0.161982
# Epoch 7/256: val rmse = 0.163039
# Epoch 8/256: val rmse = 0.161599
# Epoch 9/256: val rmse = 0.163336
# Epoch 10/256: val rmse = 0.160349
# Epoch 11/256: val rmse = 0.159366
# Epoch 12/256: val rmse = 0.159560
# Epoch 13/256: val rmse = 0.157836
# Epoch 14/256: val rmse = 0.156979
# Epoch 15/256: val rmse = 0.156455
# Epoch 16/256: val rmse = 0.156741
# Epoch 17/256: val rmse = 0.157278
# Epoch 18/256: val rmse = 0.157527
# Epoch 19/256: val rmse = 0.158703
# Epoch 20/256: val rmse = 0.159333
# Epoch 21/256: val rmse = 0.160557
# Epoch 22/256: val rmse = 0.159714
# Epoch 23/256: val rmse = 0.159044
# Epoch 24/256: val rmse = 0.159876
# Epoch 25/256: val rmse = 0.160648
# Epoch 26/256: val rmse = 0.160239
# Epoch 27/256: val rmse = 0.162083
# Epoch 28/256: val rmse = 0.160605
# Epoch 29/256: val rmse = 0.162550
# Epoch 30/256: val rmse = 0.161475
# Epoch 31/256: val rmse = 0.163255
# Epoch 32/256: val rmse = 0.161411
# Epoch 33/256: val rmse = 0.160219
# Epoch 34/256: val rmse = 0.162174
# Epoch 35/256: val rmse = 0.161517
# Epoch 36/256: val rmse = 0.160431
# Epoch 37/256: val rmse = 0.159034
# Epoch 38/256: val rmse = 0.159640
# Epoch 39/256: val rmse = 0.159295
# Epoch 40/256: val rmse = 0.158029
# Epoch 41/256: val rmse = 0.158344
# Epoch 42/256: val rmse = 0.159029
# Epoch 43/256: val rmse = 0.157516
# Epoch 44/256: val rmse = 0.157122
# Epoch 45/256: val rmse = 0.157829
# Epoch 46/256: val rmse = 0.159734
# Epoch 47/256: val rmse = 0.160147
# Epoch 48/256: val rmse = 0.162020
# Epoch 49/256: val rmse = 0.163859
# Epoch 50/256: val rmse = 0.164677
# Epoch 51/256: val rmse = 0.164985
# Epoch 52/256: val rmse = 0.164985
# Epoch 53/256: val rmse = 0.165368
# Epoch 54/256: val rmse = 0.165249
# Epoch 55/256: val rmse = 0.165464
# Epoch 56/256: val rmse = 0.164915
# Epoch 57/256: val rmse = 0.164184
# Epoch 58/256: val rmse = 0.164528
# Epoch 59/256: val rmse = 0.164561
# Epoch 60/256: val rmse = 0.165225
# Epoch 61/256: val rmse = 0.164005
# Epoch 62/256: val rmse = 0.162323
# Epoch 63/256: val rmse = 0.162110
# Epoch 64/256: val rmse = 0.162194
# Epoch 65/256: val rmse = 0.161081
# Epoch 66/256: val rmse = 0.159753
# Epoch 67/256: val rmse = 0.160422
# Epoch 68/256: val rmse = 0.160833
# Epoch 69/256: val rmse = 0.160454
# Epoch 70/256: val rmse = 0.158751
# Epoch 71/256: val rmse = 0.159968
# Epoch 72/256: val rmse = 0.160929
# Epoch 73/256: val rmse = 0.160136
# Epoch 74/256: val rmse = 0.160661
# Epoch 75/256: val rmse = 0.161419
# Epoch 76/256: val rmse = 0.161864
# Epoch 77/256: val rmse = 0.160535
# Epoch 78/256: val rmse = 0.160421
# Epoch 79/256: val rmse = 0.160683
# Epoch 80/256: val rmse = 0.161049
# Epoch 81/256: val rmse = 0.160822
# Epoch 82/256: val rmse = 0.160958
# Epoch 83/256: val rmse = 0.160810
# Epoch 84/256: val rmse = 0.160331
# Epoch 85/256: val rmse = 0.159974
# Epoch 86/256: val rmse = 0.160706
# Epoch 87/256: val rmse = 0.160385
# Epoch 88/256: val rmse = 0.160027
# Epoch 89/256: val rmse = 0.160475
# Epoch 90/256: val rmse = 0.159063
# Epoch 91/256: val rmse = 0.158885
# Epoch 92/256: val rmse = 0.158580
# Epoch 93/256: val rmse = 0.160687
# Epoch 94/256: val rmse = 0.158901
# Epoch 95/256: val rmse = 0.158625
# Epoch 96/256: val rmse = 0.158131
# Epoch 97/256: val rmse = 0.159634
# Epoch 98/256: val rmse = 0.157822
# Epoch 99/256: val rmse = 0.159118
# Epoch 100/256: val rmse = 0.157123
# Epoch 101/256: val rmse = 0.157993
# Epoch 102/256: val rmse = 0.158945
# Epoch 103/256: val rmse = 0.158437
# Epoch 104/256: val rmse = 0.160614
# Epoch 105/256: val rmse = 0.158742
# Epoch 106/256: val rmse = 0.160141
# Epoch 107/256: val rmse = 0.162142
# Epoch 108/256: val rmse = 0.163908
# Epoch 109/256: val rmse = 0.166201
# #########################
# ### Fold 3
# #########################
# Columns classified as continuous: ['hla_match_c_high', 'hla_high_res_8', 'hla_low_res_6', 'hla_high_res_6', 'hla_high_res_10', 'hla_match_dqb1_high', 'hla_nmdp_6', 'hla_match_c_low', 'hla_match_drb1_low', 'hla_match_dqb1_low', 'year_hct', 'hla_match_a_high', 'donor_age', 'hla_match_b_low', 'age_at_hct', 'hla_match_a_low', 'hla_match_b_high', 'comorbidity_score', 'karnofsky_score', 'hla_low_res_8', 'hla_match_drb1_high', 'hla_low_res_10']
# Columns classified as categorical: ['dri_score', 'psych_disturb', 'cyto_score', 'diabetes', 'tbi_status', 'arrhythmia', 'graft_type', 'vent_hist', 'renal_issue', 'pulm_severe', 'prim_disease_hct', 'cmv_status', 'tce_imm_match', 'rituximab', 'prod_type', 'cyto_score_detail', 'conditioning_intensity', 'ethnicity', 'obesity', 'mrd_hct', 'in_vivo_tcd', 'tce_match', 'hepatic_severe', 'prior_tumor', 'peptic_ulcer', 'gvhd_proph', 'rheum_issue', 'sex_match', 'race_group', 'hepatic_mild', 'tce_div_match', 'donor_related', 'melphalan_dose', 'cardiac', 'pulm_moderate']
# Epoch 1/256: val rmse = 0.168361
# Epoch 2/256: val rmse = 0.166785
# Epoch 3/256: val rmse = 0.167409
# Epoch 4/256: val rmse = 0.167595
# Epoch 5/256: val rmse = 0.167925
# Epoch 6/256: val rmse = 0.168898
# Epoch 7/256: val rmse = 0.167599
# Epoch 8/256: val rmse = 0.168093
# Epoch 9/256: val rmse = 0.164782
# Epoch 10/256: val rmse = 0.164214
# Epoch 11/256: val rmse = 0.164129
# Epoch 12/256: val rmse = 0.162479
# Epoch 13/256: val rmse = 0.160569
# Epoch 14/256: val rmse = 0.160307
# Epoch 15/256: val rmse = 0.158313
# Epoch 16/256: val rmse = 0.158243
# Epoch 17/256: val rmse = 0.158493
# Epoch 18/256: val rmse = 0.158664
# Epoch 19/256: val rmse = 0.160098
# Epoch 20/256: val rmse = 0.160738
# Epoch 21/256: val rmse = 0.161880
# Epoch 22/256: val rmse = 0.161986
# Epoch 23/256: val rmse = 0.161816
# Epoch 24/256: val rmse = 0.163157
# Epoch 25/256: val rmse = 0.164342
# Epoch 26/256: val rmse = 0.164654
# Epoch 27/256: val rmse = 0.163312
# Epoch 28/256: val rmse = 0.164686
# Epoch 29/256: val rmse = 0.167487
# Epoch 30/256: val rmse = 0.165780
# Epoch 31/256: val rmse = 0.166472
# Epoch 32/256: val rmse = 0.164293
# Epoch 33/256: val rmse = 0.165150
# Epoch 34/256: val rmse = 0.165471
# Epoch 35/256: val rmse = 0.163457
# Epoch 36/256: val rmse = 0.163748
# Epoch 37/256: val rmse = 0.162860
# Epoch 38/256: val rmse = 0.163107
# Epoch 39/256: val rmse = 0.162355
# Epoch 40/256: val rmse = 0.161456
# Epoch 41/256: val rmse = 0.160751
# Epoch 42/256: val rmse = 0.160764
# Epoch 43/256: val rmse = 0.159934
# Epoch 44/256: val rmse = 0.159645
# Epoch 45/256: val rmse = 0.160404
# Epoch 46/256: val rmse = 0.161132
# Epoch 47/256: val rmse = 0.162533
# Epoch 48/256: val rmse = 0.164129
# Epoch 49/256: val rmse = 0.164640
# Epoch 50/256: val rmse = 0.165592
# Epoch 51/256: val rmse = 0.166018
# Epoch 52/256: val rmse = 0.166043
# Epoch 53/256: val rmse = 0.166546
# #########################
# ### Fold 4
# #########################
# Columns classified as continuous: ['hla_match_c_high', 'hla_high_res_8', 'hla_low_res_6', 'hla_high_res_6', 'hla_high_res_10', 'hla_match_dqb1_high', 'hla_nmdp_6', 'hla_match_c_low', 'hla_match_drb1_low', 'hla_match_dqb1_low', 'year_hct', 'hla_match_a_high', 'donor_age', 'hla_match_b_low', 'age_at_hct', 'hla_match_a_low', 'hla_match_b_high', 'comorbidity_score', 'karnofsky_score', 'hla_low_res_8', 'hla_match_drb1_high', 'hla_low_res_10']
# Columns classified as categorical: ['dri_score', 'psych_disturb', 'cyto_score', 'diabetes', 'tbi_status', 'arrhythmia', 'graft_type', 'vent_hist', 'renal_issue', 'pulm_severe', 'prim_disease_hct', 'cmv_status', 'tce_imm_match', 'rituximab', 'prod_type', 'cyto_score_detail', 'conditioning_intensity', 'ethnicity', 'obesity', 'mrd_hct', 'in_vivo_tcd', 'tce_match', 'hepatic_severe', 'prior_tumor', 'peptic_ulcer', 'gvhd_proph', 'rheum_issue', 'sex_match', 'race_group', 'hepatic_mild', 'tce_div_match', 'donor_related', 'melphalan_dose', 'cardiac', 'pulm_moderate']
# Epoch 1/256: val rmse = 0.161610
# Epoch 2/256: val rmse = 0.165121
# Epoch 3/256: val rmse = 0.160222
# Epoch 4/256: val rmse = 0.161013
# Epoch 5/256: val rmse = 0.160137
# Epoch 6/256: val rmse = 0.160217
# Epoch 7/256: val rmse = 0.161404
# Epoch 8/256: val rmse = 0.160566
# Epoch 9/256: val rmse = 0.160554
# Epoch 10/256: val rmse = 0.159594
# Epoch 11/256: val rmse = 0.160024
# Epoch 12/256: val rmse = 0.158392
# Epoch 13/256: val rmse = 0.155965
# Epoch 14/256: val rmse = 0.155056
# Epoch 15/256: val rmse = 0.155628
# Epoch 16/256: val rmse = 0.155508
# Epoch 17/256: val rmse = 0.156281
# Epoch 18/256: val rmse = 0.156872
# Epoch 19/256: val rmse = 0.156914
# Epoch 20/256: val rmse = 0.158220
# Epoch 21/256: val rmse = 0.159132
# Epoch 22/256: val rmse = 0.157165
# Epoch 23/256: val rmse = 0.159948
# Epoch 24/256: val rmse = 0.159140
# Epoch 25/256: val rmse = 0.158135
# Epoch 26/256: val rmse = 0.159058
# Epoch 27/256: val rmse = 0.159354
# Epoch 28/256: val rmse = 0.163431
# Epoch 29/256: val rmse = 0.160022
# Epoch 30/256: val rmse = 0.159652
# Epoch 31/256: val rmse = 0.160356
# Epoch 32/256: val rmse = 0.162174
# Epoch 33/256: val rmse = 0.160137
# Epoch 34/256: val rmse = 0.160203
# Epoch 35/256: val rmse = 0.160606
# Epoch 36/256: val rmse = 0.160965
# Epoch 37/256: val rmse = 0.159326
# Epoch 38/256: val rmse = 0.157761
# Epoch 39/256: val rmse = 0.157948
# Epoch 40/256: val rmse = 0.157107
# Epoch 41/256: val rmse = 0.157855
# Epoch 42/256: val rmse = 0.157028
# Epoch 43/256: val rmse = 0.156749
# Epoch 44/256: val rmse = 0.155907
# Epoch 45/256: val rmse = 0.157107
# Epoch 46/256: val rmse = 0.158582
# Epoch 47/256: val rmse = 0.159457
# Epoch 48/256: val rmse = 0.161854
# Epoch 49/256: val rmse = 0.162673
# Epoch 50/256: val rmse = 0.163914
# Epoch 51/256: val rmse = 0.164351
# Epoch 52/256: val rmse = 0.164519
# Epoch 53/256: val rmse = 0.164408
# #########################
# ### Fold 5
# #########################
# Columns classified as continuous: ['hla_match_c_high', 'hla_high_res_8', 'hla_low_res_6', 'hla_high_res_6', 'hla_high_res_10', 'hla_match_dqb1_high', 'hla_nmdp_6', 'hla_match_c_low', 'hla_match_drb1_low', 'hla_match_dqb1_low', 'year_hct', 'hla_match_a_high', 'donor_age', 'hla_match_b_low', 'age_at_hct', 'hla_match_a_low', 'hla_match_b_high', 'comorbidity_score', 'karnofsky_score', 'hla_low_res_8', 'hla_match_drb1_high', 'hla_low_res_10']
# Columns classified as categorical: ['dri_score', 'psych_disturb', 'cyto_score', 'diabetes', 'tbi_status', 'arrhythmia', 'graft_type', 'vent_hist', 'renal_issue', 'pulm_severe', 'prim_disease_hct', 'cmv_status', 'tce_imm_match', 'rituximab', 'prod_type', 'cyto_score_detail', 'conditioning_intensity', 'ethnicity', 'obesity', 'mrd_hct', 'in_vivo_tcd', 'tce_match', 'hepatic_severe', 'prior_tumor', 'peptic_ulcer', 'gvhd_proph', 'rheum_issue', 'sex_match', 'race_group', 'hepatic_mild', 'tce_div_match', 'donor_related', 'melphalan_dose', 'cardiac', 'pulm_moderate']
# Epoch 1/256: val rmse = 0.168946
# Epoch 2/256: val rmse = 0.168961
# Epoch 3/256: val rmse = 0.167845
# Epoch 4/256: val rmse = 0.165122
# Epoch 5/256: val rmse = 0.169030
# Epoch 6/256: val rmse = 0.165898
# Epoch 7/256: val rmse = 0.168261
# Epoch 8/256: val rmse = 0.166843
# Epoch 9/256: val rmse = 0.165726
# Epoch 10/256: val rmse = 0.163619
# Epoch 11/256: val rmse = 0.163160
# Epoch 12/256: val rmse = 0.162958
# Epoch 13/256: val rmse = 0.161780
# Epoch 14/256: val rmse = 0.160962
# Epoch 15/256: val rmse = 0.160699
# Epoch 16/256: val rmse = 0.160399
# Epoch 17/256: val rmse = 0.160776
# Epoch 18/256: val rmse = 0.160916
# Epoch 19/256: val rmse = 0.161265
# Epoch 20/256: val rmse = 0.162432
# Epoch 21/256: val rmse = 0.162757
# Epoch 22/256: val rmse = 0.162817
# Epoch 23/256: val rmse = 0.163053
# Epoch 24/256: val rmse = 0.164269
# Epoch 25/256: val rmse = 0.163430
# Epoch 26/256: val rmse = 0.163821
# Epoch 27/256: val rmse = 0.166060
# Epoch 28/256: val rmse = 0.164728
# Epoch 29/256: val rmse = 0.165118
# Epoch 30/256: val rmse = 0.165539
# Epoch 31/256: val rmse = 0.167875
# Epoch 32/256: val rmse = 0.165507
# Epoch 33/256: val rmse = 0.164421
# Epoch 34/256: val rmse = 0.166204
# Epoch 35/256: val rmse = 0.164891
# Epoch 36/256: val rmse = 0.165448
# Epoch 37/256: val rmse = 0.164480
# Epoch 38/256: val rmse = 0.163638
# Epoch 39/256: val rmse = 0.164105
# Epoch 40/256: val rmse = 0.162556
# Epoch 41/256: val rmse = 0.163032
# Epoch 42/256: val rmse = 0.161892
# Epoch 43/256: val rmse = 0.160821
# Epoch 44/256: val rmse = 0.161758
# Epoch 45/256: val rmse = 0.162245
# Epoch 46/256: val rmse = 0.163467
# Epoch 47/256: val rmse = 0.164263
# Epoch 48/256: val rmse = 0.165634
# Epoch 49/256: val rmse = 0.166437
# Epoch 50/256: val rmse = 0.167285
# Epoch 51/256: val rmse = 0.167596
# Epoch 52/256: val rmse = 0.167752
# Epoch 53/256: val rmse = 0.167737
# Epoch 54/256: val rmse = 0.167763
# Epoch 55/256: val rmse = 0.167595
# Epoch 56/256: val rmse = 0.167714
# Epoch 57/256: val rmse = 0.168009
# Epoch 58/256: val rmse = 0.168051
# Epoch 59/256: val rmse = 0.167806
# Epoch 60/256: val rmse = 0.167498
# Epoch 61/256: val rmse = 0.166729
# Epoch 62/256: val rmse = 0.166217
# Epoch 63/256: val rmse = 0.165664
# Epoch 64/256: val rmse = 0.164573
# Epoch 65/256: val rmse = 0.164394
# Epoch 66/256: val rmse = 0.164625
# Epoch 67/256: val rmse = 0.165038
# Epoch 68/256: val rmse = 0.164177
# Epoch 69/256: val rmse = 0.165603
# Epoch 70/256: val rmse = 0.164331
# Epoch 71/256: val rmse = 0.165429
# Epoch 72/256: val rmse = 0.164921
# Epoch 73/256: val rmse = 0.165574
# Epoch 74/256: val rmse = 0.164913
# Epoch 75/256: val rmse = 0.164976
# Epoch 76/256: val rmse = 0.165747
# Epoch 77/256: val rmse = 0.164840
# Epoch 78/256: val rmse = 0.165353
# Epoch 79/256: val rmse = 0.166625
# Epoch 80/256: val rmse = 0.164853
# Epoch 81/256: val rmse = 0.165151
# Epoch 82/256: val rmse = 0.165789
# Epoch 83/256: val rmse = 0.166934
# Epoch 84/256: val rmse = 0.165454
# Epoch 85/256: val rmse = 0.166158
# Epoch 86/256: val rmse = 0.166337
# Epoch 87/256: val rmse = 0.164586
# Epoch 88/256: val rmse = 0.164165
# Epoch 89/256: val rmse = 0.164448
# Epoch 90/256: val rmse = 0.164568
# Epoch 91/256: val rmse = 0.163865
# Epoch 92/256: val rmse = 0.164448
# Epoch 93/256: val rmse = 0.163170
# Epoch 94/256: val rmse = 0.163308
# Epoch 95/256: val rmse = 0.162400
# Epoch 96/256: val rmse = 0.162158
# Epoch 97/256: val rmse = 0.162723
# Epoch 98/256: val rmse = 0.162495
# Epoch 99/256: val rmse = 0.162347
# Epoch 100/256: val rmse = 0.161530
# Epoch 101/256: val rmse = 0.162926
# Epoch 102/256: val rmse = 0.162334
# Epoch 103/256: val rmse = 0.162884
# Epoch 104/256: val rmse = 0.162704
# Epoch 105/256: val rmse = 0.165903
# Epoch 106/256: val rmse = 0.166325
# Epoch 107/256: val rmse = 0.167154
# #########################
# ### Fold 6
# #########################
# Columns classified as continuous: ['hla_match_c_high', 'hla_high_res_8', 'hla_low_res_6', 'hla_high_res_6', 'hla_high_res_10', 'hla_match_dqb1_high', 'hla_nmdp_6', 'hla_match_c_low', 'hla_match_drb1_low', 'hla_match_dqb1_low', 'year_hct', 'hla_match_a_high', 'donor_age', 'hla_match_b_low', 'age_at_hct', 'hla_match_a_low', 'hla_match_b_high', 'comorbidity_score', 'karnofsky_score', 'hla_low_res_8', 'hla_match_drb1_high', 'hla_low_res_10']
# Columns classified as categorical: ['dri_score', 'psych_disturb', 'cyto_score', 'diabetes', 'tbi_status', 'arrhythmia', 'graft_type', 'vent_hist', 'renal_issue', 'pulm_severe', 'prim_disease_hct', 'cmv_status', 'tce_imm_match', 'rituximab', 'prod_type', 'cyto_score_detail', 'conditioning_intensity', 'ethnicity', 'obesity', 'mrd_hct', 'in_vivo_tcd', 'tce_match', 'hepatic_severe', 'prior_tumor', 'peptic_ulcer', 'gvhd_proph', 'rheum_issue', 'sex_match', 'race_group', 'hepatic_mild', 'tce_div_match', 'donor_related', 'melphalan_dose', 'cardiac', 'pulm_moderate']
# Epoch 1/256: val rmse = 0.169369
# Epoch 2/256: val rmse = 0.167559
# Epoch 3/256: val rmse = 0.167009
# Epoch 4/256: val rmse = 0.167012
# Epoch 5/256: val rmse = 0.166450
# Epoch 6/256: val rmse = 0.167344
# Epoch 7/256: val rmse = 0.167363
# Epoch 8/256: val rmse = 0.165741
# Epoch 9/256: val rmse = 0.168590
# Epoch 10/256: val rmse = 0.165563
# Epoch 11/256: val rmse = 0.164872
# Epoch 12/256: val rmse = 0.162906
# Epoch 13/256: val rmse = 0.162528
# Epoch 14/256: val rmse = 0.161899
# Epoch 15/256: val rmse = 0.160194
# Epoch 16/256: val rmse = 0.160707
# Epoch 17/256: val rmse = 0.160967
# Epoch 18/256: val rmse = 0.161223
# Epoch 19/256: val rmse = 0.161945
# Epoch 20/256: val rmse = 0.163902
# Epoch 21/256: val rmse = 0.163393
# Epoch 22/256: val rmse = 0.163724
# Epoch 23/256: val rmse = 0.164315
# Epoch 24/256: val rmse = 0.164368
# Epoch 25/256: val rmse = 0.164623
# Epoch 26/256: val rmse = 0.166078
# Epoch 27/256: val rmse = 0.165310
# Epoch 28/256: val rmse = 0.166570
# Epoch 29/256: val rmse = 0.167243
# Epoch 30/256: val rmse = 0.165619
# Epoch 31/256: val rmse = 0.167411
# Epoch 32/256: val rmse = 0.164962
# Epoch 33/256: val rmse = 0.166267
# Epoch 34/256: val rmse = 0.167114
# Epoch 35/256: val rmse = 0.165735
# Epoch 36/256: val rmse = 0.163755
# Epoch 37/256: val rmse = 0.164512
# Epoch 38/256: val rmse = 0.163841
# Epoch 39/256: val rmse = 0.164365
# Epoch 40/256: val rmse = 0.163371
# Epoch 41/256: val rmse = 0.162396
# Epoch 42/256: val rmse = 0.163510
# Epoch 43/256: val rmse = 0.161778
# Epoch 44/256: val rmse = 0.162822
# Epoch 45/256: val rmse = 0.163616
# Epoch 46/256: val rmse = 0.164928
# Epoch 47/256: val rmse = 0.165168
# Epoch 48/256: val rmse = 0.167408
# Epoch 49/256: val rmse = 0.168626
# Epoch 50/256: val rmse = 0.169324
# Epoch 51/256: val rmse = 0.169570
# #########################
# ### Fold 7
# #########################
# Columns classified as continuous: ['hla_match_c_high', 'hla_high_res_8', 'hla_low_res_6', 'hla_high_res_6', 'hla_high_res_10', 'hla_match_dqb1_high', 'hla_nmdp_6', 'hla_match_c_low', 'hla_match_drb1_low', 'hla_match_dqb1_low', 'year_hct', 'hla_match_a_high', 'donor_age', 'hla_match_b_low', 'age_at_hct', 'hla_match_a_low', 'hla_match_b_high', 'comorbidity_score', 'karnofsky_score', 'hla_low_res_8', 'hla_match_drb1_high', 'hla_low_res_10']
# Columns classified as categorical: ['dri_score', 'psych_disturb', 'cyto_score', 'diabetes', 'tbi_status', 'arrhythmia', 'graft_type', 'vent_hist', 'renal_issue', 'pulm_severe', 'prim_disease_hct', 'cmv_status', 'tce_imm_match', 'rituximab', 'prod_type', 'cyto_score_detail', 'conditioning_intensity', 'ethnicity', 'obesity', 'mrd_hct', 'in_vivo_tcd', 'tce_match', 'hepatic_severe', 'prior_tumor', 'peptic_ulcer', 'gvhd_proph', 'rheum_issue', 'sex_match', 'race_group', 'hepatic_mild', 'tce_div_match', 'donor_related', 'melphalan_dose', 'cardiac', 'pulm_moderate']
# Epoch 1/256: val rmse = 0.167323
# Epoch 2/256: val rmse = 0.166689
# Epoch 3/256: val rmse = 0.167428
# Epoch 4/256: val rmse = 0.166993
# Epoch 5/256: val rmse = 0.165327
# Epoch 6/256: val rmse = 0.164694
# Epoch 7/256: val rmse = 0.164461
# Epoch 8/256: val rmse = 0.165013
# Epoch 9/256: val rmse = 0.165197
# Epoch 10/256: val rmse = 0.163963
# Epoch 11/256: val rmse = 0.164014
# Epoch 12/256: val rmse = 0.162088
# Epoch 13/256: val rmse = 0.161266
# Epoch 14/256: val rmse = 0.161032
# Epoch 15/256: val rmse = 0.160621
# Epoch 16/256: val rmse = 0.160828
# Epoch 17/256: val rmse = 0.161259
# Epoch 18/256: val rmse = 0.161639
# Epoch 19/256: val rmse = 0.161871
# Epoch 20/256: val rmse = 0.162730
# Epoch 21/256: val rmse = 0.162695
# Epoch 22/256: val rmse = 0.163099
# Epoch 23/256: val rmse = 0.165082
# Epoch 24/256: val rmse = 0.164224
# Epoch 25/256: val rmse = 0.163850
# Epoch 26/256: val rmse = 0.166232
# Epoch 27/256: val rmse = 0.162910
# Epoch 28/256: val rmse = 0.164640
# Epoch 29/256: val rmse = 0.167618
# Epoch 30/256: val rmse = 0.166732
# Epoch 31/256: val rmse = 0.163534
# Epoch 32/256: val rmse = 0.164642
# Epoch 33/256: val rmse = 0.164961
# Epoch 34/256: val rmse = 0.165270
# Epoch 35/256: val rmse = 0.164576
# Epoch 36/256: val rmse = 0.163174
# Epoch 37/256: val rmse = 0.163435
# Epoch 38/256: val rmse = 0.163145
# Epoch 39/256: val rmse = 0.162779
# Epoch 40/256: val rmse = 0.162886
# Epoch 41/256: val rmse = 0.162669
# Epoch 42/256: val rmse = 0.161879
# Epoch 43/256: val rmse = 0.161876
# Epoch 44/256: val rmse = 0.161084
# Epoch 45/256: val rmse = 0.162026
# Epoch 46/256: val rmse = 0.163852
# Epoch 47/256: val rmse = 0.164869
# Epoch 48/256: val rmse = 0.166118
# Epoch 49/256: val rmse = 0.166966
# Epoch 50/256: val rmse = 0.167781
# Epoch 51/256: val rmse = 0.168198
# #########################
# ### Fold 8
# #########################
# Columns classified as continuous: ['hla_match_c_high', 'hla_high_res_8', 'hla_low_res_6', 'hla_high_res_6', 'hla_high_res_10', 'hla_match_dqb1_high', 'hla_nmdp_6', 'hla_match_c_low', 'hla_match_drb1_low', 'hla_match_dqb1_low', 'year_hct', 'hla_match_a_high', 'donor_age', 'hla_match_b_low', 'age_at_hct', 'hla_match_a_low', 'hla_match_b_high', 'comorbidity_score', 'karnofsky_score', 'hla_low_res_8', 'hla_match_drb1_high', 'hla_low_res_10']
# Columns classified as categorical: ['dri_score', 'psych_disturb', 'cyto_score', 'diabetes', 'tbi_status', 'arrhythmia', 'graft_type', 'vent_hist', 'renal_issue', 'pulm_severe', 'prim_disease_hct', 'cmv_status', 'tce_imm_match', 'rituximab', 'prod_type', 'cyto_score_detail', 'conditioning_intensity', 'ethnicity', 'obesity', 'mrd_hct', 'in_vivo_tcd', 'tce_match', 'hepatic_severe', 'prior_tumor', 'peptic_ulcer', 'gvhd_proph', 'rheum_issue', 'sex_match', 'race_group', 'hepatic_mild', 'tce_div_match', 'donor_related', 'melphalan_dose', 'cardiac', 'pulm_moderate']
# Epoch 1/256: val rmse = 0.169665
# Epoch 2/256: val rmse = 0.170348
# Epoch 3/256: val rmse = 0.168475
# Epoch 4/256: val rmse = 0.168278
# Epoch 5/256: val rmse = 0.169040
# Epoch 6/256: val rmse = 0.169671
# Epoch 7/256: val rmse = 0.169053
# Epoch 8/256: val rmse = 0.170501
# Epoch 9/256: val rmse = 0.167734
# Epoch 10/256: val rmse = 0.167070
# Epoch 11/256: val rmse = 0.165810
# Epoch 12/256: val rmse = 0.164717
# Epoch 13/256: val rmse = 0.164191
# Epoch 14/256: val rmse = 0.162122
# Epoch 15/256: val rmse = 0.162461
# Epoch 16/256: val rmse = 0.162639
# Epoch 17/256: val rmse = 0.162706
# Epoch 18/256: val rmse = 0.162831
# Epoch 19/256: val rmse = 0.163740
# Epoch 20/256: val rmse = 0.164754
# Epoch 21/256: val rmse = 0.163582
# Epoch 22/256: val rmse = 0.164372
# Epoch 23/256: val rmse = 0.166407
# Epoch 24/256: val rmse = 0.165170
# Epoch 25/256: val rmse = 0.165664
# Epoch 26/256: val rmse = 0.165151
# Epoch 27/256: val rmse = 0.165849
# Epoch 28/256: val rmse = 0.167544
# Epoch 29/256: val rmse = 0.167487
# Epoch 30/256: val rmse = 0.166509
# Epoch 31/256: val rmse = 0.167101
# Epoch 32/256: val rmse = 0.166958
# Epoch 33/256: val rmse = 0.166394
# Epoch 34/256: val rmse = 0.165729
# Epoch 35/256: val rmse = 0.166224
# Epoch 36/256: val rmse = 0.165773
# Epoch 37/256: val rmse = 0.165484
# Epoch 38/256: val rmse = 0.165110
# Epoch 39/256: val rmse = 0.164884
# Epoch 40/256: val rmse = 0.165573
# Epoch 41/256: val rmse = 0.164122
# Epoch 42/256: val rmse = 0.163211
# Epoch 43/256: val rmse = 0.163177
# Epoch 44/256: val rmse = 0.162472
# Epoch 45/256: val rmse = 0.163209
# Epoch 46/256: val rmse = 0.163637
# Epoch 47/256: val rmse = 0.165352
# Epoch 48/256: val rmse = 0.165991
# Epoch 49/256: val rmse = 0.167019
# Epoch 50/256: val rmse = 0.167905
# Epoch 51/256: val rmse = 0.168095
# Epoch 52/256: val rmse = 0.168216
# Epoch 53/256: val rmse = 0.168316
# Epoch 54/256: val rmse = 0.168544
# Epoch 55/256: val rmse = 0.168632
# Epoch 56/256: val rmse = 0.168701
# Epoch 57/256: val rmse = 0.170315
# Epoch 58/256: val rmse = 0.168589
# Epoch 59/256: val rmse = 0.169989
# Epoch 60/256: val rmse = 0.168603
# Epoch 61/256: val rmse = 0.167944
# Epoch 62/256: val rmse = 0.166477
# Epoch 63/256: val rmse = 0.165698
# Epoch 64/256: val rmse = 0.167161
# Epoch 65/256: val rmse = 0.166236
# Epoch 66/256: val rmse = 0.166616
# Epoch 67/256: val rmse = 0.164818
# Epoch 68/256: val rmse = 0.166363
# Epoch 69/256: val rmse = 0.165696
# Epoch 70/256: val rmse = 0.166760
# Epoch 71/256: val rmse = 0.166049
# Epoch 72/256: val rmse = 0.166188
# Epoch 73/256: val rmse = 0.166686
# Epoch 74/256: val rmse = 0.166436
# Epoch 75/256: val rmse = 0.166358
# Epoch 76/256: val rmse = 0.166852
# Epoch 77/256: val rmse = 0.166316
# Epoch 78/256: val rmse = 0.167171
# Epoch 79/256: val rmse = 0.166870
# Epoch 80/256: val rmse = 0.169813
# Epoch 81/256: val rmse = 0.166596
# Epoch 82/256: val rmse = 0.167352
# Epoch 83/256: val rmse = 0.166718
# Epoch 84/256: val rmse = 0.167272
# Epoch 85/256: val rmse = 0.166455
# Epoch 86/256: val rmse = 0.167499
# Epoch 87/256: val rmse = 0.166356
# Epoch 88/256: val rmse = 0.166904
# Epoch 89/256: val rmse = 0.165906
# Epoch 90/256: val rmse = 0.165908
# Epoch 91/256: val rmse = 0.165692
# Epoch 92/256: val rmse = 0.164476
# Epoch 93/256: val rmse = 0.165309
# Epoch 94/256: val rmse = 0.164442
# Epoch 95/256: val rmse = 0.164061
# Epoch 96/256: val rmse = 0.164338
# Epoch 97/256: val rmse = 0.163240
# Epoch 98/256: val rmse = 0.163848
# Epoch 99/256: val rmse = 0.163273
# Epoch 100/256: val rmse = 0.163271
# Epoch 101/256: val rmse = 0.163588
# Epoch 102/256: val rmse = 0.164173
# Epoch 103/256: val rmse = 0.163649
# Epoch 104/256: val rmse = 0.164950
# Epoch 105/256: val rmse = 0.165390
# Epoch 106/256: val rmse = 0.165724
# Epoch 107/256: val rmse = 0.167460
# Epoch 108/256: val rmse = 0.169097
# Epoch 109/256: val rmse = 0.170876
# #########################
# ### Fold 9
# #########################
# Columns classified as continuous: ['hla_match_c_high', 'hla_high_res_8', 'hla_low_res_6', 'hla_high_res_6', 'hla_high_res_10', 'hla_match_dqb1_high', 'hla_nmdp_6', 'hla_match_c_low', 'hla_match_drb1_low', 'hla_match_dqb1_low', 'year_hct', 'hla_match_a_high', 'donor_age', 'hla_match_b_low', 'age_at_hct', 'hla_match_a_low', 'hla_match_b_high', 'comorbidity_score', 'karnofsky_score', 'hla_low_res_8', 'hla_match_drb1_high', 'hla_low_res_10']
# Columns classified as categorical: ['dri_score', 'psych_disturb', 'cyto_score', 'diabetes', 'tbi_status', 'arrhythmia', 'graft_type', 'vent_hist', 'renal_issue', 'pulm_severe', 'prim_disease_hct', 'cmv_status', 'tce_imm_match', 'rituximab', 'prod_type', 'cyto_score_detail', 'conditioning_intensity', 'ethnicity', 'obesity', 'mrd_hct', 'in_vivo_tcd', 'tce_match', 'hepatic_severe', 'prior_tumor', 'peptic_ulcer', 'gvhd_proph', 'rheum_issue', 'sex_match', 'race_group', 'hepatic_mild', 'tce_div_match', 'donor_related', 'melphalan_dose', 'cardiac', 'pulm_moderate']
# Epoch 1/256: val rmse = 0.168446
# Epoch 2/256: val rmse = 0.166145
# Epoch 3/256: val rmse = 0.166035
# Epoch 4/256: val rmse = 0.165532
# Epoch 5/256: val rmse = 0.167632
# Epoch 6/256: val rmse = 0.165117
# Epoch 7/256: val rmse = 0.166620
# Epoch 8/256: val rmse = 0.166519
# Epoch 9/256: val rmse = 0.165763
# Epoch 10/256: val rmse = 0.163788
# Epoch 11/256: val rmse = 0.165121
# Epoch 12/256: val rmse = 0.162664
# Epoch 13/256: val rmse = 0.161375
# Epoch 14/256: val rmse = 0.161203
# Epoch 15/256: val rmse = 0.161192
# Epoch 16/256: val rmse = 0.161183
# Epoch 17/256: val rmse = 0.161883
# Epoch 18/256: val rmse = 0.162204
# Epoch 19/256: val rmse = 0.162372
# Epoch 20/256: val rmse = 0.163312
# Epoch 21/256: val rmse = 0.163451
# Epoch 22/256: val rmse = 0.162783
# Epoch 23/256: val rmse = 0.164587
# Epoch 24/256: val rmse = 0.163823
# Epoch 25/256: val rmse = 0.164164
# Epoch 26/256: val rmse = 0.164302
# Epoch 27/256: val rmse = 0.164776
# Epoch 28/256: val rmse = 0.164758
# Epoch 29/256: val rmse = 0.166928
# Epoch 30/256: val rmse = 0.164712
# Epoch 31/256: val rmse = 0.165199
# Epoch 32/256: val rmse = 0.164383
# Epoch 33/256: val rmse = 0.165727
# Epoch 34/256: val rmse = 0.164822
# Epoch 35/256: val rmse = 0.166017
# Epoch 36/256: val rmse = 0.164530
# Epoch 37/256: val rmse = 0.165736
# Epoch 38/256: val rmse = 0.163103
# Epoch 39/256: val rmse = 0.163719
# Epoch 40/256: val rmse = 0.161867
# Epoch 41/256: val rmse = 0.162743
# Epoch 42/256: val rmse = 0.162132
# Epoch 43/256: val rmse = 0.162259
# Epoch 44/256: val rmse = 0.161333
# Epoch 45/256: val rmse = 0.162312
# Epoch 46/256: val rmse = 0.163679
# Epoch 47/256: val rmse = 0.164811
# Epoch 48/256: val rmse = 0.166223
# Epoch 49/256: val rmse = 0.167774
# Epoch 50/256: val rmse = 0.168501
# Epoch 51/256: val rmse = 0.168908
# Epoch 52/256: val rmse = 0.168912
# Epoch 53/256: val rmse = 0.168840
# Epoch 54/256: val rmse = 0.169461
# Epoch 55/256: val rmse = 0.169168
# Epoch 56/256: val rmse = 0.169418
# Epoch 57/256: val rmse = 0.169707
# Epoch 58/256: val rmse = 0.170226
# Epoch 59/256: val rmse = 0.168149
# Epoch 60/256: val rmse = 0.169088
# Epoch 61/256: val rmse = 0.168127
# Epoch 62/256: val rmse = 0.166238
# Epoch 63/256: val rmse = 0.165040
# Epoch 64/256: val rmse = 0.166715
# Epoch 65/256: val rmse = 0.164625
# Epoch 66/256: val rmse = 0.165602
# Epoch 67/256: val rmse = 0.164816
# Epoch 68/256: val rmse = 0.163854
# Epoch 69/256: val rmse = 0.163780
# Epoch 70/256: val rmse = 0.165226
# Epoch 71/256: val rmse = 0.164758
# Epoch 72/256: val rmse = 0.165588
# Epoch 73/256: val rmse = 0.163569
# Epoch 74/256: val rmse = 0.164806
# Epoch 75/256: val rmse = 0.164046
# Epoch 76/256: val rmse = 0.163926
# Epoch 77/256: val rmse = 0.164433
# Epoch 78/256: val rmse = 0.164632
# Epoch 79/256: val rmse = 0.164724
# Epoch 80/256: val rmse = 0.164161
# Epoch 81/256: val rmse = 0.165488
# Epoch 82/256: val rmse = 0.163436
# Epoch 83/256: val rmse = 0.164652
# Epoch 84/256: val rmse = 0.163698
# Epoch 85/256: val rmse = 0.163680
# Epoch 86/256: val rmse = 0.164139
# Epoch 87/256: val rmse = 0.161641
# Epoch 88/256: val rmse = 0.164856
# Epoch 89/256: val rmse = 0.163026
# Epoch 90/256: val rmse = 0.163740
# Epoch 91/256: val rmse = 0.163043
# Epoch 92/256: val rmse = 0.163226
# Epoch 93/256: val rmse = 0.162640
# Epoch 94/256: val rmse = 0.162121
# Epoch 95/256: val rmse = 0.163253
# Epoch 96/256: val rmse = 0.161699
# Epoch 97/256: val rmse = 0.161967
# Epoch 98/256: val rmse = 0.162545
# Epoch 99/256: val rmse = 0.161868
# Epoch 100/256: val rmse = 0.162082
# Epoch 101/256: val rmse = 0.162035
# Epoch 102/256: val rmse = 0.163041
# Epoch 103/256: val rmse = 0.163137
# Epoch 104/256: val rmse = 0.163585
# Epoch 105/256: val rmse = 0.164671
# Epoch 106/256: val rmse = 0.166206
# Epoch 107/256: val rmse = 0.166996
# Epoch 108/256: val rmse = 0.169214
# Epoch 109/256: val rmse = 0.171343
# #########################
# ### Fold 10
# #########################
# Columns classified as continuous: ['hla_match_c_high', 'hla_high_res_8', 'hla_low_res_6', 'hla_high_res_6', 'hla_high_res_10', 'hla_match_dqb1_high', 'hla_nmdp_6', 'hla_match_c_low', 'hla_match_drb1_low', 'hla_match_dqb1_low', 'year_hct', 'hla_match_a_high', 'donor_age', 'hla_match_b_low', 'age_at_hct', 'hla_match_a_low', 'hla_match_b_high', 'comorbidity_score', 'karnofsky_score', 'hla_low_res_8', 'hla_match_drb1_high', 'hla_low_res_10']
# Columns classified as categorical: ['dri_score', 'psych_disturb', 'cyto_score', 'diabetes', 'tbi_status', 'arrhythmia', 'graft_type', 'vent_hist', 'renal_issue', 'pulm_severe', 'prim_disease_hct', 'cmv_status', 'tce_imm_match', 'rituximab', 'prod_type', 'cyto_score_detail', 'conditioning_intensity', 'ethnicity', 'obesity', 'mrd_hct', 'in_vivo_tcd', 'tce_match', 'hepatic_severe', 'prior_tumor', 'peptic_ulcer', 'gvhd_proph', 'rheum_issue', 'sex_match', 'race_group', 'hepatic_mild', 'tce_div_match', 'donor_related', 'melphalan_dose', 'cardiac', 'pulm_moderate']
# Epoch 1/256: val rmse = 0.165572
# Epoch 2/256: val rmse = 0.164717
# Epoch 3/256: val rmse = 0.162903
# Epoch 4/256: val rmse = 0.165954
# Epoch 5/256: val rmse = 0.162721
# Epoch 6/256: val rmse = 0.164858
# Epoch 7/256: val rmse = 0.164849
# Epoch 8/256: val rmse = 0.162492
# Epoch 9/256: val rmse = 0.162789
# Epoch 10/256: val rmse = 0.163022
# Epoch 11/256: val rmse = 0.160913
# Epoch 12/256: val rmse = 0.160294
# Epoch 13/256: val rmse = 0.157874
# Epoch 14/256: val rmse = 0.158164
# Epoch 15/256: val rmse = 0.157278
# Epoch 16/256: val rmse = 0.157097
# Epoch 17/256: val rmse = 0.157390
# Epoch 18/256: val rmse = 0.157659
# Epoch 19/256: val rmse = 0.158118
# Epoch 20/256: val rmse = 0.158535
# Epoch 21/256: val rmse = 0.159504
# Epoch 22/256: val rmse = 0.159517
# Epoch 23/256: val rmse = 0.160757
# Epoch 24/256: val rmse = 0.162243
# Epoch 25/256: val rmse = 0.160910
# Epoch 26/256: val rmse = 0.161311
# Epoch 27/256: val rmse = 0.160992
# Epoch 28/256: val rmse = 0.161434
# Epoch 29/256: val rmse = 0.163917
# Epoch 30/256: val rmse = 0.166787
# Epoch 31/256: val rmse = 0.164019
# Epoch 32/256: val rmse = 0.162778
# Epoch 33/256: val rmse = 0.165374
# Epoch 34/256: val rmse = 0.163650
# Epoch 35/256: val rmse = 0.163731
# Epoch 36/256: val rmse = 0.162163
# Epoch 37/256: val rmse = 0.162048
# Epoch 38/256: val rmse = 0.162420
# Epoch 39/256: val rmse = 0.160219
# Epoch 40/256: val rmse = 0.162355
# Epoch 41/256: val rmse = 0.158741
# Epoch 42/256: val rmse = 0.158493
# Epoch 43/256: val rmse = 0.158273
# Epoch 44/256: val rmse = 0.157973
# Epoch 45/256: val rmse = 0.158576
# Epoch 46/256: val rmse = 0.159192
# Epoch 47/256: val rmse = 0.160737
# Epoch 48/256: val rmse = 0.161733
# Epoch 49/256: val rmse = 0.163800
# Epoch 50/256: val rmse = 0.163982
# Epoch 51/256: val rmse = 0.164324
# Epoch 52/256: val rmse = 0.164493
# Epoch 53/256: val rmse = 0.164785
# CPU times: user 13min 3s, sys: 6.03 s, total: 13min 9s
# Wall time: 13min 13s

# %%
y_true = train[["ID", "efs", "efs_time", "race_group"]].copy()
y_pred = train[["ID"]].copy()
y_pred["prediction"] = oof_realmlp
m_realmlp = score(y_true.copy(), y_pred.copy(), "ID")
print(f"\nOverall CV for realmlp KaplanMeier = ", m_realmlp) # 0.6688371595345517
# Out:
# Overall CV for realmlp KaplanMeier =  0.6672550692523211

# %%
# %%time
FOLDS = 10
kf = KFold(n_splits=FOLDS, shuffle=True, random_state=52)
    
oof_mlprdtl = np.zeros(len(train))
pred_mlprdtl = np.zeros(len(test))

for i, (train_index, test_index) in enumerate(kf.split(train)):
    print("#" * 25)
    print(f"### Fold {i + 1}")
    print("#" * 25)
    
    X_train = train.loc[train_index, FEATURES].copy()
    y_train = train.loc[train_index, "y"]
    X_valid = train.loc[test_index, FEATURES].copy()
    y_valid = train.loc[test_index, "y"]
    X_test = test[FEATURES].copy()

    model_mlprdtl = MLP_RTDL_D_Regressor(
        n_cv=5,
        lr=0.0001,
        max_epochs=100,
        es_patience=20,
        random_state=52, 
        verbosity=2
    )
    model_mlprdtl.fit(
        X_train, y_train,
        X_valid, y_valid
    )
    os.makedirs('/kaggle/working/mlprdtl', exist_ok=True)
    joblib.dump(model_mlprdtl, f'/kaggle/working/mlprdtl/mlprdtl_fold_{i}.pkl')

    oof_mlprdtl[test_index] = model_mlprdtl.predict(X_valid)
    pred_mlprdtl += model_mlprdtl.predict(X_test)

pred_mlprdtl /= FOLDS
# Out:
# #########################
# ### Fold 1
# #########################
# Columns classified as continuous: ['hla_match_c_high', 'hla_high_res_8', 'hla_low_res_6', 'hla_high_res_6', 'hla_high_res_10', 'hla_match_dqb1_high', 'hla_nmdp_6', 'hla_match_c_low', 'hla_match_drb1_low', 'hla_match_dqb1_low', 'year_hct', 'hla_match_a_high', 'donor_age', 'hla_match_b_low', 'age_at_hct', 'hla_match_a_low', 'hla_match_b_high', 'comorbidity_score', 'karnofsky_score', 'hla_low_res_8', 'hla_match_drb1_high', 'hla_low_res_10']
# Columns classified as categorical: ['dri_score', 'psych_disturb', 'cyto_score', 'diabetes', 'tbi_status', 'arrhythmia', 'graft_type', 'vent_hist', 'renal_issue', 'pulm_severe', 'prim_disease_hct', 'cmv_status', 'tce_imm_match', 'rituximab', 'prod_type', 'cyto_score_detail', 'conditioning_intensity', 'ethnicity', 'obesity', 'mrd_hct', 'in_vivo_tcd', 'tce_match', 'hepatic_severe', 'prior_tumor', 'peptic_ulcer', 'gvhd_proph', 'rheum_issue', 'sex_match', 'race_group', 'hepatic_mild', 'tce_div_match', 'donor_related', 'melphalan_dose', 'cardiac', 'pulm_moderate']
# fit(): torch.cuda.is_initialized()=True
# RTDL regressor
# [('epoch_timer', <skorch.callbacks.logging.EpochTimer object at 0x792850dc3f10>), ('train_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792850dc3460>), ('valid_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792850dc0f70>), ('print_log', <skorch.callbacks.logging.PrintLog object at 0x792850dc0eb0>)]
# Initializing UniquePrefixCheckpoint
# fn_prefix is 133214229801152
# A checkpoint was triggered in epoch 2.
#   epoch    constant_val_mse    train_loss    valid_loss    cp     dur
# -------  ------------------  ------------  ------------  ----  ------
#       1              0.9915        0.9424        0.8550     +  1.2756
# A checkpoint was triggered in epoch 3.
#       2              0.9915        0.8665        0.8268     +  1.2113
# A checkpoint was triggered in epoch 4.
#       3              0.9915        0.8518        0.8171     +  1.1836
#       4              0.9915        0.8430        0.8230        1.1630
# A checkpoint was triggered in epoch 6.
#       5              0.9915        0.8358        0.8114     +  1.1844
# A checkpoint was triggered in epoch 7.
#       6              0.9915        0.8278        0.8051     +  1.1815
# A checkpoint was triggered in epoch 8.
#       7              0.9915        0.8210        0.7995     +  1.1690
# A checkpoint was triggered in epoch 9.
#       8              0.9915        0.8142        0.7993     +  1.1858
# A checkpoint was triggered in epoch 10.
#       9              0.9915        0.8090        0.7966     +  1.2058
# A checkpoint was triggered in epoch 11.
#      10              0.9915        0.8022        0.7955     +  1.1669
#      11              0.9915        0.7946        0.7988        1.1832
#      12              0.9915        0.7899        0.7970        1.1861
#      13              0.9915        0.7872        0.7991        1.1905
# A checkpoint was triggered in epoch 15.
#      14              0.9915        0.7825        0.7951     +  1.1808
#      15              0.9915        0.7748        0.8012        1.1846
#      16              0.9915        0.7718        0.7973        1.1703
#      17              0.9915        0.7663        0.7999        1.2204
#      18              0.9915        0.7613        0.7953        1.1831
#      19              0.9915        0.7534        0.7996        1.1824
#      20              0.9915        0.7485        0.8042        1.1819
#      21              0.9915        0.7429        0.8022        1.2670
#      22              0.9915        0.7404        0.8037        1.2084
#      23              0.9915        0.7358        0.8034        1.1856
#      24              0.9915        0.7292        0.8071        1.2089
#      25              0.9915        0.7270        0.8076        1.2017
#      26              0.9915        0.7208        0.8109        1.2586
#      27              0.9915        0.7152        0.8122        1.1935
#      28              0.9915        0.7092        0.8188        1.1876
#      29              0.9915        0.7029        0.8170        1.2122
#      30              0.9915        0.6985        0.8154        1.1987
#      31              0.9915        0.6957        0.8206        1.2070
#      32              0.9915        0.6865        0.8211        1.2109
#      33              0.9915        0.6814        0.8278        1.2013
# train end
# Loading best checkpoint after training.
# removing ./rtdl_checkpoints/133214229801152params.pt
# fit(): torch.cuda.is_initialized()=True
# RTDL regressor
# [('epoch_timer', <skorch.callbacks.logging.EpochTimer object at 0x79285193c070>), ('train_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x79285193fbb0>), ('valid_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x79285193c2b0>), ('print_log', <skorch.callbacks.logging.PrintLog object at 0x79285193d510>)]
# Initializing UniquePrefixCheckpoint
# fn_prefix is 133214074293504
# A checkpoint was triggered in epoch 2.
#   epoch    constant_val_mse    train_loss    valid_loss    cp     dur
# -------  ------------------  ------------  ------------  ----  ------
#       1              0.9915        0.9479        0.8745     +  1.2009
# A checkpoint was triggered in epoch 3.
#       2              0.9915        0.8698        0.8298     +  1.2064
# A checkpoint was triggered in epoch 4.
#       3              0.9915        0.8484        0.8171     +  1.1600
# A checkpoint was triggered in epoch 5.
#       4              0.9915        0.8374        0.8108     +  1.1666
# A checkpoint was triggered in epoch 6.
#       5              0.9915        0.8306        0.8061     +  1.2084
# A checkpoint was triggered in epoch 7.
#       6              0.9915        0.8216        0.8026     +  1.2421
#       7              0.9915        0.8137        0.8103        1.2121
# A checkpoint was triggered in epoch 9.
#       8              0.9915        0.8051        0.8000     +  1.2471
# A checkpoint was triggered in epoch 10.
#       9              0.9915        0.7989        0.7960     +  1.2223
#      10              0.9915        0.7930        0.7967        1.1968
# A checkpoint was triggered in epoch 12.
#      11              0.9915        0.7887        0.7952     +  1.2016
# train end
# Loading best checkpoint after training.
# removing ./rtdl_checkpoints/133214062253520params.pt
# fit(): torch.cuda.is_initialized()=True
# RTDL regressor
# [('epoch_timer', <skorch.callbacks.logging.EpochTimer object at 0x792850dc20b0>), ('train_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792850dc1fc0>), ('valid_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792850dc1ae0>), ('print_log', <skorch.callbacks.logging.PrintLog object at 0x792850dc1810>)]
# Initializing UniquePrefixCheckpoint
# fn_prefix is 133214062256352
# A checkpoint was triggered in epoch 2.
#   epoch    constant_val_mse    train_loss    valid_loss    cp     dur
# -------  ------------------  ------------  ------------  ----  ------
#       1              0.9915        0.9423        0.8572     +  1.1784
# A checkpoint was triggered in epoch 3.
#       2              0.9915        0.8662        0.8263     +  1.1764
# A checkpoint was triggered in epoch 4.
#       3              0.9915        0.8462        0.8135     +  1.1635
# A checkpoint was triggered in epoch 5.
#       4              0.9915        0.8368        0.8102     +  1.2329
#       5              0.9915        0.8279        0.8119        1.1800
# A checkpoint was triggered in epoch 7.
#       6              0.9915        0.8230        0.8049     +  1.1997
# A checkpoint was triggered in epoch 8.
#       7              0.9915        0.8135        0.8019     +  1.1888
# A checkpoint was triggered in epoch 9.
#       8              0.9915        0.8086        0.8014     +  1.1916
#       9              0.9915        0.8033        0.8029        1.2008
# A checkpoint was triggered in epoch 11.
#      10              0.9915        0.7965        0.7981     +  1.2011
#      11              0.9915        0.7902        0.8001        1.1790
# A checkpoint was triggered in epoch 13.
#      12              0.9915        0.7849        0.7972     +  1.2137
#      13              0.9915        0.7814        0.8008        1.2155
#      14              0.9915        0.7773        0.8007        1.1904
#      15              0.9915        0.7707        0.8053        1.1952
#      16              0.9915        0.7655        0.8001        1.2037
#      17              0.9915        0.7583        0.7980        1.1971
#      18              0.9915        0.7553        0.8022        1.1893
#      19              0.9915        0.7501        0.8037        1.2018
#      20              0.9915        0.7407        0.8062        1.2060
#      21              0.9915        0.7396        0.8094        1.2265
#      22              0.9915        0.7357        0.8079        1.2990
#      23              0.9915        0.7282        0.8038        1.2207
#      24              0.9915        0.7244        0.8124        1.1956
#      25              0.9915        0.7168        0.8262        1.1936
#      26              0.9915        0.7160        0.8125        1.1913
#      27              0.9915        0.7073        0.8173        1.1975
#      28              0.9915        0.7036        0.8187        1.1856
#      29              0.9915        0.6946        0.8253        1.2199
#      30              0.9915        0.6937        0.8245        1.2080
#      31              0.9915        0.6884        0.8309        1.2033
# train end
# Loading best checkpoint after training.
# removing ./rtdl_checkpoints/133214062256352params.pt
# fit(): torch.cuda.is_initialized()=True
# RTDL regressor
# [('epoch_timer', <skorch.callbacks.logging.EpochTimer object at 0x792850dc39d0>), ('train_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792850dc24d0>), ('valid_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792850dc2290>), ('print_log', <skorch.callbacks.logging.PrintLog object at 0x792850dc2ad0>)]
# Initializing UniquePrefixCheckpoint
# fn_prefix is 133214062257792
# A checkpoint was triggered in epoch 2.
#   epoch    constant_val_mse    train_loss    valid_loss    cp     dur
# -------  ------------------  ------------  ------------  ----  ------
#       1              0.9915        0.9447        0.8603     +  1.1999
# A checkpoint was triggered in epoch 3.
#       2              0.9915        0.8653        0.8236     +  1.2154
# A checkpoint was triggered in epoch 4.
#       3              0.9915        0.8470        0.8130     +  1.1800
# A checkpoint was triggered in epoch 5.
#       4              0.9915        0.8394        0.8097     +  1.2048
# A checkpoint was triggered in epoch 6.
#       5              0.9915        0.8272        0.8040     +  1.2316
#       6              0.9915        0.8203        0.8132        1.1970
# A checkpoint was triggered in epoch 8.
#       7              0.9915        0.8125        0.8014     +  1.1973
#       8              0.9915        0.8050        0.8030        1.1882
# A checkpoint was triggered in epoch 10.
#       9              0.9915        0.8006        0.7993     +  1.1954
#      10              0.9915        0.7931        0.8003        1.1958
#      11              0.9915        0.7875        0.8025        1.1980
#      12              0.9915        0.7814        0.8013        1.2096
#      13              0.9915        0.7760        0.8037        1.2234
#      14              0.9915        0.7713        0.8009        1.2328
#      15              0.9915        0.7645        0.8020        1.2733
#      16              0.9915        0.7599        0.8082        1.3033
#      17              0.9915        0.7554        0.8046        1.1917
#      18              0.9915        0.7504        0.8029        1.1994
#      19              0.9915        0.7430        0.8035        1.2173
#      20              0.9915        0.7338        0.8109        1.2009
#      21              0.9915        0.7346        0.8114        1.1943
#      22              0.9915        0.7276        0.8331        1.2320
#      23              0.9915        0.7219        0.8119        1.1889
#      24              0.9915        0.7204        0.8137        1.1918
#      25              0.9915        0.7100        0.8243        1.1738
#      26              0.9915        0.7050        0.8193        1.1748
#      27              0.9915        0.6990        0.8232        1.2084
#      28              0.9915        0.6939        0.8256        1.1933
# train end
# Loading best checkpoint after training.
# removing ./rtdl_checkpoints/133214062257792params.pt
# #########################
# ### Fold 2
# #########################
# Columns classified as continuous: ['hla_match_c_high', 'hla_high_res_8', 'hla_low_res_6', 'hla_high_res_6', 'hla_high_res_10', 'hla_match_dqb1_high', 'hla_nmdp_6', 'hla_match_c_low', 'hla_match_drb1_low', 'hla_match_dqb1_low', 'year_hct', 'hla_match_a_high', 'donor_age', 'hla_match_b_low', 'age_at_hct', 'hla_match_a_low', 'hla_match_b_high', 'comorbidity_score', 'karnofsky_score', 'hla_low_res_8', 'hla_match_drb1_high', 'hla_low_res_10']
# Columns classified as categorical: ['dri_score', 'psych_disturb', 'cyto_score', 'diabetes', 'tbi_status', 'arrhythmia', 'graft_type', 'vent_hist', 'renal_issue', 'pulm_severe', 'prim_disease_hct', 'cmv_status', 'tce_imm_match', 'rituximab', 'prod_type', 'cyto_score_detail', 'conditioning_intensity', 'ethnicity', 'obesity', 'mrd_hct', 'in_vivo_tcd', 'tce_match', 'hepatic_severe', 'prior_tumor', 'peptic_ulcer', 'gvhd_proph', 'rheum_issue', 'sex_match', 'race_group', 'hepatic_mild', 'tce_div_match', 'donor_related', 'melphalan_dose', 'cardiac', 'pulm_moderate']
# fit(): torch.cuda.is_initialized()=True
# RTDL regressor
# [('epoch_timer', <skorch.callbacks.logging.EpochTimer object at 0x792851190370>), ('train_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792851193430>), ('valid_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792851193fa0>), ('print_log', <skorch.callbacks.logging.PrintLog object at 0x7928511913f0>)]
# Initializing UniquePrefixCheckpoint
# fn_prefix is 133214074293024
# A checkpoint was triggered in epoch 2.
#   epoch    constant_val_mse    train_loss    valid_loss    cp     dur
# -------  ------------------  ------------  ------------  ----  ------
#       1              0.9712        0.9447        0.8464     +  1.2037
# A checkpoint was triggered in epoch 3.
#       2              0.9712        0.8678        0.8307     +  1.2097
# A checkpoint was triggered in epoch 4.
#       3              0.9712        0.8517        0.8232     +  1.2118
# A checkpoint was triggered in epoch 5.
#       4              0.9712        0.8397        0.8186     +  1.2029
# A checkpoint was triggered in epoch 6.
#       5              0.9712        0.8294        0.8149     +  1.1972
# A checkpoint was triggered in epoch 7.
#       6              0.9712        0.8221        0.8125     +  1.2216
#       7              0.9712        0.8153        0.8151        1.2524
# A checkpoint was triggered in epoch 9.
#       8              0.9712        0.8067        0.8112     +  1.2015
# A checkpoint was triggered in epoch 10.
#       9              0.9712        0.7998        0.8111     +  1.2089
# A checkpoint was triggered in epoch 11.
#      10              0.9712        0.7959        0.8103     +  1.2277
# A checkpoint was triggered in epoch 12.
#      11              0.9712        0.7893        0.8091     +  1.2483
# A checkpoint was triggered in epoch 13.
#      12              0.9712        0.7828        0.8065     +  1.2027
#      13              0.9712        0.7758        0.8172        1.1874
#      14              0.9712        0.7723        0.8108        1.2013
#      15              0.9712        0.7665        0.8092        1.2166
#      16              0.9712        0.7618        0.8136        1.2002
#      17              0.9712        0.7539        0.8249        1.2182
#      18              0.9712        0.7486        0.8190        1.2385
#      19              0.9712        0.7438        0.8206        1.2495
#      20              0.9712        0.7390        0.8202        1.2462
#      21              0.9712        0.7340        0.8214        1.2351
#      22              0.9712        0.7318        0.8270        1.2457
#      23              0.9712        0.7212        0.8264        1.2297
#      24              0.9712        0.7179        0.8330        1.2571
#      25              0.9712        0.7145        0.8349        1.2128
#      26              0.9712        0.7088        0.8331        1.1889
#      27              0.9712        0.7050        0.8402        1.2018
#      28              0.9712        0.6989        0.8374        1.2244
#      29              0.9712        0.6959        0.8350        1.2279
#      30              0.9712        0.6893        0.8483        1.2220
#      31              0.9712        0.6837        0.8481        1.2078
# train end
# Loading best checkpoint after training.
# removing ./rtdl_checkpoints/133214074293024params.pt
# fit(): torch.cuda.is_initialized()=True
# RTDL regressor
# [('epoch_timer', <skorch.callbacks.logging.EpochTimer object at 0x792850dc1db0>), ('train_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792850dc1d80>), ('valid_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792850dc3f40>), ('print_log', <skorch.callbacks.logging.PrintLog object at 0x792850dc2830>)]
# Initializing UniquePrefixCheckpoint
# fn_prefix is 133214234067632
# A checkpoint was triggered in epoch 2.
#   epoch    constant_val_mse    train_loss    valid_loss    cp     dur
# -------  ------------------  ------------  ------------  ----  ------
#       1              0.9712        0.9503        0.8585     +  1.2327
# A checkpoint was triggered in epoch 3.
#       2              0.9712        0.8735        0.8299     +  1.2181
# A checkpoint was triggered in epoch 4.
#       3              0.9712        0.8496        0.8293     +  1.2102
# A checkpoint was triggered in epoch 5.
#       4              0.9712        0.8370        0.8153     +  1.3438
# A checkpoint was triggered in epoch 6.
#       5              0.9712        0.8276        0.8136     +  1.2321
# A checkpoint was triggered in epoch 7.
#       6              0.9712        0.8185        0.8097     +  1.2117
#       7              0.9712        0.8127        0.8137        1.2469
#       8              0.9712        0.8058        0.8132        1.2342
# A checkpoint was triggered in epoch 10.
#       9              0.9712        0.7992        0.8062     +  1.1967
#      10              0.9712        0.7941        0.8097        1.2041
#      11              0.9712        0.7891        0.8085        1.2144
#      12              0.9712        0.7848        0.8128        1.1994
#      13              0.9712        0.7785        0.8077        1.2105
#      14              0.9712        0.7716        0.8075        1.1837
#      15              0.9712        0.7664        0.8112        1.1814
#      16              0.9712        0.7610        0.8126        1.2193
#      17              0.9712        0.7576        0.8278        1.1953
#      18              0.9712        0.7520        0.8099        1.2105
#      19              0.9712        0.7464        0.8140        1.1792
#      20              0.9712        0.7399        0.8124        1.1843
#      21              0.9712        0.7344        0.8111        1.1825
#      22              0.9712        0.7292        0.8126        1.2141
#      23              0.9712        0.7257        0.8232        1.2456
#      24              0.9712        0.7216        0.8163        1.2438
#      25              0.9712        0.7132        0.8169        1.1749
#      26              0.9712        0.7096        0.8158        1.1775
#      27              0.9712        0.7039        0.8245        1.1832
#      28              0.9712        0.6972        0.8191        1.1770
# train end
# Loading best checkpoint after training.
# removing ./rtdl_checkpoints/133214234067632params.pt
# fit(): torch.cuda.is_initialized()=True
# RTDL regressor
# [('epoch_timer', <skorch.callbacks.logging.EpochTimer object at 0x792850dc1c30>), ('train_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792850dc1a20>), ('valid_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792850dc2d40>), ('print_log', <skorch.callbacks.logging.PrintLog object at 0x792850dc2bc0>)]
# Initializing UniquePrefixCheckpoint
# fn_prefix is 133214062259472
# A checkpoint was triggered in epoch 2.
#   epoch    constant_val_mse    train_loss    valid_loss    cp     dur
# -------  ------------------  ------------  ------------  ----  ------
#       1              0.9712        0.9445        0.8436     +  1.2464
# A checkpoint was triggered in epoch 3.
#       2              0.9712        0.8664        0.8262     +  1.1981
# A checkpoint was triggered in epoch 4.
#       3              0.9712        0.8518        0.8218     +  1.2373
# A checkpoint was triggered in epoch 5.
#       4              0.9712        0.8381        0.8176     +  1.1703
# A checkpoint was triggered in epoch 6.
#       5              0.9712        0.8290        0.8140     +  1.1605
#       6              0.9712        0.8218        0.8146        1.1836
# A checkpoint was triggered in epoch 8.
#       7              0.9712        0.8139        0.8100     +  1.2005
# A checkpoint was triggered in epoch 9.
#       8              0.9712        0.8093        0.8079     +  1.1722
#       9              0.9712        0.8043        0.8086        1.1664
# A checkpoint was triggered in epoch 11.
#      10              0.9712        0.7987        0.8064     +  1.1760
#      11              0.9712        0.7909        0.8087        1.2125
# A checkpoint was triggered in epoch 13.
#      12              0.9712        0.7870        0.8047     +  1.1825
# A checkpoint was triggered in epoch 14.
#      13              0.9712        0.7819        0.8015     +  1.1826
#      14              0.9712        0.7788        0.8047        1.1579
#      15              0.9712        0.7700        0.8076        1.1946
# A checkpoint was triggered in epoch 17.
#      16              0.9712        0.7653        0.8007     +  1.1796
#      17              0.9712        0.7588        0.8025        1.1729
#      18              0.9712        0.7523        0.8044        1.2441
#      19              0.9712        0.7487        0.8009        1.2312
#       6              0.9712        0.8183        0.8060     +  1.1843
#       7              0.9712        0.8103        0.8084        1.1922
#       8              0.9712        0.8051        0.8066        1.1969
# A checkpoint was triggered in epoch 10.
#       9              0.9712        0.7993        0.8058     +  1.2547
#      10              0.9712        0.7940        0.8068        1.2188
# A checkpoint was triggered in epoch 12.
#      11              0.9712        0.7892        0.8053     +  1.1938
#      12              0.9712        0.7827        0.8153        1.2060
# A checkpoint was triggered in epoch 14.
#      13              0.9712        0.7793        0.8011     +  1.2104
# A checkpoint was triggered in epoch 15.
#      14              0.9712        0.7731        0.8006     +  1.2168
#      15              0.9712        0.7685        0.8040        1.1881
#      16              0.9712        0.7608        0.8031        1.2333
#      17              0.9712        0.7587        0.8038        1.1986
#      18              0.9712        0.7512        0.8037        1.2170
#      19              0.9712        0.7466        0.8068        1.1972
#      20              0.9712        0.7425        0.8038        1.1960
#      21              0.9712        0.7371        0.8053        1.2003
#      22              0.9712        0.7326        0.8035        1.1912
#      23              0.9712        0.7259        0.8074        1.1992
#      24              0.9712        0.7208        0.8072        1.2605
#      25              0.9712        0.7159        0.8148        1.1745
#      26              0.9712        0.7091        0.8219        1.2025
#      27              0.9712        0.7055        0.8271        1.1819
#      28              0.9712        0.7014        0.8175        1.1967
#      29              0.9712        0.6932        0.8302        1.1877
#      30              0.9712        0.6930        0.8203        1.1971
#      31              0.9712        0.6869        0.8244        1.2014
#      32              0.9712        0.6814        0.8212        1.1862
#      33              0.9712        0.6733        0.8221        1.2332
# train end
# Loading best checkpoint after training.
# removing ./rtdl_checkpoints/133214234081264params.pt
# #########################
# ### Fold 3
# #########################
# Columns classified as continuous: ['hla_match_c_high', 'hla_high_res_8', 'hla_low_res_6', 'hla_high_res_6', 'hla_high_res_10', 'hla_match_dqb1_high', 'hla_nmdp_6', 'hla_match_c_low', 'hla_match_drb1_low', 'hla_match_dqb1_low', 'year_hct', 'hla_match_a_high', 'donor_age', 'hla_match_b_low', 'age_at_hct', 'hla_match_a_low', 'hla_match_b_high', 'comorbidity_score', 'karnofsky_score', 'hla_low_res_8', 'hla_match_drb1_high', 'hla_low_res_10']
# Columns classified as categorical: ['dri_score', 'psych_disturb', 'cyto_score', 'diabetes', 'tbi_status', 'arrhythmia', 'graft_type', 'vent_hist', 'renal_issue', 'pulm_severe', 'prim_disease_hct', 'cmv_status', 'tce_imm_match', 'rituximab', 'prod_type', 'cyto_score_detail', 'conditioning_intensity', 'ethnicity', 'obesity', 'mrd_hct', 'in_vivo_tcd', 'tce_match', 'hepatic_severe', 'prior_tumor', 'peptic_ulcer', 'gvhd_proph', 'rheum_issue', 'sex_match', 'race_group', 'hepatic_mild', 'tce_div_match', 'donor_related', 'melphalan_dose', 'cardiac', 'pulm_moderate']
# fit(): torch.cuda.is_initialized()=True
# RTDL regressor
# [('epoch_timer', <skorch.callbacks.logging.EpochTimer object at 0x7928519e42e0>), ('train_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x7928519e40d0>), ('valid_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x7928519e7d30>), ('print_log', <skorch.callbacks.logging.PrintLog object at 0x7928519e6080>)]
# Initializing UniquePrefixCheckpoint
# fn_prefix is 133214074305600
# A checkpoint was triggered in epoch 2.
#   epoch    constant_val_mse    train_loss    valid_loss    cp     dur
# -------  ------------------  ------------  ------------  ----  ------
#       1              1.0239        0.9422        0.9022     +  1.2192
# A checkpoint was triggered in epoch 3.
#       2              1.0239        0.8641        0.8709     +  1.2151
# A checkpoint was triggered in epoch 4.
#       3              1.0239        0.8480        0.8636     +  1.1991
# A checkpoint was triggered in epoch 5.
#       4              1.0239        0.8381        0.8622     +  1.1897
# A checkpoint was triggered in epoch 6.
#       5              1.0239        0.8311        0.8427     +  1.2341
# A checkpoint was triggered in epoch 7.
#       6              1.0239        0.8231        0.8388     +  1.2332
#       7              1.0239        0.8164        0.8389        1.2039
# A checkpoint was triggered in epoch 9.
#       8              1.0239        0.8108        0.8324     +  1.1938
# A checkpoint was triggered in epoch 10.
#       9              1.0239        0.8063        0.8291     +  1.1813
# A checkpoint was triggered in epoch 11.
#      10              1.0239        0.7994        0.8242     +  1.1981
#      11              1.0239        0.7953        0.8297        1.1857
# A checkpoint was triggered in epoch 13.
#      12              1.0239        0.7902        0.8198     +  1.2063
#      13              1.0239        0.7852        0.8255        1.2385
# A checkpoint was triggered in epoch 15.
#      14              1.0239        0.7770        0.8181     +  1.2040
#      15              1.0239        0.7730        0.8211        1.2277
# A checkpoint was triggered in epoch 17.
#      16              1.0239        0.7698        0.8148     +  1.2089
#      17              1.0239        0.7643        0.8150        1.1882
#      18              1.0239        0.7589        0.8196        1.1832
#      19              1.0239        0.7563        0.8169        1.1973
#      20              1.0239        0.7482        0.8148        1.2052
# A checkpoint was triggered in epoch 22.
#      21              1.0239        0.7456        0.8145     +  1.2291
#      22              1.0239        0.7411        0.8154        1.2092
#      23              1.0239        0.7333        0.8171        1.2096
#      24              1.0239        0.7301        0.8210        1.2353
#      25              1.0239        0.7243        0.8204        1.2603
#      26              1.0239        0.7211        0.8215        1.2461
#      27              1.0239        0.7138        0.8237        1.2191
#      28              1.0239        0.7132        0.8241        1.2085
#      29              1.0239        0.7095        0.8247        1.2723
#      30              1.0239        0.7020        0.8217        1.2308
#      31              1.0239        0.6990        0.8254        1.1992
#      32              1.0239        0.6938        0.8282        1.1984
#      33              1.0239        0.6885        0.8295        1.1920
#      34              1.0239        0.6829        0.8271        1.2040
#      35              1.0239        0.6790        0.8366        1.2063
#      36              1.0239        0.6741        0.8357        1.1809
#      37              1.0239        0.6718        0.8318        1.1937
#      38              1.0239        0.6599        0.8401        1.2242
#      39              1.0239        0.6561        0.8403        1.2033
#      40              1.0239        0.6569        0.8443        1.1902
# train end
# Loading best checkpoint after training.
# removing ./rtdl_checkpoints/133214074305600params.pt
# fit(): torch.cuda.is_initialized()=True
# RTDL regressor
# [('epoch_timer', <skorch.callbacks.logging.EpochTimer object at 0x79285b19edd0>), ('train_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x79285b19ead0>), ('valid_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x79285b19f490>), ('print_log', <skorch.callbacks.logging.PrintLog object at 0x79285b19c220>)]
# Initializing UniquePrefixCheckpoint
# fn_prefix is 133214234076704
# A checkpoint was triggered in epoch 2.
#   epoch    constant_val_mse    train_loss    valid_loss    cp     dur
# -------  ------------------  ------------  ------------  ----  ------
#       1              1.0239        0.9451        0.9059     +  1.2234
# A checkpoint was triggered in epoch 3.
#       2              1.0239        0.8632        0.8672     +  1.2106
# A checkpoint was triggered in epoch 4.
#       3              1.0239        0.8441        0.8581     +  1.2013
# A checkpoint was triggered in epoch 5.
#       4              1.0239        0.8330        0.8522     +  1.1870
# A checkpoint was triggered in epoch 6.
#       5              1.0239        0.8276        0.8411     +  1.2258
# A checkpoint was triggered in epoch 7.
#       6              1.0239        0.8201        0.8347     +  1.2023
# A checkpoint was triggered in epoch 8.
#       7              1.0239        0.8130        0.8322     +  1.1891
# A checkpoint was triggered in epoch 9.
#       8              1.0239        0.8039        0.8275     +  1.2099
# A checkpoint was triggered in epoch 10.
#       9              1.0239        0.7994        0.8211     +  1.2040
# A checkpoint was triggered in epoch 11.
#      10              1.0239        0.7929        0.8189     +  1.3094
# A checkpoint was triggered in epoch 12.
#      11              1.0239        0.7860        0.8173     +  1.2087
#      12              1.0239        0.7817        0.8214        1.1889
# A checkpoint was triggered in epoch 14.
#      13              1.0239        0.7775        0.8160     +  1.2319
# A checkpoint was triggered in epoch 15.
#      14              1.0239        0.7733        0.8137     +  1.1980
# A checkpoint was triggered in epoch 16.
#      15              1.0239        0.7680        0.8123     +  1.2130
#      16              1.0239        0.7611        0.8139        1.1973
#      17              1.0239        0.7537        0.8204        1.1850
#      18              1.0239        0.7521        0.8141        1.1933
#      19              1.0239        0.7442        0.8124        1.2197
#      20              1.0239        0.7398        0.8132        1.2152
#      21              1.0239        0.7356        0.8164        1.2753
# A checkpoint was triggered in epoch 23.
#      22              1.0239        0.7319        0.8105     +  1.2376
#      23              1.0239        0.7248        0.8216        1.2297
#      24              1.0239        0.7204        0.8169        1.2226
#      25              1.0239        0.7163        0.8205        1.2154
#      26              1.0239        0.7110        0.8250        1.2412
#      27              1.0239        0.7040        0.8364        1.2150
#      28              1.0239        0.6979        0.8271        1.2268
#      29              1.0239        0.6966        0.8205        1.2463
#      30              1.0239        0.6888        0.8287        1.1903
#      31              1.0239        0.6856        0.8272        1.2054
#      32              1.0239        0.6798        0.8330        1.2185
#      33              1.0239        0.6759        0.8331        1.2211
#      34              1.0239        0.6705        0.8404        1.2313
#      35              1.0239        0.6671        0.8331        1.2447
#      36              1.0239        0.6620        0.8358        1.2670
#      37              1.0239        0.6520        0.8371        1.2564
#      38              1.0239        0.6498        0.8441        1.2242
#      39              1.0239        0.6483        0.8441        1.2248
#      40              1.0239        0.6399        0.8425        1.2079
#      41              1.0239        0.6348        0.8645        1.2157
# train end
# Loading best checkpoint after training.
# removing ./rtdl_checkpoints/133214234076704params.pt
# fit(): torch.cuda.is_initialized()=True
# RTDL regressor
# [('epoch_timer', <skorch.callbacks.logging.EpochTimer object at 0x79285ad58af0>), ('train_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x79285ad5bb80>), ('valid_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x79285ad59c90>), ('print_log', <skorch.callbacks.logging.PrintLog object at 0x79285a9b4eb0>)]
# Initializing UniquePrefixCheckpoint
# fn_prefix is 133214229602720
# A checkpoint was triggered in epoch 2.
#   epoch    constant_val_mse    train_loss    valid_loss    cp     dur
# -------  ------------------  ------------  ------------  ----  ------
#       1              1.0239        0.9426        0.9077     +  1.2234
# A checkpoint was triggered in epoch 3.
#       2              1.0239        0.8668        0.8810     +  1.2722
# A checkpoint was triggered in epoch 4.
#       3              1.0239        0.8475        0.8604     +  1.2879
# A checkpoint was triggered in epoch 5.
#       4              1.0239        0.8351        0.8503     +  1.2358
# A checkpoint was triggered in epoch 6.
#       5              1.0239        0.8278        0.8423     +  1.2243
# A checkpoint was triggered in epoch 7.
#       6              1.0239        0.8207        0.8417     +  1.2296
# A checkpoint was triggered in epoch 8.
#       7              1.0239        0.8124        0.8320     +  1.2255
# A checkpoint was triggered in epoch 9.
#       8              1.0239        0.8048        0.8275     +  1.2349
#       9              1.0239        0.7990        0.8491        1.2201
# A checkpoint was triggered in epoch 11.
#      10              1.0239        0.7926        0.8265     +  1.2408
# A checkpoint was triggered in epoch 12.
#      11              1.0239        0.7885        0.8210     +  1.2638
# A checkpoint was triggered in epoch 13.
#      12              1.0239        0.7809        0.8178     +  1.2303
#      13              1.0239        0.7760        0.8237        1.1930
# A checkpoint was triggered in epoch 15.
#      14              1.0239        0.7692        0.8150     +  1.2060
# A checkpoint was triggered in epoch 16.
#      15              1.0239        0.7640        0.8128     +  1.2198
#      16              1.0239        0.7583        0.8151        1.1933
# A checkpoint was triggered in epoch 18.
#      17              1.0239        0.7544        0.8115     +  1.2034
#      18              1.0239        0.7480        0.8118        1.2050
#      19              1.0239        0.7440        0.8162        1.3398
#      20              1.0239        0.7383        0.8193        1.2159
#      21              1.0239        0.7304        0.8143        1.2145
#      22              1.0239        0.7282        0.8201        1.2070
#      23              1.0239        0.7212        0.8144        1.2189
#      24              1.0239        0.7190        0.8180        1.2276
#      25              1.0239        0.7117        0.8181        1.2401
#      26              1.0239        0.7057        0.8341        1.2161
#      27              1.0239        0.7010        0.8238        1.2690
#      28              1.0239        0.6973        0.8232        1.2156
#      29              1.0239        0.6892        0.8255        1.2534
#      30              1.0239        0.6867        0.8298        1.2632
#      31              1.0239        0.6790        0.8339        1.2270
#      32              1.0239        0.6727        0.8370        1.2077
#      33              1.0239        0.6732        0.8345        1.2130
#      34              1.0239        0.6660        0.8369        1.2052
#      35              1.0239        0.6623        0.8438        1.2374
#      36              1.0239        0.6543        0.8394        1.2344
# train end
# ...
#       9              1.0044        0.8041        0.8063        1.1938
# A checkpoint was triggered in epoch 11.
#      10              1.0044        0.8010        0.8012     +  1.1865
#      11              1.0044        0.7928        0.8024        1.2494
#      12              1.0044        0.7883        0.8019        1.2145
# A checkpoint was triggered in epoch 14.
#      13              1.0044        0.7827        0.7996     +  1.2053
# A checkpoint was triggered in epoch 15.
#      14              1.0044        0.7768        0.7981     +  1.1945
# A checkpoint was triggered in epoch 16.
#      15              1.0044        0.7713        0.7980     +  1.2119
#      16              1.0044        0.7684        0.7985        1.2060
# A checkpoint was triggered in epoch 18.
#      17              1.0044        0.7614        0.7980     +  1.2053
# A checkpoint was triggered in epoch 19.
#      18              1.0044        0.7579        0.7971     +  1.2113
#      19              1.0044        0.7549        0.8017        1.2609
#      20              1.0044        0.7483        0.7998        1.1907
#      21              1.0044        0.7430        0.8028        1.3537
#      22              1.0044        0.7405        0.8042        1.2187
#      23              1.0044        0.7357        0.8097        1.2121
#      24              1.0044        0.7295        0.8124        1.2262
#      25              1.0044        0.7262        0.8047        1.2152
#      26              1.0044        0.7203        0.8076        1.2231
#      27              1.0044        0.7170        0.8111        1.2267
#      28              1.0044        0.7131        0.8087        1.1981
#      29              1.0044        0.7092        0.8191        1.1821
#      30              1.0044        0.7069        0.8147        1.2150
#      31              1.0044        0.6991        0.8186        1.2156
#      32              1.0044        0.6983        0.8146        1.2108
#      33              1.0044        0.6869        0.8195        1.2252
#      34              1.0044        0.6889        0.8163        1.2229
#      35              1.0044        0.6846        0.8178        1.2276
#      36              1.0044        0.6802        0.8190        1.2392
#      37              1.0044        0.6712        0.8270        1.2194
# train end
# Loading best checkpoint after training.
# removing ./rtdl_checkpoints/133214062122592params.pt
# fit(): torch.cuda.is_initialized()=True
# RTDL regressor
# [('epoch_timer', <skorch.callbacks.logging.EpochTimer object at 0x792850da03a0>), ('train_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792850da07f0>), ('valid_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792850da25f0>), ('print_log', <skorch.callbacks.logging.PrintLog object at 0x792850da3d60>)]
# Initializing UniquePrefixCheckpoint
# fn_prefix is 133214062125808
# A checkpoint was triggered in epoch 2.
#   epoch    constant_val_mse    train_loss    valid_loss    cp     dur
# -------  ------------------  ------------  ------------  ----  ------
#       1              1.0044        0.9490        0.8751     +  1.2141
# A checkpoint was triggered in epoch 3.
#       2              1.0044        0.8703        0.8336     +  1.1884
# A checkpoint was triggered in epoch 4.
#       3              1.0044        0.8488        0.8206     +  1.2086
# A checkpoint was triggered in epoch 5.
#       4              1.0044        0.8374        0.8119     +  1.2431
# A checkpoint was triggered in epoch 6.
#       5              1.0044        0.8281        0.8118     +  1.2746
# A checkpoint was triggered in epoch 7.
#       6              1.0044        0.8214        0.8021     +  1.2065
# A checkpoint was triggered in epoch 8.
#       7              1.0044        0.8124        0.8012     +  1.2138
#       8              1.0044        0.8051        0.8175        1.2740
# A checkpoint was triggered in epoch 10.
#       9              1.0044        0.8005        0.7983     +  1.2845
# A checkpoint was triggered in epoch 11.
#      10              1.0044        0.7927        0.7954     +  1.2281
#      11              1.0044        0.7856        0.8011        1.2059
# A checkpoint was triggered in epoch 13.
#      12              1.0044        0.7799        0.7951     +  1.2009
# A checkpoint was triggered in epoch 14.
#      13              1.0044        0.7732        0.7949     +  1.2438
#      14              1.0044        0.7692        0.7962        1.2286
#      15              1.0044        0.7632        0.7980        1.1899
#      16              1.0044        0.7562        0.7993        1.1993
#      17              1.0044        0.7509        0.8014        1.2024
# A checkpoint was triggered in epoch 2.
#   epoch    constant_val_mse    train_loss    valid_loss    cp     dur
# -------  ------------------  ------------  ------------  ----  ------
#       1              1.0044        0.9424        0.8678     +  1.1953
# A checkpoint was triggered in epoch 3.
#       2              1.0044        0.8632        0.8339     +  1.2337
# A checkpoint was triggered in epoch 4.
#       3              1.0044        0.8455        0.8215     +  1.2006
# A checkpoint was triggered in epoch 5.
#       4              1.0044        0.8360        0.8125     +  1.2026
# A checkpoint was triggered in epoch 6.
#       5              1.0044        0.8266        0.8102     +  1.1852
# A checkpoint was triggered in epoch 7.
#       6              1.0044        0.8208        0.8063     +  1.2479
# A checkpoint was triggered in epoch 8.
#       7              1.0044        0.8159        0.8042     +  1.2116
# A checkpoint was triggered in epoch 9.
#       8              1.0044        0.8078        0.8001     +  1.1948
#       9              1.0044        0.8040        0.8002        1.1974
#      10              1.0044        0.7974        0.8009        1.1993
# A checkpoint was triggered in epoch 12.
#      11              1.0044        0.7924        0.7963     +  1.2239
#      12              1.0044        0.7866        0.7979        1.2154
#      13              1.0044        0.7815        0.7974        1.1842
# A checkpoint was triggered in epoch 15.
#      14              1.0044        0.7740        0.7958     +  1.2006
# A checkpoint was triggered in epoch 16.
#      15              1.0044        0.7738        0.7944     +  1.2091
#      16              1.0044        0.7644        0.7962        1.2117
#      17              1.0044        0.7606        0.7957        1.2185
#      18              1.0044        0.7530        0.7976        1.3236
#      19              1.0044        0.7484        0.7976        1.2256
#      20              1.0044        0.7458        0.8013        1.2166
#      21              1.0044        0.7412        0.8024        1.2072
#      22              1.0044        0.7326        0.7976        1.1827
#      23              1.0044        0.7284        0.8003        1.2071
#      24              1.0044        0.7236        0.8000        1.2051
#      25              1.0044        0.7215        0.7981        1.2032
#      26              1.0044        0.7158        0.8078        1.2065
#      27              1.0044        0.7060        0.8058        1.2353
#      28              1.0044        0.7062        0.8109        1.2188
#      29              1.0044        0.6987        0.8052        1.2104
#      30              1.0044        0.6923        0.8129        1.1978
#      31              1.0044        0.6860        0.8116        1.2131
#      32              1.0044        0.6830        0.8174        1.1968
#      33              1.0044        0.6749        0.8130        1.2178
#      34              1.0044        0.6717        0.8171        1.1915
# train end
# Loading best checkpoint after training.
# removing ./rtdl_checkpoints/133214209283056params.pt
# fit(): torch.cuda.is_initialized()=True
# RTDL regressor
# [('epoch_timer', <skorch.callbacks.logging.EpochTimer object at 0x7928599f8a00>), ('train_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x7928599fb430>), ('valid_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x7928599fa3b0>), ('print_log', <skorch.callbacks.logging.PrintLog object at 0x7928599f9c90>)]
# Initializing UniquePrefixCheckpoint
# fn_prefix is 133214062129504
# A checkpoint was triggered in epoch 2.
#   epoch    constant_val_mse    train_loss    valid_loss    cp     dur
# -------  ------------------  ------------  ------------  ----  ------
#       1              1.0044        0.9386        0.8671     +  1.2084
# A checkpoint was triggered in epoch 3.
#       2              1.0044        0.8637        0.8327     +  1.2087
# A checkpoint was triggered in epoch 4.
#       3              1.0044        0.8468        0.8237     +  1.1993
# A checkpoint was triggered in epoch 5.
#       4              1.0044        0.8372        0.8119     +  1.2254
#       5              1.0044        0.8286        0.8161        1.2492
# A checkpoint was triggered in epoch 7.
#       6              1.0044        0.8223        0.8049     +  1.2016
# A checkpoint was triggered in epoch 8.
#       7              1.0044        0.8143        0.8033     +  1.2169
# A checkpoint was triggered in epoch 9.
#       8              1.0044        0.8069        0.8024     +  1.3267
# A checkpoint was triggered in epoch 10.
#       9              1.0044        0.8006        0.8004     +  1.2101
# A checkpoint was triggered in epoch 11.
#      10              1.0044        0.7950        0.7999     +  1.2020
# A checkpoint was triggered in epoch 12.
#      11              1.0044        0.7898        0.7982     +  1.1998
#      12              1.0044        0.7838        0.8053        1.2020
#      13              1.0044        0.7768        0.8026        1.2107
#      14              1.0044        0.7750        0.8022        1.2173
#      15              1.0044        0.7674        0.8011        1.1699
#      16              1.0044        0.7614        0.8057        1.2146
#      17              1.0044        0.7557        0.8061        1.2103
#      18              1.0044        0.7487        0.8081        1.1880
#      19              1.0044        0.7434        0.8075        1.2154
#      20              1.0044        0.7404        0.8075        1.1950
#      21              1.0044        0.7367        0.8104        1.2019
#      22              1.0044        0.7283        0.8122        1.2332
#      23              1.0044        0.7233        0.8134        1.2107
#      24              1.0044        0.7174        0.8144        1.2262
#      25              1.0044        0.7106        0.8142        1.2225
#      26              1.0044        0.7072        0.8147        1.1935
#      27              1.0044        0.7022        0.8134        1.2272
#      28              1.0044        0.6960        0.8194        1.1787
#      29              1.0044        0.6932        0.8192        1.2057
#      30              1.0044        0.6859        0.8245        1.2097
# train end
# Loading best checkpoint after training.
# removing ./rtdl_checkpoints/133214062129504params.pt
# CPU times: user 35min 39s, sys: 17.5 s, total: 35min 56s
# Wall time: 36min 11s

# %%
y_true = train[["ID", "efs", "efs_time", "race_group"]].copy()
y_pred = train[["ID"]].copy()
y_pred["prediction"] = oof_mlprdtl
m_mlprdtl = score(y_true.copy(), y_pred.copy(), "ID")
print(f"\nOverall CV for mlprdtl KaplanMeier = ", m_mlprdtl) # 0.6642933850923877
# Out:
# Overall CV for mlprdtl KaplanMeier =  0.6643116873294168

# %%
# %%time
FOLDS = 10
kf = KFold(n_splits=FOLDS, shuffle=True, random_state=52)
    
oof_resnet = np.zeros(len(train))
pred_resnet = np.zeros(len(test))

for i, (train_index, test_index) in enumerate(kf.split(train)):
    print("#" * 25)
    print(f"### Fold {i + 1}")
    print("#" * 25)
    
    X_train = train.loc[train_index, FEATURES].copy()
    y_train = train.loc[train_index, "y"]
    X_valid = train.loc[test_index, FEATURES].copy()
    y_valid = train.loc[test_index, "y"]
    X_test = test[FEATURES].copy()

    model_resnet = Resnet_RTDL_D_Regressor(
        n_cv=5,
        lr=0.0001,
        max_epochs=200,
        es_patience=20,
        random_state=52, 
        verbosity=2
    )
    model_resnet.fit(
        X_train, y_train,
        X_valid, y_valid
    )
    os.makedirs('/kaggle/working/resnet', exist_ok=True)
    joblib.dump(model_resnet, f'/kaggle/working/resnet/resnet_fold_{i}.pkl')

    oof_resnet[test_index] = model_resnet.predict(X_valid)
    pred_resnet += model_resnet.predict(X_test)

pred_resnet /= FOLDS
# Out:
# #########################
# ### Fold 1
# #########################
# Columns classified as continuous: ['hla_match_c_high', 'hla_high_res_8', 'hla_low_res_6', 'hla_high_res_6', 'hla_high_res_10', 'hla_match_dqb1_high', 'hla_nmdp_6', 'hla_match_c_low', 'hla_match_drb1_low', 'hla_match_dqb1_low', 'year_hct', 'hla_match_a_high', 'donor_age', 'hla_match_b_low', 'age_at_hct', 'hla_match_a_low', 'hla_match_b_high', 'comorbidity_score', 'karnofsky_score', 'hla_low_res_8', 'hla_match_drb1_high', 'hla_low_res_10']
# Columns classified as categorical: ['dri_score', 'psych_disturb', 'cyto_score', 'diabetes', 'tbi_status', 'arrhythmia', 'graft_type', 'vent_hist', 'renal_issue', 'pulm_severe', 'prim_disease_hct', 'cmv_status', 'tce_imm_match', 'rituximab', 'prod_type', 'cyto_score_detail', 'conditioning_intensity', 'ethnicity', 'obesity', 'mrd_hct', 'in_vivo_tcd', 'tce_match', 'hepatic_severe', 'prior_tumor', 'peptic_ulcer', 'gvhd_proph', 'rheum_issue', 'sex_match', 'race_group', 'hepatic_mild', 'tce_div_match', 'donor_related', 'melphalan_dose', 'cardiac', 'pulm_moderate']
# fit(): torch.cuda.is_initialized()=True
# RTDL regressor
# [('epoch_timer', <skorch.callbacks.logging.EpochTimer object at 0x7928519e4b80>), ('train_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x7928519e7d30>), ('valid_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x7928519e7ca0>), ('print_log', <skorch.callbacks.logging.PrintLog object at 0x7928519e6470>)]
# Initializing UniquePrefixCheckpoint
# fn_prefix is 133214074984944
# A checkpoint was triggered in epoch 2.
#   epoch    constant_val_mse    train_loss    valid_loss    cp     dur
# -------  ------------------  ------------  ------------  ----  ------
#       1              0.9915        0.9734        0.8624     +  1.4888
# A checkpoint was triggered in epoch 3.
#       2              0.9915        0.8898        0.8303     +  1.4233
# A checkpoint was triggered in epoch 4.
#       3              0.9915        0.8609        0.8210     +  1.4271
# A checkpoint was triggered in epoch 5.
#       4              0.9915        0.8447        0.8138     +  1.4331
# A checkpoint was triggered in epoch 6.
#       5              0.9915        0.8329        0.8119     +  1.4346
# A checkpoint was triggered in epoch 7.
#       6              0.9915        0.8228        0.8055     +  1.4562
# A checkpoint was triggered in epoch 2.
#   epoch    constant_val_mse    train_loss    valid_loss    cp     dur
# -------  ------------------  ------------  ------------  ----  ------
#       1              0.9915        0.9538        0.8439     +  1.3985
# A checkpoint was triggered in epoch 3.
#       2              0.9915        0.8779        0.8161     +  1.5689
# A checkpoint was triggered in epoch 4.
#       3              0.9915        0.8535        0.8112     +  1.4457
# A checkpoint was triggered in epoch 5.
#       4              0.9915        0.8414        0.8078     +  1.4426
# A checkpoint was triggered in epoch 6.
#       5              0.9915        0.8252        0.8032     +  1.4350
#       6              0.9915        0.8180        0.8081        1.4430
# A checkpoint was triggered in epoch 8.
#       7              0.9915        0.8106        0.8005     +  1.4461
#       8              0.9915        0.7993        0.8038        1.4404
# A checkpoint was triggered in epoch 10.
#       9              0.9915        0.7930        0.7995     +  1.4854
#      10              0.9915        0.7881        0.8062        1.4319
#      11              0.9915        0.7828        0.8046        1.4571
# A checkpoint was triggered in epoch 13.
#      12              0.9915        0.7765        0.7987     +  1.4379
# A checkpoint was triggered in epoch 14.
#      13              0.9915        0.7687        0.7956     +  1.4396
#      14              0.9915        0.7648        0.7973        1.4290
#      15              0.9915        0.7624        0.7959        1.4165
#      16              0.9915        0.7565        0.7962        1.4453
#      17              0.9915        0.7502        0.8030        1.4373
# A checkpoint was triggered in epoch 19.
#      18              0.9915        0.7473        0.7945     +  1.4221
#      19              0.9915        0.7441        0.8013        1.4233
#      20              0.9915        0.7408        0.7986        1.4573
#      21              0.9915        0.7323        0.8005        1.4496
#      22              0.9915        0.7304        0.8041        1.4439
#      23              0.9915        0.7255        0.7996        1.4656
#      24              0.9915        0.7245        0.8073        1.5386
#      25              0.9915        0.7179        0.8142        1.4044
#      26              0.9915        0.7102        0.8151        1.4248
#      27              0.9915        0.7065        0.8123        1.4357
#      28              0.9915        0.7017        0.8190        1.4587
#      29              0.9915        0.7019        0.8127        1.4439
#      30              0.9915        0.6955        0.8218        1.4812
#      31              0.9915        0.6901        0.8186        1.4163
#      32              0.9915        0.6821        0.8237        1.4463
#      33              0.9915        0.6889        0.8304        1.4316
#      34              0.9915        0.6751        0.8279        1.4490
#      35              0.9915        0.6700        0.8276        1.4300
#      36              0.9915        0.6690        0.8252        1.4229
#      37              0.9915        0.6656        0.8323        1.4687
# train end
# Loading best checkpoint after training.
# removing ./rtdl_checkpoints/133214062126960params.pt
# fit(): torch.cuda.is_initialized()=True
# RTDL regressor
# [('epoch_timer', <skorch.callbacks.logging.EpochTimer object at 0x79285b197670>), ('train_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x79285b196950>), ('valid_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x7928599fa650>), ('print_log', <skorch.callbacks.logging.PrintLog object at 0x7928599fa980>)]
# Initializing UniquePrefixCheckpoint
# fn_prefix is 133214234049456
# A checkpoint was triggered in epoch 2.
#   epoch    constant_val_mse    train_loss    valid_loss    cp     dur
# -------  ------------------  ------------  ------------  ----  ------
#       1              0.9915        0.9600        0.8582     +  1.4041
# A checkpoint was triggered in epoch 3.
#       2              0.9915        0.8877        0.8267     +  1.4281
# A checkpoint was triggered in epoch 4.
#       3              0.9915        0.8544        0.8190     +  1.4190
# A checkpoint was triggered in epoch 5.
#       4              0.9915        0.8370        0.8086     +  1.4232
# A checkpoint was triggered in epoch 6.
#       5              0.9915        0.8250        0.8080     +  1.4358
# A checkpoint was triggered in epoch 7.
#       6              0.9915        0.8148        0.8074     +  1.4657
#       7              0.9915        0.8107        0.8075        1.4931
# A checkpoint was triggered in epoch 9.
#       8              0.9915        0.7995        0.8015     +  1.5023
# A checkpoint was triggered in epoch 10.
#       9              0.9915        0.7977        0.8008     +  1.4224
# A checkpoint was triggered in epoch 11.
#      10              0.9915        0.7877        0.8000     +  1.4348
# A checkpoint was triggered in epoch 12.
#      11              0.9915        0.7838        0.7977     +  1.4378
#      12              0.9915        0.7767        0.7978        1.5055
# A checkpoint was triggered in epoch 14.
#      13              0.9915        0.7686        0.7971     +  1.4417
# A checkpoint was triggered in epoch 15.
#      14              0.9915        0.7698        0.7924     +  1.4342
# train end
# Loading best checkpoint after training.
# removing ./rtdl_checkpoints/133214061478768params.pt
# fit(): torch.cuda.is_initialized()=True
# RTDL regressor
# [('epoch_timer', <skorch.callbacks.logging.EpochTimer object at 0x792850d050f0>), ('train_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792850d06200>), ('valid_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792850d06b60>), ('print_log', <skorch.callbacks.logging.PrintLog object at 0x792850d067a0>)]
# Initializing UniquePrefixCheckpoint
# fn_prefix is 133214061494032
# A checkpoint was triggered in epoch 2.
#   epoch    constant_val_mse    train_loss    valid_loss    cp     dur
# -------  ------------------  ------------  ------------  ----  ------
#       1              0.9712        0.9699        0.8538     +  1.4134
# A checkpoint was triggered in epoch 3.
#       2              0.9712        0.8880        0.8398     +  1.4373
# A checkpoint was triggered in epoch 4.
#       3              0.9712        0.8594        0.8207     +  1.4246
# A checkpoint was triggered in epoch 5.
#       4              0.9712        0.8417        0.8175     +  1.4476
# A checkpoint was triggered in epoch 6.
#       5              0.9712        0.8253        0.8140     +  1.5330
#       6              0.9712        0.8219        0.8167        1.4772
# A checkpoint was triggered in epoch 8.
#       7              0.9712        0.8125        0.8081     +  1.4390
#       8              0.9712        0.8059        0.8109        1.4221
# A checkpoint was triggered in epoch 10.
#       9              0.9712        0.7952        0.8076     +  1.4735
#      10              0.9712        0.7941        0.8087        1.4297
# A checkpoint was triggered in epoch 12.
#      11              0.9712        0.7831        0.8058     +  1.4247
# A checkpoint was triggered in epoch 13.
#      12              0.9712        0.7799        0.8051     +  1.4466
# A checkpoint was triggered in epoch 14.
#      13              0.9712        0.7742        0.8035     +  1.4778
#      14              0.9712        0.7670        0.8056        1.4346
# A checkpoint was triggered in epoch 16.
#      15              0.9712        0.7641        0.8022     +  1.4599
#      16              0.9712        0.7597        0.8044        1.4561
# A checkpoint was triggered in epoch 18.
#      17              0.9712        0.7509        0.8000     +  1.4464
#      18              0.9712        0.7523        0.8006        1.4582
#      19              0.9712        0.7441        0.8005        1.4717
# A checkpoint was triggered in epoch 21.
#      20              0.9712        0.7414        0.7995     +  1.4712
#      21              0.9712        0.7349        0.8025        1.4562
#      22              0.9712        0.7294        0.8002        1.4392
#      23              0.9712        0.7295        0.8049        1.4326
#      24              0.9712        0.7254        0.8067        1.4342
#      25              0.9712        0.7192        0.8033        1.4706
#      26              0.9712        0.7121        0.8117        1.5261
#      27              0.9712        0.7053        0.8123        1.5635
#      28              0.9712        0.7060        0.8072        1.4785
#      29              0.9712        0.7004        0.8123        1.4549
#      30              0.9712        0.6943        0.8130        1.4533
#      31              0.9712        0.6923        0.8143        1.4741
#      32              0.9712        0.6897        0.8255        1.4498
#      33              0.9712        0.6800        0.8204        1.4369
#      34              0.9712        0.6821        0.8216        1.4661
#      35              0.9712        0.6725        0.8234        1.4624
#      36              0.9712        0.6741        0.8327        1.4438
#      37              0.9712        0.6675        0.8273        1.4487
#      38              0.9712        0.6638        0.8222        1.4549
#      39              0.9712        0.6581        0.8299        1.4696
# train end
# Loading best checkpoint after training.
# removing ./rtdl_checkpoints/133214061494032params.pt
# fit(): torch.cuda.is_initialized()=True
# RTDL regressor
# [('epoch_timer', <skorch.callbacks.logging.EpochTimer object at 0x7928511068f0>), ('train_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792851105450>), ('valid_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792851106950>), ('print_log', <skorch.callbacks.logging.PrintLog object at 0x792851107d90>)]
# Initializing UniquePrefixCheckpoint
# fn_prefix is 133214061492880
# A checkpoint was triggered in epoch 2.
#   epoch    constant_val_mse    train_loss    valid_loss    cp     dur
# -------  ------------------  ------------  ------------  ----  ------
#       1              0.9712        0.9645        0.8549     +  1.4424
# A checkpoint was triggered in epoch 3.
#       2              0.9712        0.8849        0.8321     +  1.4359
# A checkpoint was triggered in epoch 4.
#       3              0.9712        0.8602        0.8203     +  1.4425
# A checkpoint was triggered in epoch 5.
#       4              0.9712        0.8425        0.8148     +  1.4219
# A checkpoint was triggered in epoch 6.
#       5              0.9712        0.8323        0.8143     +  1.4429
# A checkpoint was triggered in epoch 7.
#       6              0.9712        0.8214        0.8090     +  1.4430
#      25              0.9712        0.7126        0.8042        1.4406
#      26              0.9712        0.7068        0.8043        1.4856
#      27              0.9712        0.7052        0.8124        1.4297
#      28              0.9712        0.6996        0.8073        1.4644
#      29              0.9712        0.6963        0.8179        1.4469
#      30              0.9712        0.6907        0.8140        1.4422
#      31              0.9712        0.6809        0.8138        1.4479
#      32              0.9712        0.6832        0.8251        1.4583
#      33              0.9712        0.6769        0.8215        1.4746
# train end
# Loading best checkpoint after training.
# removing ./rtdl_checkpoints/133214065677200params.pt
# fit(): torch.cuda.is_initialized()=True
# RTDL regressor
# [('epoch_timer', <skorch.callbacks.logging.EpochTimer object at 0x792850d06650>), ('train_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792850d077f0>), ('valid_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792850d05300>), ('print_log', <skorch.callbacks.logging.PrintLog object at 0x792850d07e50>)]
# Initializing UniquePrefixCheckpoint
# fn_prefix is 133214209291696
# A checkpoint was triggered in epoch 2.
#   epoch    constant_val_mse    train_loss    valid_loss    cp     dur
# -------  ------------------  ------------  ------------  ----  ------
#       1              0.9712        0.9543        0.8404     +  1.4530
# A checkpoint was triggered in epoch 3.
#       2              0.9712        0.8832        0.8245     +  1.4358
# A checkpoint was triggered in epoch 4.
#       3              0.9712        0.8598        0.8225     +  1.5588
# A checkpoint was triggered in epoch 5.
#       4              0.9712        0.8437        0.8149     +  1.4463
#       5              0.9712        0.8284        0.8164        1.4429
# A checkpoint was triggered in epoch 7.
#       6              0.9712        0.8175        0.8126     +  1.4802
# A checkpoint was triggered in epoch 8.
#       7              0.9712        0.8120        0.8079     +  1.4467
# A checkpoint was triggered in epoch 9.
#       8              0.9712        0.8001        0.8061     +  1.4453
#       9              0.9712        0.7959        0.8137        1.4432
#      10              0.9712        0.7890        0.8084        1.4483
#      11              0.9712        0.7865        0.8111        1.4411
#      12              0.9712        0.7822        0.8095        1.4605
# A checkpoint was triggered in epoch 14.
#      13              0.9712        0.7773        0.8051     +  1.4411
#      14              0.9712        0.7663        0.8122        1.4437
#      15              0.9712        0.7655        0.8157        1.4454
#      16              0.9712        0.7603        0.8054        1.4438
# A checkpoint was triggered in epoch 18.
#      17              0.9712        0.7531        0.8024     +  1.4385
#      18              0.9712        0.7490        0.8091        1.4405
#      19              0.9712        0.7405        0.8103        1.4938
#      20              0.9712        0.7388        0.8078        1.4434
#      21              0.9712        0.7334        0.8108        1.4505
#      22              0.9712        0.7300        0.8117        1.4406
#      23              0.9712        0.7223        0.8131        1.4591
#      24              0.9712        0.7203        0.8133        1.4941
#      25              0.9712        0.7160        0.8118        1.5393
#      26              0.9712        0.7034        0.8163        1.4818
#      27              0.9712        0.7085        0.8242        1.4573
#      28              0.9712        0.7064        0.8134        1.4671
#      29              0.9712        0.6932        0.8203        1.4633
#      30              0.9712        0.6917        0.8210        1.4346
#      31              0.9712        0.6879        0.8212        1.4609
#      32              0.9712        0.6842        0.8245        1.4432
#      33              0.9712        0.6828        0.8251        1.4562
#      34              0.9712        0.6786        0.8257        1.4430
#      35              0.9712        0.6753        0.8311        1.4613
#      36              0.9712        0.6692        0.8295        1.4779
# train end
# Loading best checkpoint after training.
# removing ./rtdl_checkpoints/133214209291696params.pt
# #########################
# ### Fold 3
# #########################
# Columns classified as continuous: ['hla_match_c_high', 'hla_high_res_8', 'hla_low_res_6', 'hla_high_res_6', 'hla_high_res_10', 'hla_match_dqb1_high', 'hla_nmdp_6', 'hla_match_c_low', 'hla_match_drb1_low', 'hla_match_dqb1_low', 'year_hct', 'hla_match_a_high', 'donor_age', 'hla_match_b_low', 'age_at_hct', 'hla_match_a_low', 'hla_match_b_high', 'comorbidity_score', 'karnofsky_score', 'hla_low_res_8', 'hla_match_drb1_high', 'hla_low_res_10']
# Columns classified as categorical: ['dri_score', 'psych_disturb', 'cyto_score', 'diabetes', 'tbi_status', 'arrhythmia', 'graft_type', 'vent_hist', 'renal_issue', 'pulm_severe', 'prim_disease_hct', 'cmv_status', 'tce_imm_match', 'rituximab', 'prod_type', 'cyto_score_detail', 'conditioning_intensity', 'ethnicity', 'obesity', 'mrd_hct', 'in_vivo_tcd', 'tce_match', 'hepatic_severe', 'prior_tumor', 'peptic_ulcer', 'gvhd_proph', 'rheum_issue', 'sex_match', 'race_group', 'hepatic_mild', 'tce_div_match', 'donor_related', 'melphalan_dose', 'cardiac', 'pulm_moderate']
# fit(): torch.cuda.is_initialized()=True
# RTDL regressor
# [('epoch_timer', <skorch.callbacks.logging.EpochTimer object at 0x7928599fa710>), ('train_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x7928599fa6e0>), ('valid_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x7928599fba90>), ('print_log', <skorch.callbacks.logging.PrintLog object at 0x7928599f8760>)]
# Initializing UniquePrefixCheckpoint
# fn_prefix is 133214209290976
# A checkpoint was triggered in epoch 2.
#   epoch    constant_val_mse    train_loss    valid_loss    cp     dur
# -------  ------------------  ------------  ------------  ----  ------
#       1              1.0239        0.9680        0.8976     +  1.5074
# A checkpoint was triggered in epoch 3.
#       2              1.0239        0.8894        0.8702     +  1.4542
# A checkpoint was triggered in epoch 4.
#       3              1.0239        0.8614        0.8593     +  1.4611
# A checkpoint was triggered in epoch 5.
#       4              1.0239        0.8389        0.8503     +  1.4554
# A checkpoint was triggered in epoch 6.
#       5              1.0239        0.8296        0.8445     +  1.4711
# A checkpoint was triggered in epoch 7.
#       6              1.0239        0.8154        0.8364     +  1.4402
# A checkpoint was triggered in epoch 8.
#       7              1.0239        0.8078        0.8354     +  1.5194
# A checkpoint was triggered in epoch 9.
#       8              1.0239        0.8000        0.8299     +  1.5100
#       9              1.0239        0.7956        0.8331        1.4564
# A checkpoint was triggered in epoch 11.
#      10              1.0239        0.7883        0.8284     +  1.4394
#      11              1.0239        0.7848        0.8300        1.4344
# A checkpoint was triggered in epoch 13.
#      12              1.0239        0.7786        0.8220     +  1.4584
# A checkpoint was triggered in epoch 14.
#      13              1.0239        0.7723        0.8210     +  1.4753
#      14              1.0239        0.7661        0.8219        1.4449
# A checkpoint was triggered in epoch 16.
#      15              1.0239        0.7593        0.8205     +  1.4893
#      16              1.0239        0.7554        0.8319        1.4418
# A checkpoint was triggered in epoch 18.
#      17              1.0239        0.7515        0.8204     +  1.4493
#      18              1.0239        0.7429        0.8274        1.4744
#      19              1.0239        0.7413        0.8263        1.4308
#      20              1.0239        0.7346        0.8299        1.4513
#      21              1.0239        0.7313        0.8268        1.4706
#      22              1.0239        0.7271        0.8336        1.4781
#      23              1.0239        0.7211        0.8277        1.4428
#      24              1.0239        0.7149        0.8311        1.4565
#      25              1.0239        0.7101        0.8383        1.4674
#      26              1.0239        0.7068        0.8330        1.4534
#      27              1.0239        0.7026        0.8321        1.4419
#      28              1.0239        0.6997        0.8352        1.4719
#      29              1.0239        0.6941        0.8408        1.5302
#      30              1.0239        0.6887        0.8425        1.4617
#      31              1.0239        0.6874        0.8388        1.4606
#      32              1.0239        0.6812        0.8537        1.4651
#      33              1.0239        0.6775        0.8492        1.4498
#      34              1.0239        0.6736        0.8414        1.4430
#      35              1.0239        0.6700        0.8556        1.4994
#      36              1.0239        0.6673        0.8457        1.4394
# train end
# Loading best checkpoint after training.
# removing ./rtdl_checkpoints/133214209290976params.pt
# fit(): torch.cuda.is_initialized()=True
# RTDL regressor
# [('epoch_timer', <skorch.callbacks.logging.EpochTimer object at 0x7928599fa560>), ('train_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x7928599f9270>), ('valid_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792850da1f00>), ('print_log', <skorch.callbacks.logging.PrintLog object at 0x792850da0a00>)]
# Initializing UniquePrefixCheckpoint
# fn_prefix is 133214229601760
# A checkpoint was triggered in epoch 2.
#   epoch    constant_val_mse    train_loss    valid_loss    cp     dur
# -------  ------------------  ------------  ------------  ----  ------
#       1              1.0239        0.9691        0.8907     +  1.4466
# A checkpoint was triggered in epoch 3.
#       2              1.0239        0.8795        0.8657     +  1.4540
# A checkpoint was triggered in epoch 4.
#       3              1.0239        0.8488        0.8572     +  1.4707
# A checkpoint was triggered in epoch 5.
#       4              1.0239        0.8350        0.8443     +  1.4707
# A checkpoint was triggered in epoch 6.
#       5              1.0239        0.8236        0.8365     +  1.4745
# A checkpoint was triggered in epoch 7.
#       6              1.0239        0.8178        0.8291     +  1.4556
# A checkpoint was triggered in epoch 8.
#       7              1.0239        0.8058        0.8272     +  1.4358
#       8              1.0239        0.8008        0.8288        1.4508
# A checkpoint was triggered in epoch 10.
#       9              1.0239        0.7942        0.8234     +  1.4483
# A checkpoint was triggered in epoch 11.
#      10              1.0239        0.7877        0.8228     +  1.4533
#      11              1.0239        0.7852        0.8263        1.4560
#      12              1.0239        0.7777        0.8276        1.4679
#      13              1.0239        0.7723        0.8288        1.5539
#      14              1.0239        0.7683        0.8280        1.4747
# A checkpoint was triggered in epoch 16.
#      15              1.0239        0.7621        0.8171     +  1.4480
#      16              1.0239        0.7548        0.8272        1.4833
#      17              1.0239        0.7522        0.8228        1.4341
#      18              1.0239        0.7480        0.8242        1.4335
#      19              1.0239        0.7428        0.8273        1.4244
#      20              1.0239        0.7394        0.8240        1.4415
#      21              1.0239        0.7349        0.8230        1.4397
#      22              1.0239        0.7269        0.8299        1.4848
#      23              1.0239        0.7237        0.8258        1.4723
#      24              1.0239        0.7182        0.8253        1.4653
#      25              1.0239        0.7144        0.8265        1.5072
#      26              1.0239        0.7083        0.8291        1.5044
#      27              1.0239        0.7028        0.8322        1.4537
#      28              1.0239        0.7044        0.8364        1.4728
#      29              1.0239        0.6977        0.8320        1.4635
#      30              1.0239        0.6937        0.8377        1.4354
#      31              1.0239        0.6890        0.8432        1.4222
#      32              1.0239        0.6831        0.8370        1.4728
#      33              1.0239        0.6785        0.8456        1.4051
#      34              1.0239        0.6743        0.8479        1.5133
# train end
# Loading best checkpoint after training.
# removing ./rtdl_checkpoints/133214229601760params.pt
# fit(): torch.cuda.is_initialized()=True
# RTDL regressor
# [('epoch_timer', <skorch.callbacks.logging.EpochTimer object at 0x792850da0040>), ('train_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792850da0520>), ('valid_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792850da3550>), ('print_log', <skorch.callbacks.logging.PrintLog object at 0x792850da1450>)]
# Initializing UniquePrefixCheckpoint
# fn_prefix is 133214062122880
# A checkpoint was triggered in epoch 2.
#   epoch    constant_val_mse    train_loss    valid_loss    cp     dur
# -------  ------------------  ------------  ------------  ----  ------
#       1              1.0239        0.9467        0.8855     +  1.4607
# A checkpoint was triggered in epoch 3.
#       2              1.0239        0.8795        0.8661     +  1.4231
# A checkpoint was triggered in epoch 4.
#       3              1.0239        0.8500        0.8494     +  1.4326
# A checkpoint was triggered in epoch 5.
#       4              1.0239        0.8322        0.8355     +  1.4772
#       5              1.0239        0.8249        0.8362        1.4359
# A checkpoint was triggered in epoch 7.
#       6              1.0239        0.8107        0.8292     +  1.4355
# A checkpoint was triggered in epoch 8.
#       7              1.0239        0.8011        0.8281     +  1.4479
# A checkpoint was triggered in epoch 9.
#       8              1.0239        0.7937        0.8208     +  1.4357
#       9              1.0239        0.7883        0.8243        1.4590
#      10              1.0239        0.7809        0.8245        1.5059
#      11              1.0239        0.7779        0.8214        1.4355
#      12              1.0239        0.7722        0.8270        1.4598
# A checkpoint was triggered in epoch 14.
#      13              1.0239        0.7671        0.8172     +  1.4372
#      14              1.0239        0.7592        0.8197        1.4331
#      15              1.0239        0.7546        0.8241        1.4375
# A checkpoint was triggered in epoch 17.
#      16              1.0239        0.7469        0.8151     +  1.4438
# A checkpoint was triggered in epoch 18.
#      17              1.0239        0.7420        0.8144     +  1.4785
#      18              1.0239        0.7427        0.8230        1.4557
# ...
# A checkpoint was triggered in epoch 10.
#       9              1.0044        0.7985        0.8045     +  1.5094
#      10              1.0044        0.7911        0.8051        1.4635
# A checkpoint was triggered in epoch 12.
#      11              1.0044        0.7878        0.8015     +  1.4223
# A checkpoint was triggered in epoch 13.
#      12              1.0044        0.7782        0.8012     +  1.4340
# A checkpoint was triggered in epoch 14.
#      13              1.0044        0.7767        0.7994     +  1.4381
# A checkpoint was triggered in epoch 15.
#      14              1.0044        0.7704        0.7904     +  1.4322
#      15              1.0044        0.7637        0.7952        1.4526
#      16              1.0044        0.7600        0.7970        1.4451
#      17              1.0044        0.7527        0.7987        1.4457
# train end
# Loading best checkpoint after training.
# removing ./rtdl_checkpoints/133214229601280params.pt
# fit(): torch.cuda.is_initialized()=True
# RTDL regressor
# [('epoch_timer', <skorch.callbacks.logging.EpochTimer object at 0x792850da2f80>), ('train_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792850da1f00>), ('valid_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792850da2770>), ('print_log', <skorch.callbacks.logging.PrintLog object at 0x792850da1120>)]
# Initializing UniquePrefixCheckpoint
# fn_prefix is 133214062120096
# A checkpoint was triggered in epoch 2.
#   epoch    constant_val_mse    train_loss    valid_loss    cp     dur
# -------  ------------------  ------------  ------------  ----  ------
#       1              1.0044        0.9534        0.8611     +  1.4377
# A checkpoint was triggered in epoch 3.
#       2              1.0044        0.8802        0.8357     +  1.4737
# A checkpoint was triggered in epoch 4.
#       3              1.0044        0.8544        0.8156     +  1.4330
# A checkpoint was triggered in epoch 5.
#       4              1.0044        0.8364        0.8091     +  1.4196
#       5              1.0044        0.8264        0.8104        1.4186
# A checkpoint was triggered in epoch 7.
#       6              1.0044        0.8141        0.8018     +  1.4054
# A checkpoint was triggered in epoch 8.
#       7              1.0044        0.8068        0.7953     +  1.4244
# A checkpoint was triggered in epoch 9.
#       8              1.0044        0.8021        0.7936     +  1.4320
# A checkpoint was triggered in epoch 10.
#       9              1.0044        0.7902        0.7900     +  1.4860
#      10              1.0044        0.7828        0.7915        1.4336
# A checkpoint was triggered in epoch 12.
#      11              1.0044        0.7791        0.7895     +  1.4248
# A checkpoint was triggered in epoch 13.
#      12              1.0044        0.7756        0.7875     +  1.4383
#      13              1.0044        0.7665        0.7901        1.4374
# A checkpoint was triggered in epoch 15.
#      14              1.0044        0.7625        0.7866     +  1.4178
# A checkpoint was triggered in epoch 16.
#      15              1.0044        0.7572        0.7853     +  1.4284
#      16              1.0044        0.7530        0.7857        1.4561
#      17              1.0044        0.7497        0.7895        1.4273
#      18              1.0044        0.7469        0.7857        1.4204
#      19              1.0044        0.7366        0.7891        1.4517
#      20              1.0044        0.7328        0.7883        1.4451
#      21              1.0044        0.7257        0.7947        1.5779
#      22              1.0044        0.7271        0.7885        1.4179
#      23              1.0044        0.7202        0.7940        1.4693
#      24              1.0044        0.7186        0.7905        1.4495
#      25              1.0044        0.7114        0.7962        1.4364
#      26              1.0044        0.7081        0.7905        1.4438
#      27              1.0044        0.7032        0.7962        1.4204
#      28              1.0044        0.6994        0.8013        1.4519
#      29              1.0044        0.6921        0.7959        1.4510
#      30              1.0044        0.6879        0.8049        1.4360
#      31              1.0044        0.6855        0.8018        1.4532
#      32              1.0044        0.6864        0.8072        1.4204
#      33              1.0044        0.6784        0.8012        1.4051
#      34              1.0044        0.6735        0.8057        1.4320
# train end
# Loading best checkpoint after training.
# removing ./rtdl_checkpoints/133214062120096params.pt
# fit(): torch.cuda.is_initialized()=True
# RTDL regressor
# [('epoch_timer', <skorch.callbacks.logging.EpochTimer object at 0x7928519e7160>), ('train_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x7928519e77c0>), ('valid_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x7928519e61a0>), ('print_log', <skorch.callbacks.logging.PrintLog object at 0x7928519e5a50>)]
# Initializing UniquePrefixCheckpoint
# fn_prefix is 133214074984416
# A checkpoint was triggered in epoch 2.
#   epoch    constant_val_mse    train_loss    valid_loss    cp     dur
# -------  ------------------  ------------  ------------  ----  ------
#       1              1.0044        0.9487        0.8553     +  1.4597
# A checkpoint was triggered in epoch 3.
#       2              1.0044        0.8780        0.8322     +  1.4189
# A checkpoint was triggered in epoch 4.
#       3              1.0044        0.8552        0.8212     +  1.4069
# A checkpoint was triggered in epoch 5.
#       4              1.0044        0.8401        0.8137     +  1.4134
# A checkpoint was triggered in epoch 6.
#       5              1.0044        0.8313        0.8100     +  1.4009
# A checkpoint was triggered in epoch 7.
#       6              1.0044        0.8185        0.8070     +  1.4380
# A checkpoint was triggered in epoch 8.
#       7              1.0044        0.8073        0.8053     +  1.5634
# A checkpoint was triggered in epoch 9.
#       8              1.0044        0.7990        0.8021     +  1.6475
#       9              1.0044        0.7922        0.8058        1.4146
# train end
# Loading best checkpoint after training.
# removing ./rtdl_checkpoints/133214074992528params.pt
# CPU times: user 42min 53s, sys: 19.4 s, total: 43min 12s
# Wall time: 43min 30s

# %%
y_true = train[["ID", "efs", "efs_time", "race_group"]].copy()
y_pred = train[["ID"]].copy()
y_pred["prediction"] = oof_resnet
m_resnet = score(y_true.copy(), y_pred.copy(), "ID")
print(f"\nOverall CV for resnet KaplanMeier = ", m_resnet) # 0.6663569259927158
# Out:
# Overall CV for resnet KaplanMeier =  0.6663968239200998

# %%
# %%time
FOLDS = 10
kf = KFold(n_splits=FOLDS, shuffle=True, random_state=52)
    
oof_ftt = np.zeros(len(train))
pred_ftt = np.zeros(len(test))

for i, (train_index, test_index) in enumerate(kf.split(train)):
    print("#" * 25)
    print(f"### Fold {i + 1}")
    print("#" * 25)
    
    X_train = train.loc[train_index, FEATURES].copy()
    y_train = train.loc[train_index, "y"]
    X_valid = train.loc[test_index, FEATURES].copy()
    y_valid = train.loc[test_index, "y"]
    X_test = test[FEATURES].copy()

    model_ftt = FTT_D_Regressor(
        n_cv=5,
        lr=0.0001,
        max_epochs=100,
        es_patience=15,
        random_state=52, 
        verbosity=2
    )
    model_ftt.fit(
        X_train, y_train,
        X_valid, y_valid
    )
    os.makedirs('/kaggle/working/ftt', exist_ok=True)
    joblib.dump(model_ftt, f'/kaggle/working/ftt/ftt_fold_{i}.pkl')

    oof_ftt[test_index] = model_ftt.predict(X_valid)
    pred_ftt += model_ftt.predict(X_test)

pred_ftt /= FOLDS
# Out:
# #########################
# ### Fold 1
# #########################
# Columns classified as continuous: ['hla_match_c_high', 'hla_high_res_8', 'hla_low_res_6', 'hla_high_res_6', 'hla_high_res_10', 'hla_match_dqb1_high', 'hla_nmdp_6', 'hla_match_c_low', 'hla_match_drb1_low', 'hla_match_dqb1_low', 'year_hct', 'hla_match_a_high', 'donor_age', 'hla_match_b_low', 'age_at_hct', 'hla_match_a_low', 'hla_match_b_high', 'comorbidity_score', 'karnofsky_score', 'hla_low_res_8', 'hla_match_drb1_high', 'hla_low_res_10']
# Columns classified as categorical: ['dri_score', 'psych_disturb', 'cyto_score', 'diabetes', 'tbi_status', 'arrhythmia', 'graft_type', 'vent_hist', 'renal_issue', 'pulm_severe', 'prim_disease_hct', 'cmv_status', 'tce_imm_match', 'rituximab', 'prod_type', 'cyto_score_detail', 'conditioning_intensity', 'ethnicity', 'obesity', 'mrd_hct', 'in_vivo_tcd', 'tce_match', 'hepatic_severe', 'prior_tumor', 'peptic_ulcer', 'gvhd_proph', 'rheum_issue', 'sex_match', 'race_group', 'hepatic_mild', 'tce_div_match', 'donor_related', 'melphalan_dose', 'cardiac', 'pulm_moderate']
# fit(): torch.cuda.is_initialized()=True
# RTDL regressor
# [('epoch_timer', <skorch.callbacks.logging.EpochTimer object at 0x792859984370>), ('train_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x7928599876d0>), ('valid_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792859987520>), ('print_log', <skorch.callbacks.logging.PrintLog object at 0x792859987400>)]
# Initializing UniquePrefixCheckpoint
# fn_prefix is 133214209281088
# self.category_embeddings.weight.shape=torch.Size([226, 192])
# A checkpoint was triggered in epoch 2.
#   epoch    constant_val_mse    train_loss    valid_loss    cp     dur
# -------  ------------------  ------------  ------------  ----  ------
#       1              0.9915        0.9207        0.8301     +  4.6725
# A checkpoint was triggered in epoch 3.
#       2              0.9915        0.8386        0.7939     +  4.6862
#       3              0.9915        0.8210        0.7939        4.7685
#       4              0.9915        0.8145        0.7941        4.8069
# A checkpoint was triggered in epoch 6.
#       5              0.9915        0.8107        0.7910     +  4.7236
#       6              0.9915        0.8112        0.8417        4.6312
#       7              0.9915        0.8002        0.7962        4.5872
#       8              0.9915        0.7992        0.7969        4.5195
#       9              0.9915        0.7927        0.8096        4.5026
# A checkpoint was triggered in epoch 11.
#      10              0.9915        0.7910        0.7888     +  4.4960
#      11              0.9915        0.7871        0.7971        4.4475
#      12              0.9915        0.7868        0.7936        4.4422
#      13              0.9915        0.7791        0.8104        4.4410
# A checkpoint was triggered in epoch 15.
#      14              0.9915        0.7766        0.7824     +  4.4141
#      15              0.9915        0.7696        0.7903        4.4492
#      16              0.9915        0.7707        0.7877        4.4641
#      17              0.9915        0.7598        0.7935        4.4948
#      18              0.9915        0.7651        0.8132        4.5226
#      19              0.9915        0.7550        0.7988        4.5313
#      20              0.9915        0.7483        0.7888        4.5394
#      21              0.9915        0.7389        0.7849        4.5318
# A checkpoint was triggered in epoch 23.
#      22              0.9915        0.7393        0.7810     +  4.5711
#      23              0.9915        0.7334        0.8147        4.5228
# A checkpoint was triggered in epoch 2.
#   epoch    constant_val_mse    train_loss    valid_loss    cp     dur
# -------  ------------------  ------------  ------------  ----  ------
#       1              0.9915        0.9174        0.8734     +  4.5589
# A checkpoint was triggered in epoch 3.
#       2              0.9915        0.8552        0.8072     +  4.5880
# A checkpoint was triggered in epoch 4.
#       3              0.9915        0.8269        0.7996     +  4.5677
#       4              0.9915        0.8143        0.8031        4.5712
# A checkpoint was triggered in epoch 6.
#       5              0.9915        0.8116        0.7895     +  4.5348
#       6              0.9915        0.8096        0.8090        4.5610
#       7              0.9915        0.8032        0.7952        4.5886
# A checkpoint was triggered in epoch 9.
#       8              0.9915        0.7991        0.7880     +  4.5723
#       9              0.9915        0.7973        0.8000        4.5600
#      10              0.9915        0.7952        0.7919        4.5706
# A checkpoint was triggered in epoch 12.
#      11              0.9915        0.7891        0.7860     +  4.5600
#      12              0.9915        0.7900        0.7870        4.5674
# A checkpoint was triggered in epoch 14.
#      13              0.9915        0.7837        0.7852     +  4.5571
#      14              0.9915        0.7771        0.8387        4.5380
#      15              0.9915        0.7769        0.7856        4.5696
# A checkpoint was triggered in epoch 17.
#      16              0.9915        0.7681        0.7847     +  4.5905
# A checkpoint was triggered in epoch 18.
#      17              0.9915        0.7665        0.7821     +  4.5580
# A checkpoint was triggered in epoch 19.
#      18              0.9915        0.7620        0.7781     +  4.5693
#      19              0.9915        0.7518        0.7918        4.5806
# A checkpoint was triggered in epoch 21.
#      20              0.9915        0.7559        0.7742     +  4.5826
#      21              0.9915        0.7465        0.7833        4.5645
#      22              0.9915        0.7435        0.7987        4.5679
#      23              0.9915        0.7392        0.7859        4.5752
#      24              0.9915        0.7318        0.8097        4.5757
#      25              0.9915        0.7256        0.7870        4.5535
#      26              0.9915        0.7175        0.7986        4.5714
#      27              0.9915        0.7173        0.7982        4.5804
#      28              0.9915        0.7069        0.8058        4.5689
#      29              0.9915        0.7026        0.8001        4.5836
#      30              0.9915        0.6918        0.8118        4.5898
#      31              0.9915        0.6891        0.8142        4.5823
#      32              0.9915        0.6788        0.8229        4.5715
#      33              0.9915        0.6686        0.8502        4.5683
#      34              0.9915        0.6663        0.8395        4.5847
# train end
# Loading best checkpoint after training.
# removing ./rtdl_checkpoints/133214234042976params.pt
# fit(): torch.cuda.is_initialized()=True
# RTDL regressor
# [('epoch_timer', <skorch.callbacks.logging.EpochTimer object at 0x7928519e6c50>), ('train_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x7928519e6a40>), ('valid_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x7928519e5a20>), ('print_log', <skorch.callbacks.logging.PrintLog object at 0x7928519e6e90>)]
# Initializing UniquePrefixCheckpoint
# fn_prefix is 133214208809600
# self.category_embeddings.weight.shape=torch.Size([226, 192])
# A checkpoint was triggered in epoch 2.
#   epoch    constant_val_mse    train_loss    valid_loss    cp     dur
# -------  ------------------  ------------  ------------  ----  ------
#       1              0.9915        0.9287        0.8783     +  4.5530
# A checkpoint was triggered in epoch 3.
#       2              0.9915        0.8408        0.8154     +  4.5585
# A checkpoint was triggered in epoch 4.
#       3              0.9915        0.8278        0.7946     +  4.5520
#       4              0.9915        0.8181        0.8238        4.5664
#       5              0.9915        0.8117        0.7987        4.5631
# A checkpoint was triggered in epoch 7.
#       6              0.9915        0.8038        0.7944     +  4.5607
# A checkpoint was triggered in epoch 8.
#       7              0.9915        0.8017        0.7912     +  4.5346
#       8              0.9915        0.8007        0.7922        4.5955
#       9              0.9915        0.7955        0.8086        4.5411
#      10              0.9915        0.7945        0.8324        4.5399
#      11              0.9915        0.7999        0.8191        4.5690
#      12              0.9915        0.7896        0.7913        4.5439
#      13              0.9915        0.7834        0.7977        4.5866
#      14              0.9915        0.7799        0.8203        4.5350
#      15              0.9915        0.7801        0.7954        4.5893
# A checkpoint was triggered in epoch 17.
#      16              0.9915        0.7680        0.7854     +  4.5548
#      17              0.9915        0.7683        0.7875        4.5472
#      18              0.9915        0.7635        0.7876        4.5457
#      19              0.9915        0.7638        0.8040        4.5631
# A checkpoint was triggered in epoch 21.
#      20              0.9915        0.7527        0.7851     +  4.5403
# A checkpoint was triggered in epoch 2.
#   epoch    constant_val_mse    train_loss    valid_loss    cp     dur
# -------  ------------------  ------------  ------------  ----  ------
#       1              0.9712        0.9115        0.8177     +  4.5076
#       2              0.9712        0.8472        0.8234        4.5179
# A checkpoint was triggered in epoch 4.
#       3              0.9712        0.8271        0.7954     +  4.5210
#       4              0.9712        0.8186        0.7985        4.5126
# A checkpoint was triggered in epoch 6.
#       5              0.9712        0.8130        0.7814     +  4.5176
# A checkpoint was triggered in epoch 7.
#       6              0.9712        0.8056        0.7748     +  4.5136
#       7              0.9712        0.8101        0.7748        4.5455
# A checkpoint was triggered in epoch 9.
#       8              0.9712        0.8021        0.7745     +  4.5651
#       9              0.9712        0.8014        0.7787        4.5354
#      10              0.9712        0.7908        0.7996        4.5400
#      11              0.9712        0.7949        0.7817        4.5429
#      12              0.9712        0.7872        0.7765        4.5462
#      13              0.9712        0.7843        0.7825        4.5394
#      14              0.9712        0.7807        0.7788        4.5286
# A checkpoint was triggered in epoch 16.
#      15              0.9712        0.7798        0.7743     +  4.5391
#      16              0.9712        0.7768        0.7840        4.5384
#      17              0.9712        0.7685        0.8135        4.5290
#      18              0.9712        0.7691        0.7934        4.5232
#      19              0.9712        0.7660        0.8030        4.5156
#      20              0.9712        0.7532        0.7813        4.5296
# A checkpoint was triggered in epoch 22.
#      21              0.9712        0.7515        0.7723     +  4.5354
#      22              0.9712        0.7466        0.7908        4.5497
#      23              0.9712        0.7405        0.7870        4.5209
#      24              0.9712        0.7360        0.7998        4.5210
#      25              0.9712        0.7255        0.8067        4.5110
#      26              0.9712        0.7161        0.7929        4.5085
#      27              0.9712        0.7139        0.7936        4.5235
#      28              0.9712        0.7072        0.8239        4.5103
#      29              0.9712        0.7034        0.8060        4.5335
#      30              0.9712        0.6986        0.8063        4.4955
#      31              0.9712        0.6865        0.8203        4.5150
#      32              0.9712        0.6805        0.8091        4.4879
#      33              0.9712        0.6702        0.8070        4.5127
#      34              0.9712        0.6598        0.8225        4.4975
#      35              0.9712        0.6559        0.8445        4.4785
# train end
# Loading best checkpoint after training.
# removing ./rtdl_checkpoints/133214065811776params.pt
# fit(): torch.cuda.is_initialized()=True
# RTDL regressor
# [('epoch_timer', <skorch.callbacks.logging.EpochTimer object at 0x792851125660>), ('train_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792851124760>), ('valid_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792851124340>), ('print_log', <skorch.callbacks.logging.PrintLog object at 0x792851126a70>)]
# Initializing UniquePrefixCheckpoint
# fn_prefix is 133214065817296
# self.category_embeddings.weight.shape=torch.Size([225, 192])
# A checkpoint was triggered in epoch 2.
#   epoch    constant_val_mse    train_loss    valid_loss    cp     dur
# -------  ------------------  ------------  ------------  ----  ------
#       1              0.9712        0.9274        0.8360     +  4.5204
# A checkpoint was triggered in epoch 3.
#       2              0.9712        0.8497        0.8072     +  4.5406
# A checkpoint was triggered in epoch 4.
#       3              0.9712        0.8298        0.7986     +  4.5429
# A checkpoint was triggered in epoch 5.
#       4              0.9712        0.8200        0.7808     +  4.5504
#       5              0.9712        0.8136        0.7827        4.5262
# A checkpoint was triggered in epoch 7.
#       6              0.9712        0.8076        0.7744     +  4.5265
#       7              0.9712        0.8057        0.7840        4.5714
# A checkpoint was triggered in epoch 9.
#       8              0.9712        0.8007        0.7717     +  4.5584
#       9              0.9712        0.8019        0.7778        4.5326
#      10              0.9712        0.7959        0.8062        4.5606
#      11              0.9712        0.7907        0.7852        4.5440
#      12              0.9712        0.7864        0.7940        4.5515
#      13              0.9712        0.7827        0.7778        4.5487
#      14              0.9712        0.7789        0.7794        4.5424
#      15              0.9712        0.7776        0.7822        4.5420
#      16              0.9712        0.7690        0.7833        4.5264
#      17              0.9712        0.7684        0.7723        4.5344
#      18              0.9712        0.7599        0.7865        4.5344
#      19              0.9712        0.7549        0.7727        4.5386
#      20              0.9712        0.7526        0.7870        4.5496
#      21              0.9712        0.7480        0.7770        4.5686
#      22              0.9712        0.7450        0.7771        4.5577
# train end
# Loading best checkpoint after training.
# removing ./rtdl_checkpoints/133214065817296params.pt
# fit(): torch.cuda.is_initialized()=True
# RTDL regressor
# [('epoch_timer', <skorch.callbacks.logging.EpochTimer object at 0x7928519121d0>), ('train_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792851912950>), ('valid_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792851913cd0>), ('print_log', <skorch.callbacks.logging.PrintLog object at 0x7928519105e0>)]
# Initializing UniquePrefixCheckpoint
# fn_prefix is 133214065807456
# self.category_embeddings.weight.shape=torch.Size([225, 192])
# A checkpoint was triggered in epoch 2.
#   epoch    constant_val_mse    train_loss    valid_loss    cp     dur
# -------  ------------------  ------------  ------------  ----  ------
#       1              0.9712        0.9382        0.8253     +  4.5629
# A checkpoint was triggered in epoch 3.
#       2              0.9712        0.8467        0.8071     +  4.5422
# A checkpoint was triggered in epoch 4.
#       3              0.9712        0.8287        0.7824     +  4.5689
#       4              0.9712        0.8171        0.7875        4.5898
# A checkpoint was triggered in epoch 6.
#       5              0.9712        0.8184        0.7818     +  4.5599
#       6              0.9712        0.8070        0.7922        4.5674
# A checkpoint was triggered in epoch 8.
#       7              0.9712        0.8045        0.7712     +  4.5824
#       8              0.9712        0.7989        0.7791        4.5772
#       9              0.9712        0.7959        0.7733        4.5937
#      10              0.9712        0.7907        0.7906        4.5896
#      11              0.9712        0.7871        0.7792        4.5924
#      12              0.9712        0.7858        0.7775        4.5849
#      13              0.9712        0.7782        0.7865        4.5698
# A checkpoint was triggered in epoch 15.
#      14              0.9712        0.7740        0.7689     +  4.5708
#      15              0.9712        0.7747        0.8018        4.5914
#      16              0.9712        0.7653        0.7718        4.5818
#      17              0.9712        0.7582        0.7714        4.5664
#      18              0.9712        0.7590        0.7815        4.5919
#      19              0.9712        0.7535        0.7864        4.5867
# A checkpoint was triggered in epoch 21.
#      20              0.9712        0.7473        0.7683     +  4.5992
#      21              0.9712        0.7419        0.7903        4.5713
#      22              0.9712        0.7386        0.7745        4.5834
#      23              0.9712        0.7323        0.8027        4.5905
#      24              0.9712        0.7217        0.8002        4.5594
#      25              0.9712        0.7136        0.7820        4.6142
#      26              0.9712        0.7086        0.7895        4.5873
#      27              0.9712        0.7060        0.7916        4.5713
#      28              0.9712        0.6968        0.8083        4.5565
#      29              0.9712        0.6893        0.7803        4.5445
#      30              0.9712        0.6774        0.8253        4.5503
#      31              0.9712        0.6697        0.8075        4.5550
#      32              0.9712        0.6618        0.8132        4.5917
#      33              0.9712        0.6520        0.8211        4.5955
#      34              0.9712        0.6434        0.8406        4.6120
# train end
# Loading best checkpoint after training.
# removing ./rtdl_checkpoints/133214065807456params.pt
# fit(): torch.cuda.is_initialized()=True
# RTDL regressor
# [('epoch_timer', <skorch.callbacks.logging.EpochTimer object at 0x792851910610>), ('train_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792851913040>), ('valid_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792851911630>), ('print_log', <skorch.callbacks.logging.PrintLog object at 0x792851913490>)]
# Initializing UniquePrefixCheckpoint
# fn_prefix is 133214074110736
# self.category_embeddings.weight.shape=torch.Size([225, 192])
# A checkpoint was triggered in epoch 2.
#   epoch    constant_val_mse    train_loss    valid_loss    cp     dur
# -------  ------------------  ------------  ------------  ----  ------
#       1              0.9712        0.9266        0.8227     +  4.5703
# A checkpoint was triggered in epoch 3.
#       2              0.9712        0.8474        0.7944     +  4.5674
# A checkpoint was triggered in epoch 4.
#       3              0.9712        0.8243        0.7869     +  4.5858
#       4              0.9712        0.8172        0.7900        4.6044
#       5              0.9712        0.8154        0.7909        4.5659
#       6              0.9712        0.8114        0.8127        4.5654
# A checkpoint was triggered in epoch 8.
#       7              0.9712        0.8078        0.7821     +  4.5866
# A checkpoint was triggered in epoch 9.
#       8              0.9712        0.8022        0.7766     +  4.5761
#       9              0.9712        0.7978        0.7780        4.5769
#      10              0.9712        0.7956        0.7779        4.5862
#      11              0.9712        0.7945        0.7974        4.5654
# A checkpoint was triggered in epoch 13.
#      12              0.9712        0.7918        0.7705     +  4.5618
#      13              0.9712        0.7894        0.7833        4.5514
#      14              0.9712        0.7875        0.7753        4.5378
#      15              0.9712        0.7790        0.7711        4.5554
#      16              0.9712        0.7796        0.7799        4.5555
# A checkpoint was triggered in epoch 18.
#      17              0.9712        0.7722        0.7700     +  4.5875
#      18              0.9712        0.7677        0.7757        4.5679
#      19              0.9712        0.7618        0.7752        4.5706
#      20              0.9712        0.7578        0.7733        4.5605
# A checkpoint was triggered in epoch 22.
#      21              0.9712        0.7526        0.7691     +  4.5698
#      22              0.9712        0.7471        0.7778        4.5776
#      23              0.9712        0.7468        0.7702        4.5587
#      24              0.9712        0.7388        0.7813        4.5860
#      25              0.9712        0.7343        0.7844        4.5624
#      26              0.9712        0.7280        0.7870        4.5541
#      27              0.9712        0.7241        0.7954        4.5651
#      28              0.9712        0.7161        0.8058        4.5698
#      29              0.9712        0.7098        0.7948        4.5658
#      30              0.9712        0.6967        0.8089        4.5189
#      31              0.9712        0.6953        0.7951        4.5888
#      32              0.9712        0.6857        0.7959        4.5514
#      33              0.9712        0.6828        0.8270        4.5430
#      34              0.9712        0.6781        0.8239        4.5684
#      35              0.9712        0.6672        0.8240        4.5589
# train end
# Loading best checkpoint after training.
# removing ./rtdl_checkpoints/133214074110736params.pt
# fit(): torch.cuda.is_initialized()=True
# RTDL regressor
# [('epoch_timer', <skorch.callbacks.logging.EpochTimer object at 0x792851913a90>), ('train_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x7928519106d0>), ('valid_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792851911990>), ('print_log', <skorch.callbacks.logging.PrintLog object at 0x7928519116c0>)]
# Initializing UniquePrefixCheckpoint
# fn_prefix is 133214074110688
# self.category_embeddings.weight.shape=torch.Size([225, 192])
# A checkpoint was triggered in epoch 2.
#   epoch    constant_val_mse    train_loss    valid_loss    cp     dur
# -------  ------------------  ------------  ------------  ----  ------
#       1              0.9712        0.9285        0.8109     +  4.5777
#       2              0.9712        0.8474        0.8130        4.5965
# A checkpoint was triggered in epoch 4.
#       3              0.9712        0.8339        0.8078     +  4.5906
# A checkpoint was triggered in epoch 5.
#       4              0.9712        0.8183        0.7886     +  4.5874
# A checkpoint was triggered in epoch 6.
#       5              0.9712        0.8089        0.7833     +  4.5824
#       6              0.9712        0.8108        0.7837        4.5890
#       7              0.9712        0.8059        0.8405        4.5789
# A checkpoint was triggered in epoch 9.
#       8              0.9712        0.8053        0.7809     +  4.5882
# A checkpoint was triggered in epoch 10.
#       9              0.9712        0.7970        0.7768     +  4.5907
#      10              0.9712        0.8000        0.7801        4.5789
#      11              0.9712        0.7990        0.7911        4.5788
#      12              0.9712        0.7962        0.7964        4.5877
#      13              0.9712        0.7920        0.7776        4.5928
#      14              0.9712        0.7859        0.7813        4.5958
#      15              0.9712        0.7834        0.7843        4.5889
#      16              0.9712        0.7761        0.7818        4.6169
# A checkpoint was triggered in epoch 18.
#      17              0.9712        0.7784        0.7741     +  4.6110
#      18              0.9712        0.7724        0.7827        4.5876
#      19              0.9712        0.7671        0.7761        4.5867
#      20              0.9712        0.7636        0.7816        4.5835
#      21              0.9712        0.7619        0.7810        4.5986
# A checkpoint was triggered in epoch 23.
#      22              0.9712        0.7609        0.7658     +  4.5991
#      23              0.9712        0.7525        0.7754        4.6058
#      24              0.9712        0.7469        0.7778        4.5736
#      25              0.9712        0.7408        0.7861        4.5772
#      26              0.9712        0.7356        0.7843        4.5947
#      27              0.9712        0.7325        0.7875        4.6035
#      28              0.9712        0.7261        0.8106        4.6122
#      29              0.9712        0.7175        0.7821        4.6118
#      30              0.9712        0.7160        0.8175        4.6063
#      31              0.9712        0.7103        0.7972        4.5925
#      32              0.9712        0.6971        0.8071        4.5866
#      33              0.9712        0.6890        0.8172        4.5934
#      34              0.9712        0.6827        0.8457        4.5851
#      35              0.9712        0.6769        0.8326        4.6018
#      36              0.9712        0.6691        0.8369        4.5960
# train end
# Loading best checkpoint after training.
# removing ./rtdl_checkpoints/133214074110688params.pt
# #########################
# ### Fold 3
# #########################
# Columns classified as continuous: ['hla_match_c_high', 'hla_high_res_8', 'hla_low_res_6', 'hla_high_res_6', 'hla_high_res_10', 'hla_match_dqb1_high', 'hla_nmdp_6', 'hla_match_c_low', 'hla_match_drb1_low', 'hla_match_dqb1_low', 'year_hct', 'hla_match_a_high', 'donor_age', 'hla_match_b_low', 'age_at_hct', 'hla_match_a_low', 'hla_match_b_high', 'comorbidity_score', 'karnofsky_score', 'hla_low_res_8', 'hla_match_drb1_high', 'hla_low_res_10']
# Columns classified as categorical: ['dri_score', 'psych_disturb', 'cyto_score', 'diabetes', 'tbi_status', 'arrhythmia', 'graft_type', 'vent_hist', 'renal_issue', 'pulm_severe', 'prim_disease_hct', 'cmv_status', 'tce_imm_match', 'rituximab', 'prod_type', 'cyto_score_detail', 'conditioning_intensity', 'ethnicity', 'obesity', 'mrd_hct', 'in_vivo_tcd', 'tce_match', 'hepatic_severe', 'prior_tumor', 'peptic_ulcer', 'gvhd_proph', 'rheum_issue', 'sex_match', 'race_group', 'hepatic_mild', 'tce_div_match', 'donor_related', 'melphalan_dose', 'cardiac', 'pulm_moderate']
# fit(): torch.cuda.is_initialized()=True
# RTDL regressor
# [('epoch_timer', <skorch.callbacks.logging.EpochTimer object at 0x79285b197460>), ('train_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x79285b1973d0>), ('valid_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x79285b1967d0>), ('print_log', <skorch.callbacks.logging.PrintLog object at 0x79285b1966e0>)]
# Initializing UniquePrefixCheckpoint
# fn_prefix is 133214074981296
# self.category_embeddings.weight.shape=torch.Size([226, 192])
# A checkpoint was triggered in epoch 2.
#   epoch    constant_val_mse    train_loss    valid_loss    cp     dur
# -------  ------------------  ------------  ------------  ----  ------
#       1              1.0239        0.9176        0.9069     +  4.5127
# A checkpoint was triggered in epoch 3.
#       2              1.0239        0.8366        0.8607     +  4.5223
# A checkpoint was triggered in epoch 4.
#       3              1.0239        0.8229        0.8317     +  4.5515
#       4              1.0239        0.8126        0.8363        4.5243
# A checkpoint was triggered in epoch 6.
#       5              1.0239        0.8093        0.8194     +  4.5256
#       6              1.0239        0.8088        0.8277        4.5474
# A checkpoint was triggered in epoch 8.
#       7              1.0239        0.8038        0.8109     +  4.5540
# A checkpoint was triggered in epoch 9.
#       8              1.0239        0.7926        0.8055     +  4.5192
# A checkpoint was triggered in epoch 10.
#       9              1.0239        0.7938        0.8034     +  4.5253
#      10              1.0239        0.7912        0.8041        4.5226
# A checkpoint was triggered in epoch 12.
#      11              1.0239        0.7848        0.7979     +  4.5116
#      12              1.0239        0.7839        0.8122        4.5272
# A checkpoint was triggered in epoch 14.
#      13              1.0239        0.7810        0.7955     +  4.5417
#      14              1.0239        0.7780        0.8014        4.5281
# A checkpoint was triggered in epoch 16.
#      15              1.0239        0.7760        0.7938     +  4.5106
#      16              1.0239        0.7666        0.7968        4.5193
# A checkpoint was triggered in epoch 18.
#      17              1.0239        0.7621        0.7933     +  4.5245
#      18              1.0239        0.7578        0.8004        4.5286
# A checkpoint was triggered in epoch 20.
#      19              1.0239        0.7590        0.7888     +  4.4867
#      20              1.0239        0.7507        0.7974        4.5406
#      21              1.0239        0.7480        0.7975        4.5517
#      22              1.0239        0.7412        0.7952        4.5402
#      23              1.0239        0.7388        0.7977        4.5454
#      24              1.0239        0.7294        0.7948        4.5198
#      25              1.0239        0.7254        0.8059        4.5154
#      26              1.0239        0.7186        0.8058        4.5286
#      27              1.0239        0.7127        0.8088        4.5366
#      28              1.0239        0.7074        0.8167        4.5267
#      29              1.0239        0.6989        0.8091        4.5020
#      30              1.0239        0.6946        0.8098        4.5303
#      31              1.0239        0.6847        0.8155        4.5303
#      32              1.0239        0.6803        0.8171        4.5150
#      33              1.0239        0.6713        0.8353        4.5124
# train end
# Loading best checkpoint after training.
# removing ./rtdl_checkpoints/133214074981296params.pt
# fit(): torch.cuda.is_initialized()=True
# RTDL regressor
# [('epoch_timer', <skorch.callbacks.logging.EpochTimer object at 0x792850da3640>), ('train_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792850da0fd0>), ('valid_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792850da0670>), ('print_log', <skorch.callbacks.logging.PrintLog object at 0x792850da0ee0>)]
# Initializing UniquePrefixCheckpoint
# fn_prefix is 133214062124320
# self.category_embeddings.weight.shape=torch.Size([226, 192])
# A checkpoint was triggered in epoch 2.
#   epoch    constant_val_mse    train_loss    valid_loss    cp     dur
# -------  ------------------  ------------  ------------  ----  ------
#       1              1.0239        0.9261        0.8683     +  4.5384
# A checkpoint was triggered in epoch 3.
#       2              1.0239        0.8359        0.8419     +  4.5476
# A checkpoint was triggered in epoch 4.
#       3              1.0239        0.8217        0.8240     +  4.5299
# A checkpoint was triggered in epoch 5.
#       4              1.0239        0.8200        0.8236     +  4.5618
# A checkpoint was triggered in epoch 6.
#       5              1.0239        0.8104        0.8167     +  4.5503
#       6              1.0239        0.8021        0.8418        4.5495
#       7              1.0239        0.8034        0.8210        4.5328
#       8              1.0239        0.8011        0.8196        4.5184
#       9              1.0239        0.7951        0.8401        4.5522
# A checkpoint was triggered in epoch 11.
#      10              1.0239        0.7976        0.8030     +  4.5346
#      11              1.0239        0.7889        0.8511        4.5394
#      12              1.0239        0.7876        0.8074        4.5268
#      13              1.0239        0.7819        0.8058        4.5649
#      14              1.0239        0.7783        0.8383        4.5331
#      15              1.0239        0.7814        0.8208        4.5276
# A checkpoint was triggered in epoch 17.
#      16              1.0239        0.7718        0.8003     +  4.5385
# A checkpoint was triggered in epoch 18.
#      17              1.0239        0.7639        0.7920     +  4.5298
#      18              1.0239        0.7630        0.7938        4.5182
#      19              1.0239        0.7605        0.8239        4.5142
# A checkpoint was triggered in epoch 21.
#      20              1.0239        0.7543        0.7902     +  4.5329
#      21              1.0239        0.7486        0.7922        4.5378
#      22              1.0239        0.7457        0.7958        4.5524
#      23              1.0239        0.7371        0.8111        4.5205
#      24              1.0239        0.7364        0.7982        4.5331
#      25              1.0239        0.7286        0.8082        4.5162
#      26              1.0239        0.7214        0.8065        4.5339
#      27              1.0239        0.7200        0.8026        4.5595
#      28              1.0239        0.7117        0.8074        4.5217
#      29              1.0239        0.7064        0.8137        4.5316
#      30              1.0239        0.6982        0.8036        4.5148
#      31              1.0239        0.6901        0.8110        4.5213
#      32              1.0239        0.6804        0.8191        4.5307
#      33              1.0239        0.6755        0.8456        4.5218
#      34              1.0239        0.6650        0.8430        4.5308
# train end
# Loading best checkpoint after training.
# removing ./rtdl_checkpoints/133214062124320params.pt
# fit(): torch.cuda.is_initialized()=True
# RTDL regressor
# [('epoch_timer', <skorch.callbacks.logging.EpochTimer object at 0x7928519e5810>), ('train_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x7928519e62f0>), ('valid_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x7928519e6a70>), ('print_log', <skorch.callbacks.logging.PrintLog object at 0x7928519e6bf0>)]
# Initializing UniquePrefixCheckpoint
# fn_prefix is 133214074992288
# self.category_embeddings.weight.shape=torch.Size([226, 192])
# A checkpoint was triggered in epoch 2.
#   epoch    constant_val_mse    train_loss    valid_loss    cp     dur
# -------  ------------------  ------------  ------------  ----  ------
#       1              1.0239        0.9228        0.9198     +  4.5276
# A checkpoint was triggered in epoch 3.
#       2              1.0239        0.8438        0.8859     +  4.5466
# A checkpoint was triggered in epoch 4.
#       3              1.0239        0.8281        0.8480     +  4.5529
# A checkpoint was triggered in epoch 5.
#       4              1.0239        0.8138        0.8204     +  4.5570
#       5              1.0239        0.8137        0.8254        4.5270
# A checkpoint was triggered in epoch 7.
#       6              1.0239        0.8039        0.8157     +  4.5513
# A checkpoint was triggered in epoch 8.
#       7              1.0239        0.8028        0.8093     +  4.5579
#       8              1.0239        0.7995        0.8235        4.5570
# A checkpoint was triggered in epoch 10.
#       9              1.0239        0.7980        0.8051     +  4.5562
#      10              1.0239        0.7934        0.8065        4.5425
#      11              1.0239        0.7917        0.8055        4.5601
# A checkpoint was triggered in epoch 13.
#      12              1.0239        0.7856        0.8004     +  4.5449
#      13              1.0239        0.7853        0.8076        4.5762
#      14              1.0239        0.7809        0.8174        4.5293
# A checkpoint was triggered in epoch 16.
#      15              1.0239        0.7819        0.7974     +  4.5582
# A checkpoint was triggered in epoch 17.
#      16              1.0239        0.7688        0.7958     +  4.5499
#      17              1.0239        0.7674        0.7968        4.5503
# A checkpoint was triggered in epoch 19.
#      18              1.0239        0.7675        0.7956     +  4.5254
# A checkpoint was triggered in epoch 20.
#      19              1.0239        0.7584        0.7948     +  4.5420
#      20              1.0239        0.7518        0.7975        4.5567
#      21              1.0239        0.7507        0.7966        4.5332
#      22              1.0239        0.7408        0.8167        4.5608
#      23              1.0239        0.7430        0.8038        4.5311
#      24              1.0239        0.7315        0.8191        4.5578
#      25              1.0239        0.7309        0.7968        4.5329
#      26              1.0239        0.7211        0.8044        4.5371
#      27              1.0239        0.7137        0.8077        4.5568
#      28              1.0239        0.7084        0.8052        4.5209
#      29              1.0239        0.7072        0.8250        4.5284
#      30              1.0239        0.6995        0.8089        4.5393
#      31              1.0239        0.6948        0.8092        4.5335
#      32              1.0239        0.6826        0.8027        4.5346
#      33              1.0239        0.6802        0.8451        4.5327
# train end
# Loading best checkpoint after training.
# removing ./rtdl_checkpoints/133214074992288params.pt
# fit(): torch.cuda.is_initialized()=True
# RTDL regressor
# [('epoch_timer', <skorch.callbacks.logging.EpochTimer object at 0x792859986890>), ('train_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792859987490>), ('valid_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792859985390>), ('print_log', <skorch.callbacks.logging.PrintLog object at 0x792859986c50>)]
# Initializing UniquePrefixCheckpoint
# fn_prefix is 133214074989120
# ...
#      15              1.0044        0.7748        0.7899        4.5193
# A checkpoint was triggered in epoch 17.
#      16              1.0044        0.7719        0.7769     +  4.5260
# A checkpoint was triggered in epoch 18.
#      17              1.0044        0.7648        0.7700     +  4.5178
#      18              1.0044        0.7601        0.7912        4.5299
#      19              1.0044        0.7553        0.7907        4.4982
#      20              1.0044        0.7514        0.7786        4.5241
#      21              1.0044        0.7454        0.7912        4.4882
#      22              1.0044        0.7432        0.7786        4.4770
#      23              1.0044        0.7348        0.7852        4.5319
#      24              1.0044        0.7286        0.7906        4.4727
#      25              1.0044        0.7281        0.8012        4.4883
#      26              1.0044        0.7212        0.7991        4.4910
#      27              1.0044        0.7120        0.7884        4.5095
#      28              1.0044        0.7019        0.7935        4.4630
#      29              1.0044        0.6970        0.8071        4.5128
#      30              1.0044        0.6926        0.8094        4.5182
#      31              1.0044        0.6852        0.8118        4.5184
# train end
# Loading best checkpoint after training.
# removing ./rtdl_checkpoints/133214065702752params.pt
# fit(): torch.cuda.is_initialized()=True
# RTDL regressor
# [('epoch_timer', <skorch.callbacks.logging.EpochTimer object at 0x792851106320>), ('train_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792851105210>), ('valid_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792851106ef0>), ('print_log', <skorch.callbacks.logging.PrintLog object at 0x792851105db0>)]
# Initializing UniquePrefixCheckpoint
# fn_prefix is 133214065680176
# self.category_embeddings.weight.shape=torch.Size([226, 192])
# A checkpoint was triggered in epoch 2.
#   epoch    constant_val_mse    train_loss    valid_loss    cp     dur
# -------  ------------------  ------------  ------------  ----  ------
#       1              1.0044        0.9174        0.8207     +  4.5270
#       2              1.0044        0.8371        0.8531        4.5698
# A checkpoint was triggered in epoch 4.
#       3              1.0044        0.8244        0.7993     +  4.5402
#       4              1.0044        0.8190        0.8203        4.5444
# A checkpoint was triggered in epoch 6.
#       5              1.0044        0.8225        0.7936     +  4.5374
#       6              1.0044        0.8035        0.8099        4.5415
#       7              1.0044        0.8043        0.7996        4.5230
#       8              1.0044        0.8061        0.7979        4.5453
# A checkpoint was triggered in epoch 10.
#       9              1.0044        0.7989        0.7915     +  4.5196
#      10              1.0044        0.7958        0.7916        4.5094
#      11              1.0044        0.7912        0.8274        4.5151
# A checkpoint was triggered in epoch 13.
#      12              1.0044        0.7876        0.7815     +  4.5066
#      13              1.0044        0.7823        0.7880        4.5384
#      14              1.0044        0.7812        0.7853        4.5193
#      15              1.0044        0.7778        0.7840        4.5499
# A checkpoint was triggered in epoch 17.
#      16              1.0044        0.7755        0.7765     +  4.5513
# A checkpoint was triggered in epoch 18.
#      17              1.0044        0.7683        0.7658     +  4.5586
#      18              1.0044        0.7679        0.7736        4.5488
#      19              1.0044        0.7661        0.7700        4.5587
#      20              1.0044        0.7594        0.7674        4.5469
#      21              1.0044        0.7549        0.8023        4.5593
#      22              1.0044        0.7505        0.7730        4.5297
#      23              1.0044        0.7457        0.7664        4.5360
# A checkpoint was triggered in epoch 25.
#      24              1.0044        0.7425        0.7640     +  4.5144
#      25              1.0044        0.7353        0.7668        4.5158
#      26              1.0044        0.7283        0.7819        4.5139
#      27              1.0044        0.7262        0.7938        4.5027
#      28              1.0044        0.7188        0.7867        4.5303
#      29              1.0044        0.7112        0.8148        4.5237
#      30              1.0044        0.7139        0.7852        4.5155
#      31              1.0044        0.7008        0.7995        4.5042
#      32              1.0044        0.6962        0.7967        4.5135
#      33              1.0044        0.6938        0.7966        4.5449
#      34              1.0044        0.6763        0.8221        4.5619
#      35              1.0044        0.6704        0.8108        4.5578
#      36              1.0044        0.6574        0.8050        4.5718
#      37              1.0044        0.6511        0.7973        4.5578
#      38              1.0044        0.6463        0.8510        4.5082
# train end
# Loading best checkpoint after training.
# removing ./rtdl_checkpoints/133214065680176params.pt
# fit(): torch.cuda.is_initialized()=True
# RTDL regressor
# [('epoch_timer', <skorch.callbacks.logging.EpochTimer object at 0x79285110b7c0>), ('train_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x79285110a770>), ('valid_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x79285110b4c0>), ('print_log', <skorch.callbacks.logging.PrintLog object at 0x79285110a110>)]
# Initializing UniquePrefixCheckpoint
# fn_prefix is 133214065694016
# self.category_embeddings.weight.shape=torch.Size([226, 192])
# A checkpoint was triggered in epoch 2.
#   epoch    constant_val_mse    train_loss    valid_loss    cp     dur
# -------  ------------------  ------------  ------------  ----  ------
#       1              1.0044        0.9160        0.8547     +  4.5351
# A checkpoint was triggered in epoch 3.
#       2              1.0044        0.8483        0.8048     +  4.5466
# A checkpoint was triggered in epoch 4.
#       3              1.0044        0.8331        0.7992     +  4.5255
# A checkpoint was triggered in epoch 5.
#       4              1.0044        0.8184        0.7902     +  4.5371
#       5              1.0044        0.8133        0.7967        4.5429
# A checkpoint was triggered in epoch 7.
#       6              1.0044        0.8126        0.7887     +  4.5308
#       7              1.0044        0.8073        0.7948        4.5249
#       8              1.0044        0.8015        0.7971        4.5236
# A checkpoint was triggered in epoch 10.
#       9              1.0044        0.7983        0.7856     +  4.5283
#      10              1.0044        0.7961        0.7949        4.5236
#      11              1.0044        0.7924        0.7952        4.5521
#      12              1.0044        0.7914        0.8024        4.5232
#      13              1.0044        0.7857        0.7968        4.5592
# A checkpoint was triggered in epoch 15.
#      14              1.0044        0.7838        0.7719     +  4.5435
#      15              1.0044        0.7804        0.7774        4.5480
#      16              1.0044        0.7774        0.7851        4.5351
#      17              1.0044        0.7722        0.7753        4.5546
# A checkpoint was triggered in epoch 19.
#      18              1.0044        0.7720        0.7713     +  4.5768
#      19              1.0044        0.7617        0.7885        4.5475
#      20              1.0044        0.7572        0.7940        4.5611
# A checkpoint was triggered in epoch 22.
#      21              1.0044        0.7543        0.7701     +  4.5719
# A checkpoint was triggered in epoch 23.
#      22              1.0044        0.7504        0.7690     +  4.5688
# A checkpoint was triggered in epoch 24.
#      23              1.0044        0.7442        0.7631     +  4.5584
#      24              1.0044        0.7348        0.7797        4.5712
#      25              1.0044        0.7330        0.7852        4.5653
#      26              1.0044        0.7271        0.7748        4.5578
#      27              1.0044        0.7209        0.7853        4.5592
#      28              1.0044        0.7128        0.8104        4.5553
#      29              1.0044        0.7056        0.7820        4.5488
#      30              1.0044        0.6998        0.7877        4.5874
#      31              1.0044        0.6940        0.8300        4.5483
#      32              1.0044        0.6822        0.8003        4.5362
#      33              1.0044        0.6752        0.7969        4.5514
#      34              1.0044        0.6697        0.8073        4.5540
#      35              1.0044        0.6611        0.8248        4.5372
#      36              1.0044        0.6543        0.8593        4.5443
#      37              1.0044        0.6442        0.8450        4.5562
# train end
# Loading best checkpoint after training.
# removing ./rtdl_checkpoints/133214065694016params.pt
# fit(): torch.cuda.is_initialized()=True
# RTDL regressor
# [('epoch_timer', <skorch.callbacks.logging.EpochTimer object at 0x79285110af80>), ('train_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x79285110a530>), ('valid_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x79285110b5b0>), ('print_log', <skorch.callbacks.logging.PrintLog object at 0x79285110aef0>)]
# Initializing UniquePrefixCheckpoint
# fn_prefix is 133214065679360
# self.category_embeddings.weight.shape=torch.Size([226, 192])
# A checkpoint was triggered in epoch 2.
#   epoch    constant_val_mse    train_loss    valid_loss    cp     dur
# -------  ------------------  ------------  ------------  ----  ------
#       1              1.0044        0.9321        0.8562     +  4.5538
# A checkpoint was triggered in epoch 3.
#       2              1.0044        0.8487        0.8055     +  4.5115
# A checkpoint was triggered in epoch 4.
#       3              1.0044        0.8308        0.7965     +  4.5265
#       4              1.0044        0.8196        0.8036        4.5242
#       5              1.0044        0.8127        0.7970        4.5007
# A checkpoint was triggered in epoch 7.
#       6              1.0044        0.8106        0.7877     +  4.5423
#       7              1.0044        0.8015        0.7878        4.5355
#       8              1.0044        0.8010        0.8041        4.5602
#       9              1.0044        0.7962        0.7898        4.5409
#      10              1.0044        0.7925        0.8245        4.5460
#      11              1.0044        0.7968        0.7899        4.5324
#      12              1.0044        0.7869        0.8009        4.5218
# A checkpoint was triggered in epoch 14.
#      13              1.0044        0.7820        0.7868     +  4.5298
#      14              1.0044        0.7846        0.7934        4.5283
# A checkpoint was triggered in epoch 16.
#      15              1.0044        0.7766        0.7857     +  4.5580
# A checkpoint was triggered in epoch 17.
#      16              1.0044        0.7714        0.7819     +  4.5403
# A checkpoint was triggered in epoch 18.
#      17              1.0044        0.7680        0.7714     +  4.5134
#      18              1.0044        0.7618        0.7733        4.5295
#      19              1.0044        0.7608        0.7800        4.5273
#      20              1.0044        0.7560        0.7808        4.5312
#      21              1.0044        0.7530        0.7861        4.5330
#      22              1.0044        0.7453        0.7814        4.5594
#      23              1.0044        0.7402        0.7917        4.5165
#      24              1.0044        0.7332        0.7829        4.5258
#      25              1.0044        0.7303        0.8282        4.5307
#      26              1.0044        0.7234        0.7830        4.5357
#      27              1.0044        0.7216        0.7933        4.5322
#      28              1.0044        0.7172        0.7851        4.5534
#      29              1.0044        0.7026        0.7954        4.5316
#      30              1.0044        0.6991        0.8008        4.5398
#      31              1.0044        0.6902        0.8073        4.5182
# train end
# Loading best checkpoint after training.
# removing ./rtdl_checkpoints/133214065679360params.pt
# fit(): torch.cuda.is_initialized()=True
# RTDL regressor
# [('epoch_timer', <skorch.callbacks.logging.EpochTimer object at 0x79285193cd30>), ('train_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792851108a90>), ('valid_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x79285110b610>), ('print_log', <skorch.callbacks.logging.PrintLog object at 0x792851109b70>)]
# Initializing UniquePrefixCheckpoint
# fn_prefix is 133214065690176
# self.category_embeddings.weight.shape=torch.Size([226, 192])
# A checkpoint was triggered in epoch 2.
#   epoch    constant_val_mse    train_loss    valid_loss    cp     dur
# -------  ------------------  ------------  ------------  ----  ------
#       1              1.0044        0.9265        0.8239     +  4.5388
# A checkpoint was triggered in epoch 3.
#       2              1.0044        0.8463        0.8071     +  4.5344
#       3              1.0044        0.8292        0.8182        4.5536
# A checkpoint was triggered in epoch 5.
#       4              1.0044        0.8125        0.7992     +  4.5446
#       5              1.0044        0.8102        0.8159        4.5396
# A checkpoint was triggered in epoch 7.
#       6              1.0044        0.8082        0.7900     +  4.5210
#       7              1.0044        0.8054        0.7926        4.5417
#       8              1.0044        0.8007        0.8211        4.5570
# A checkpoint was triggered in epoch 10.
#       9              1.0044        0.7939        0.7863     +  4.5459
# A checkpoint was triggered in epoch 11.
#      10              1.0044        0.7851        0.7816     +  4.5647
# A checkpoint was triggered in epoch 12.
#      11              1.0044        0.7825        0.7793     +  4.5461
#      12              1.0044        0.7875        0.7996        4.5510
# A checkpoint was triggered in epoch 14.
#      13              1.0044        0.7761        0.7735     +  4.5351
#      14              1.0044        0.7714        0.7780        4.5163
# A checkpoint was triggered in epoch 16.
#      15              1.0044        0.7697        0.7726     +  4.5388
#      16              1.0044        0.7654        0.7761        4.5468
#      17              1.0044        0.7593        0.7740        4.5601
# A checkpoint was triggered in epoch 19.
#      18              1.0044        0.7542        0.7716     +  4.5242
#      19              1.0044        0.7517        0.7755        4.5492
#      20              1.0044        0.7445        0.7769        4.5468
#      21              1.0044        0.7381        0.7756        4.5163
# A checkpoint was triggered in epoch 23.
#      22              1.0044        0.7401        0.7712     +  4.5472
#      23              1.0044        0.7281        0.7742        4.5567
#      24              1.0044        0.7268        0.7931        4.5769
#      25              1.0044        0.7194        0.7729        4.5585
#      26              1.0044        0.7140        0.7803        4.5480
#      27              1.0044        0.7036        0.8003        4.5450
#      28              1.0044        0.7014        0.8001        4.5266
#      29              1.0044        0.6935        0.7982        4.5541
#      30              1.0044        0.6805        0.8190        4.5309
#      31              1.0044        0.6722        0.8147        4.5693
#      32              1.0044        0.6686        0.8049        4.5457
#      33              1.0044        0.6636        0.8240        4.5396
#      34              1.0044        0.6520        0.8340        4.5206
#      35              1.0044        0.6471        0.8495        4.5584
#      36              1.0044        0.6358        0.8298        4.5500
# train end
# Loading best checkpoint after training.
# removing ./rtdl_checkpoints/133214065690176params.pt
# CPU times: user 2h 7min 4s, sys: 17.4 s, total: 2h 7min 22s
# Wall time: 2h 7min 29s

# %%
y_true = train[["ID", "efs", "efs_time", "race_group"]].copy()
y_pred = train[["ID"]].copy()
y_pred["prediction"] = oof_ftt
m_ftt = score(y_true.copy(), y_pred.copy(), "ID")
print(f"\nOverall CV for ftt KaplanMeier = ", m_ftt) # 0.6680354797728337
# Out:
# Overall CV for ftt KaplanMeier =  0.6734988161252538

# %%
# %%time
FOLDS = 10
kf = KFold(n_splits=FOLDS, shuffle=True, random_state=52)
    
oof_mlpprl = np.zeros(len(train))
pred_mlpprl = np.zeros(len(test))

for i, (train_index, test_index) in enumerate(kf.split(train)):
    print("#" * 25)
    print(f"### Fold {i + 1}")
    print("#" * 25)
    
    X_train = train.loc[train_index, FEATURES].copy()
    y_train = train.loc[train_index, "y"]
    X_valid = train.loc[test_index, FEATURES].copy()
    y_valid = train.loc[test_index, "y"]
    X_test = test[FEATURES].copy()

    model_mlpprl = MLP_PLR_D_Regressor(
        n_cv=5,
        lr=0.0001,
        max_epochs=100,
        es_patience=20,
        random_state=52, 
        verbosity=2
    )
    model_mlpprl.fit(
        X_train, y_train,
        X_valid, y_valid
    )
    os.makedirs('/kaggle/working/mlpprl', exist_ok=True)
    joblib.dump(model_mlpprl, f'/kaggle/working/mlpprl/mlpprl_fold_{i}.pkl')

    oof_mlpprl[test_index] = model_mlpprl.predict(X_valid)
    pred_mlpprl += model_mlpprl.predict(X_test)

pred_mlpprl /= FOLDS
# Out:
# #########################
# ### Fold 1
# #########################
# Columns classified as continuous: ['hla_match_c_high', 'hla_high_res_8', 'hla_low_res_6', 'hla_high_res_6', 'hla_high_res_10', 'hla_match_dqb1_high', 'hla_nmdp_6', 'hla_match_c_low', 'hla_match_drb1_low', 'hla_match_dqb1_low', 'year_hct', 'hla_match_a_high', 'donor_age', 'hla_match_b_low', 'age_at_hct', 'hla_match_a_low', 'hla_match_b_high', 'comorbidity_score', 'karnofsky_score', 'hla_low_res_8', 'hla_match_drb1_high', 'hla_low_res_10']
# Columns classified as categorical: ['dri_score', 'psych_disturb', 'cyto_score', 'diabetes', 'tbi_status', 'arrhythmia', 'graft_type', 'vent_hist', 'renal_issue', 'pulm_severe', 'prim_disease_hct', 'cmv_status', 'tce_imm_match', 'rituximab', 'prod_type', 'cyto_score_detail', 'conditioning_intensity', 'ethnicity', 'obesity', 'mrd_hct', 'in_vivo_tcd', 'tce_match', 'hepatic_severe', 'prior_tumor', 'peptic_ulcer', 'gvhd_proph', 'rheum_issue', 'sex_match', 'race_group', 'hepatic_mild', 'tce_div_match', 'donor_related', 'melphalan_dose', 'cardiac', 'pulm_moderate']
# fit(): torch.cuda.is_initialized()=True
# RTDL regressor
# [('epoch_timer', <skorch.callbacks.logging.EpochTimer object at 0x792850d04bb0>), ('train_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792850d05bd0>), ('valid_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792850d04850>), ('print_log', <skorch.callbacks.logging.PrintLog object at 0x792850d053f0>)]
# Initializing UniquePrefixCheckpoint
# fn_prefix is 133214061493840
# A checkpoint was triggered in epoch 2.
#   epoch    constant_val_mse    train_loss    valid_loss    cp     dur
# -------  ------------------  ------------  ------------  ----  ------
#       1              0.9915        0.9609        0.8964     +  1.4373
# A checkpoint was triggered in epoch 3.
#       2              0.9915        0.8766        0.8371     +  1.4152
# A checkpoint was triggered in epoch 4.
#       3              0.9915        0.8511        0.8180     +  1.4203
# A checkpoint was triggered in epoch 5.
#       4              0.9915        0.8391        0.8134     +  1.4562
# A checkpoint was triggered in epoch 6.
#       5              0.9915        0.8345        0.8093     +  1.4123
#       6              0.9915        0.8210        0.8099        1.4072
# A checkpoint was triggered in epoch 8.
#       7              0.9915        0.8172        0.8013     +  1.4067
#       8              0.9915        0.8137        0.8035        1.4153
# A checkpoint was triggered in epoch 10.
#       9              0.9915        0.8069        0.7966     +  1.4088
# A checkpoint was triggered in epoch 11.
#      10              0.9915        0.8036        0.7945     +  1.4142
# A checkpoint was triggered in epoch 12.
#      11              0.9915        0.7987        0.7926     +  1.4584
#      12              0.9915        0.7934        0.8101        1.4339
# A checkpoint was triggered in epoch 14.
#      13              0.9915        0.7901        0.7902     +  1.4280
#      14              0.9915        0.7834        0.7928        1.4457
#      15              0.9915        0.7800        0.7913        1.4354
# A checkpoint was triggered in epoch 17.
#      16              0.9915        0.7710        0.7861     +  1.4208
#      17              0.9915        0.7704        0.7889        1.4069
#      18              0.9915        0.7644        0.7896        1.4631
#      19              0.9915        0.7591        0.7870        1.4717
#      20              0.9915        0.7525        0.7920        1.4576
#      21              0.9915        0.7474        0.7903        1.4996
#      22              0.9915        0.7450        0.7999        1.5115
#      23              0.9915        0.7401        0.7883        1.4304
#      24              0.9915        0.7331        0.8030        1.4179
#      25              0.9915        0.7264        0.7914        1.4502
#      26              0.9915        0.7213        0.7997        1.4244
#      27              0.9915        0.7155        0.7958        1.4117
#      28              0.9915        0.7102        0.8098        1.4151
#      29              0.9915        0.6996        0.8080        1.4193
#      30              0.9915        0.6951        0.8015        1.4301
#      31              0.9915        0.6880        0.8006        1.4071
#      32              0.9915        0.6822        0.8089        1.4964
#      33              0.9915        0.6749        0.8124        1.4271
#      34              0.9915        0.6665        0.8182        1.4150
#      35              0.9915        0.6596        0.8179        1.4221
# train end
# Loading best checkpoint after training.
# removing ./rtdl_checkpoints/133214061493840params.pt
# fit(): torch.cuda.is_initialized()=True
# RTDL regressor
# [('epoch_timer', <skorch.callbacks.logging.EpochTimer object at 0x792851104c70>), ('train_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792851107010>), ('valid_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792851105ed0>), ('print_log', <skorch.callbacks.logging.PrintLog object at 0x792851106ad0>)]
# Initializing UniquePrefixCheckpoint
# fn_prefix is 133214234067056
# A checkpoint was triggered in epoch 2.
#   epoch    constant_val_mse    train_loss    valid_loss    cp     dur
# -------  ------------------  ------------  ------------  ----  ------
#       1              0.9915        0.9572        0.8735     +  1.4013
# A checkpoint was triggered in epoch 3.
#       2              0.9915        0.8694        0.8424     +  1.3958
# A checkpoint was triggered in epoch 4.
#       3              0.9915        0.8455        0.8166     +  1.4173
# A checkpoint was triggered in epoch 5.
#       4              0.9915        0.8342        0.8104     +  1.4141
# A checkpoint was triggered in epoch 6.
#       5              0.9915        0.8248        0.8051     +  1.3999
# A checkpoint was triggered in epoch 7.
#       6              0.9915        0.8199        0.8007     +  1.4251
#       7              0.9915        0.8146        0.8008        1.6320
#       8              0.9915        0.8082        0.8009        1.4124
# A checkpoint was triggered in epoch 10.
#       9              0.9915        0.8031        0.7979     +  1.4387
# A checkpoint was triggered in epoch 11.
#      10              0.9915        0.7998        0.7952     +  1.4550
# A checkpoint was triggered in epoch 12.
#      11              0.9915        0.7948        0.7928     +  1.4522
# A checkpoint was triggered in epoch 13.
#      12              0.9915        0.7909        0.7922     +  1.4469
# A checkpoint was triggered in epoch 14.
#      13              0.9915        0.7861        0.7917     +  1.4377
# A checkpoint was triggered in epoch 15.
#      14              0.9915        0.7835        0.7889     +  1.4566
#      15              0.9915        0.7784        0.7973        1.4561
#      16              0.9915        0.7740        0.7903        1.4624
#      17              0.9915        0.7689        0.7931        1.4191
# A checkpoint was triggered in epoch 19.
#      18              0.9915        0.7657        0.7873     +  1.4495
#      19              0.9915        0.7617        0.7981        1.4245
# A checkpoint was triggered in epoch 21.
#      20              0.9915        0.7560        0.7858     +  1.4311
#      21              0.9915        0.7522        0.7876        1.4320
#      22              0.9915        0.7456        0.7922        1.4323
#      23              0.9915        0.7465        0.7913        1.4318
#      24              0.9915        0.7399        0.7925        1.4276
#      25              0.9915        0.7307        0.7934        1.4255
#      26              0.9915        0.7259        0.7926        1.4215
#      27              0.9915        0.7202        0.7966        1.4157
#      28              0.9915        0.7147        0.8018        1.4597
#      29              0.9915        0.7123        0.7992        1.4837
#      30              0.9915        0.7032        0.7995        1.4691
#      31              0.9915        0.6986        0.8097        1.4122
#      32              0.9915        0.6946        0.8134        1.4062
#      33              0.9915        0.6859        0.8116        1.4173
#      34              0.9915        0.6800        0.8138        1.4569
#      35              0.9915        0.6695        0.8256        1.4173
#      36              0.9915        0.6652        0.8169        1.4194
#      37              0.9915        0.6581        0.8230        1.4529
#      38              0.9915        0.6548        0.8336        1.4174
#      39              0.9915        0.6464        0.8237        1.4339
# train end
# Loading best checkpoint after training.
# removing ./rtdl_checkpoints/133214234067056params.pt
# fit(): torch.cuda.is_initialized()=True
# RTDL regressor
# [('epoch_timer', <skorch.callbacks.logging.EpochTimer object at 0x79285110b640>), ('train_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792851108580>), ('valid_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792851108d30>), ('print_log', <skorch.callbacks.logging.PrintLog object at 0x7928511084c0>)]
# Initializing UniquePrefixCheckpoint
# fn_prefix is 133214065692816
# A checkpoint was triggered in epoch 2.
#   epoch    constant_val_mse    train_loss    valid_loss    cp     dur
# -------  ------------------  ------------  ------------  ----  ------
#       1              0.9915        0.9652        0.8849     +  1.4301
# A checkpoint was triggered in epoch 3.
#       2              0.9915        0.8800        0.8562     +  1.4197
# A checkpoint was triggered in epoch 4.
#       3              0.9915        0.8532        0.8252     +  1.3956
# A checkpoint was triggered in epoch 5.
#       4              0.9915        0.8384        0.8130     +  1.4496
# A checkpoint was triggered in epoch 6.
#       5              0.9915        0.8336        0.8099     +  1.4091
# A checkpoint was triggered in epoch 7.
#       6              0.9915        0.8263        0.8056     +  1.4251
# A checkpoint was triggered in epoch 8.
#       7              0.9915        0.8199        0.8011     +  1.4229
#       8              0.9915        0.8142        0.8041        1.4191
# A checkpoint was triggered in epoch 10.
#       9              0.9915        0.8090        0.7981     +  1.4394
# A checkpoint was triggered in epoch 11.
#      10              0.9915        0.8052        0.7944     +  1.5168
#      11              0.9915        0.8005        0.8020        1.5623
# A checkpoint was triggered in epoch 13.
#      12              0.9915        0.7952        0.7924     +  1.4314
#      13              0.9915        0.7915        0.7935        1.4220
# A checkpoint was triggered in epoch 15.
#      14              0.9915        0.7861        0.7891     +  1.4394
#      15              0.9915        0.7839        0.7962        1.4135
#      16              0.9915        0.7811        0.7898        1.4061
# A checkpoint was triggered in epoch 18.
#      17              0.9915        0.7739        0.7891     +  1.4075
# train end
# Loading best checkpoint after training.
# removing ./rtdl_checkpoints/133214234067536params.pt
# fit(): torch.cuda.is_initialized()=True
# RTDL regressor
# [('epoch_timer', <skorch.callbacks.logging.EpochTimer object at 0x79285193f700>), ('train_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x79285193f520>), ('valid_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x79285193efe0>), ('print_log', <skorch.callbacks.logging.PrintLog object at 0x79285193d000>)]
# Initializing UniquePrefixCheckpoint
# fn_prefix is 133214065696224
# A checkpoint was triggered in epoch 2.
#   epoch    constant_val_mse    train_loss    valid_loss    cp     dur
# -------  ------------------  ------------  ------------  ----  ------
#       1              0.9915        0.9558        0.8691     +  1.4625
# A checkpoint was triggered in epoch 3.
#       2              0.9915        0.8726        0.8375     +  1.4039
# A checkpoint was triggered in epoch 4.
#       3              0.9915        0.8490        0.8169     +  1.4120
# A checkpoint was triggered in epoch 5.
#       4              0.9915        0.8376        0.8069     +  1.4145
# A checkpoint was triggered in epoch 6.
#       5              0.9915        0.8306        0.8050     +  1.4499
#       6              0.9915        0.8239        0.8070        1.4204
# A checkpoint was triggered in epoch 8.
#       7              0.9915        0.8162        0.8015     +  1.4196
# A checkpoint was triggered in epoch 9.
#       8              0.9915        0.8101        0.7969     +  1.4217
#       9              0.9915        0.8089        0.8070        1.4272
#      10              0.9915        0.8039        0.7991        1.4251
# A checkpoint was triggered in epoch 12.
#      11              0.9915        0.7981        0.7926     +  1.4215
#      12              0.9915        0.7953        0.8035        1.4494
#      13              0.9915        0.7936        0.7962        1.4173
# A checkpoint was triggered in epoch 15.
#      14              0.9915        0.7871        0.7871     +  1.4075
#      15              0.9915        0.7834        0.7904        1.4224
#      16              0.9915        0.7802        0.7951        1.4446
#      17              0.9915        0.7744        0.7879        1.4346
#      18              0.9915        0.7689        0.7901        1.4267
# A checkpoint was triggered in epoch 20.
#      19              0.9915        0.7671        0.7870     +  1.4294
#      20              0.9915        0.7613        0.7880        1.4096
#      21              0.9915        0.7594        0.7891        1.4093
#      22              0.9915        0.7512        0.7912        1.4032
#      23              0.9915        0.7478        0.7951        1.5158
#      24              0.9915        0.7411        0.7921        1.5428
# A checkpoint was triggered in epoch 26.
#      25              0.9915        0.7347        0.7863     +  1.4005
#      26              0.9915        0.7272        0.7946        1.4499
#      27              0.9915        0.7227        0.7940        1.4148
#      28              0.9915        0.7163        0.7934        1.4074
#      29              0.9915        0.7092        0.7897        1.4046
#      30              0.9915        0.7008        0.7988        1.4039
#      31              0.9915        0.6990        0.7985        1.4106
#      32              0.9915        0.6902        0.7976        1.4004
#      33              0.9915        0.6824        0.8071        1.4412
#      34              0.9915        0.6784        0.8110        1.4069
#      35              0.9915        0.6730        0.8058        1.4177
#      36              0.9915        0.6668        0.8059        1.4089
#      37              0.9915        0.6599        0.8107        1.4122
#      38              0.9915        0.6517        0.8346        1.4396
#      39              0.9915        0.6464        0.8202        1.4079
#      40              0.9915        0.6370        0.8509        1.4290
#      41              0.9915        0.6306        0.8327        1.4257
#      42              0.9915        0.6291        0.8226        1.4242
#      43              0.9915        0.6225        0.8686        1.4060
#      44              0.9915        0.6143        0.8491        1.4287
# train end
# Loading best checkpoint after training.
# removing ./rtdl_checkpoints/133214065696224params.pt
# #########################
# ### Fold 2
# #########################
# Columns classified as continuous: ['hla_match_c_high', 'hla_high_res_8', 'hla_low_res_6', 'hla_high_res_6', 'hla_high_res_10', 'hla_match_dqb1_high', 'hla_nmdp_6', 'hla_match_c_low', 'hla_match_drb1_low', 'hla_match_dqb1_low', 'year_hct', 'hla_match_a_high', 'donor_age', 'hla_match_b_low', 'age_at_hct', 'hla_match_a_low', 'hla_match_b_high', 'comorbidity_score', 'karnofsky_score', 'hla_low_res_8', 'hla_match_drb1_high', 'hla_low_res_10']
# Columns classified as categorical: ['dri_score', 'psych_disturb', 'cyto_score', 'diabetes', 'tbi_status', 'arrhythmia', 'graft_type', 'vent_hist', 'renal_issue', 'pulm_severe', 'prim_disease_hct', 'cmv_status', 'tce_imm_match', 'rituximab', 'prod_type', 'cyto_score_detail', 'conditioning_intensity', 'ethnicity', 'obesity', 'mrd_hct', 'in_vivo_tcd', 'tce_match', 'hepatic_severe', 'prior_tumor', 'peptic_ulcer', 'gvhd_proph', 'rheum_issue', 'sex_match', 'race_group', 'hepatic_mild', 'tce_div_match', 'donor_related', 'melphalan_dose', 'cardiac', 'pulm_moderate']
# fit(): torch.cuda.is_initialized()=True
# RTDL regressor
# [('epoch_timer', <skorch.callbacks.logging.EpochTimer object at 0x79285110a830>), ('train_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792851125030>), ('valid_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792851127610>), ('print_log', <skorch.callbacks.logging.PrintLog object at 0x792851127100>)]
# Initializing UniquePrefixCheckpoint
# fn_prefix is 133214065691952
# A checkpoint was triggered in epoch 2.
#   epoch    constant_val_mse    train_loss    valid_loss    cp     dur
# -------  ------------------  ------------  ------------  ----  ------
#       1              0.9712        0.9599        0.8506     +  1.4044
# A checkpoint was triggered in epoch 3.
#       2              0.9712        0.8747        0.8251     +  1.4170
# A checkpoint was triggered in epoch 4.
#       3              0.9712        0.8543        0.8168     +  1.4029
# A checkpoint was triggered in epoch 5.
#       4              0.9712        0.8445        0.8118     +  1.3937
# A checkpoint was triggered in epoch 6.
#       5              0.9712        0.8329        0.8043     +  1.4209
# A checkpoint was triggered in epoch 7.
#       6              0.9712        0.8269        0.8024     +  1.4009
# A checkpoint was triggered in epoch 8.
#       7              0.9712        0.8220        0.8017     +  1.4314
# A checkpoint was triggered in epoch 9.
#       8              0.9712        0.8148        0.7919     +  1.4184
# A checkpoint was triggered in epoch 10.
#       9              0.9712        0.8077        0.7915     +  1.3988
# A checkpoint was triggered in epoch 11.
#      10              0.9712        0.8051        0.7868     +  1.4008
# A checkpoint was triggered in epoch 12.
#      11              0.9712        0.8011        0.7865     +  1.4250
#      12              0.9712        0.7971        0.7910        1.4429
# A checkpoint was triggered in epoch 14.
#      13              0.9712        0.7899        0.7850     +  1.4329
#      14              0.9712        0.7852        0.7856        1.4850
# A checkpoint was triggered in epoch 16.
#      15              0.9712        0.7816        0.7813     +  1.4205
#      16              0.9712        0.7732        0.7837        1.4045
#      17              0.9712        0.7688        0.7820        1.4260
# A checkpoint was triggered in epoch 19.
#      18              0.9712        0.7650        0.7773     +  1.4290
#      19              0.9712        0.7580        0.7775        1.4105
#      20              0.9712        0.7524        0.7791        1.4124
#      21              0.9712        0.7451        0.7848        1.5477
#      22              0.9712        0.7380        0.7850        1.4152
#      23              0.9712        0.7325        0.7924        1.4358
#      24              0.9712        0.7279        0.7877        1.4376
#      25              0.9712        0.7200        0.7901        1.4220
#      26              0.9712        0.7177        0.7939        1.4258
#      27              0.9712        0.7089        0.7993        1.4143
#      28              0.9712        0.7027        0.8012        1.4465
#      29              0.9712        0.6963        0.8269        1.4120
#      30              0.9712        0.6915        0.8056        1.4192
#      31              0.9712        0.6850        0.8025        1.4184
#      32              0.9712        0.6762        0.8111        1.3976
#      33              0.9712        0.6737        0.8096        1.3966
#      34              0.9712        0.6649        0.8089        1.4128
#      35              0.9712        0.6650        0.8139        1.4474
#      36              0.9712        0.6517        0.8299        1.4283
#      37              0.9712        0.6453        0.8214        1.4621
# train end
# Loading best checkpoint after training.
# removing ./rtdl_checkpoints/133214065691952params.pt
# fit(): torch.cuda.is_initialized()=True
# RTDL regressor
# [('epoch_timer', <skorch.callbacks.logging.EpochTimer object at 0x7928511759f0>), ('train_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792851175780>), ('valid_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792851175c90>), ('print_log', <skorch.callbacks.logging.PrintLog object at 0x7928511746d0>)]
# Initializing UniquePrefixCheckpoint
# fn_prefix is 133214065692960
# A checkpoint was triggered in epoch 2.
#   epoch    constant_val_mse    train_loss    valid_loss    cp     dur
# -------  ------------------  ------------  ------------  ----  ------
#       1              0.9712        0.9514        0.8462     +  1.4311
# A checkpoint was triggered in epoch 3.
#       2              0.9712        0.8661        0.8199     +  1.4314
# A checkpoint was triggered in epoch 4.
#       3              0.9712        0.8483        0.8115     +  1.3897
# A checkpoint was triggered in epoch 5.
#       4              0.9712        0.8359        0.8036     +  1.4719
#       5              0.9712        0.8301        0.8238        1.4882
# A checkpoint was triggered in epoch 7.
#       6              0.9712        0.8221        0.7991     +  1.4226
# A checkpoint was triggered in epoch 8.
#       7              0.9712        0.8129        0.7890     +  1.4029
# A checkpoint was triggered in epoch 9.
#       8              0.9712        0.8072        0.7888     +  1.4163
# A checkpoint was triggered in epoch 10.
#       9              0.9712        0.8010        0.7879     +  1.4072
# A checkpoint was triggered in epoch 11.
#      10              0.9712        0.7960        0.7817     +  1.4184
# A checkpoint was triggered in epoch 12.
#      11              0.9712        0.7927        0.7799     +  1.4349
#      12              0.9712        0.7875        0.7828        1.4152
#      13              0.9712        0.7831        0.7834        1.4180
#      14              0.9712        0.7767        0.7889        1.3949
#      15              0.9712        0.7739        0.7834        1.4005
#      16              0.9712        0.7677        0.7823        1.4157
#      17              0.9712        0.7622        0.7853        1.3970
#      18              0.9712        0.7614        0.7811        1.4446
#      19              0.9712        0.7527        0.7845        1.4181
#      20              0.9712        0.7470        0.7840        1.4044
#      21              0.9712        0.7420        0.7844        1.4252
#      22              0.9712        0.7385        0.7875        1.4270
# A checkpoint was triggered in epoch 24.
#      23              0.9712        0.7309        0.7785     +  1.4432
#      24              0.9712        0.7247        0.7840        1.4174
#      25              0.9712        0.7203        0.7880        1.4537
#      26              0.9712        0.7125        0.7905        1.4602
#      27              0.9712        0.7072        0.7969        1.4658
#      28              0.9712        0.6978        0.8005        1.4292
#      29              0.9712        0.6908        0.7972        1.4244
#      30              0.9712        0.6861        0.7978        1.4079
#      31              0.9712        0.6780        0.7980        1.4098
#      32              0.9712        0.6744        0.8043        1.4483
#      33              0.9712        0.6679        0.8051        1.4315
#      34              0.9712        0.6579        0.8195        1.4095
#      35              0.9712        0.6562        0.8125        1.3909
#      36              0.9712        0.6429        0.8137        1.4039
#      37              0.9712        0.6350        0.8186        1.4104
#      38              0.9712        0.6320        0.8242        1.4141
#      39              0.9712        0.6294        0.8227        1.4314
#      40              0.9712        0.6172        0.8279        1.3930
#      41              0.9712        0.6115        0.8287        1.3905
#      42              0.9712        0.6079        0.8395        1.4154
# train end
# Loading best checkpoint after training.
# removing ./rtdl_checkpoints/133214065692960params.pt
# fit(): torch.cuda.is_initialized()=True
# RTDL regressor
# [('epoch_timer', <skorch.callbacks.logging.EpochTimer object at 0x792851176650>), ('train_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792851175b10>), ('valid_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x7928511743a0>), ('print_log', <skorch.callbacks.logging.PrintLog object at 0x7928511764a0>)]
# Initializing UniquePrefixCheckpoint
# fn_prefix is 133214066136000
# A checkpoint was triggered in epoch 2.
#   epoch    constant_val_mse    train_loss    valid_loss    cp     dur
# -------  ------------------  ------------  ------------  ----  ------
#       1              0.9712        0.9583        0.8477     +  1.3990
# A checkpoint was triggered in epoch 3.
#       2              0.9712        0.8720        0.8272     +  1.3803
# A checkpoint was triggered in epoch 4.
#       3              0.9712        0.8540        0.8194     +  1.4668
# A checkpoint was triggered in epoch 5.
#       4              0.9712        0.8432        0.8166     +  1.3949
# A checkpoint was triggered in epoch 6.
#       5              0.9712        0.8352        0.8075     +  1.4793
# A checkpoint was triggered in epoch 7.
#       6              0.9712        0.8275        0.8021     +  1.4611
#       7              0.9712        0.8223        0.8147        1.3965
# A checkpoint was triggered in epoch 9.
#       8              0.9712        0.8164        0.7978     +  1.4056
# A checkpoint was triggered in epoch 10.
#       9              0.9712        0.8132        0.7925     +  1.3931
# A checkpoint was triggered in epoch 11.
#      10              0.9712        0.8056        0.7908     +  1.4345
#      11              0.9712        0.8000        0.7910        1.3943
# A checkpoint was triggered in epoch 13.
#      12              0.9712        0.7954        0.7884     +  1.4075
#      13              0.9712        0.7935        0.7951        1.4030
# A checkpoint was triggered in epoch 15.
#      14              0.9712        0.7911        0.7838     +  1.4252
# A checkpoint was triggered in epoch 16.
#      15              0.9712        0.7841        0.7812     +  1.3865
#      16              0.9712        0.7811        0.7841        1.4331
#      17              0.9712        0.7756        0.7858        1.4208
# A checkpoint was triggered in epoch 19.
#      18              0.9712        0.7702        0.7808     +  1.4043
#      19              0.9712        0.7670        0.7929        1.4028
#      20              0.9712        0.7618        0.7900        1.4167
#      21              0.9712        0.7553        0.7839        1.4056
#      22              0.9712        0.7507        0.7852        1.4222
#      23              0.9712        0.7427        0.7858        1.4031
#      24              0.9712        0.7378        0.7906        1.4522
#      25              0.9712        0.7322        0.7989        1.4240
#      26              0.9712        0.7272        0.8075        1.3749
#      27              0.9712        0.7258        0.8007        1.3550
#      28              0.9712        0.7152        0.7972        1.5657
#      29              0.9712        0.7077        0.8069        1.4010
#      30              0.9712        0.7007        0.8111        1.3768
#      31              0.9712        0.6948        0.8104        1.3939
#      32              0.9712        0.6878        0.8106        1.3515
#      33              0.9712        0.6836        0.8247        1.3670
#      34              0.9712        0.6741        0.8230        1.3707
#      35              0.9712        0.6706        0.8168        1.3620
#      36              0.9712        0.6605        0.8316        1.3483
#      37              0.9712        0.6589        0.8205        1.3510
# train end
# Loading best checkpoint after training.
# removing ./rtdl_checkpoints/133214066136000params.pt
# fit(): torch.cuda.is_initialized()=True
# RTDL regressor
# [('epoch_timer', <skorch.callbacks.logging.EpochTimer object at 0x79285193ece0>), ('train_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x79285193ca60>), ('valid_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x79285193e440>), ('print_log', <skorch.callbacks.logging.PrintLog object at 0x79285193f1f0>)]
# Initializing UniquePrefixCheckpoint
# fn_prefix is 133214066145456
# A checkpoint was triggered in epoch 2.
#   epoch    constant_val_mse    train_loss    valid_loss    cp     dur
# -------  ------------------  ------------  ------------  ----  ------
#       1              0.9712        0.9611        0.8420     +  1.3541
# A checkpoint was triggered in epoch 3.
#       2              0.9712        0.8725        0.8332     +  1.3275
# A checkpoint was triggered in epoch 4.
#       3              0.9712        0.8562        0.8213     +  1.3577
# A checkpoint was triggered in epoch 5.
#       4              0.9712        0.8460        0.8197     +  1.4061
#       5              0.9712        0.8414        0.8198        1.4325
#       6              0.9712        0.8328        0.8212        1.4287
# A checkpoint was triggered in epoch 8.
#       7              0.9712        0.8298        0.8115     +  1.4775
# A checkpoint was triggered in epoch 9.
#       8              0.9712        0.8245        0.8078     +  1.4474
# A checkpoint was triggered in epoch 10.
#       9              0.9712        0.8194        0.7995     +  1.4567
# A checkpoint was triggered in epoch 11.
#      10              0.9712        0.8095        0.7963     +  1.4125
# A checkpoint was triggered in epoch 12.
#      11              0.9712        0.8053        0.7919     +  1.4306
#      12              0.9712        0.7995        0.7967        1.5670
# A checkpoint was triggered in epoch 14.
#      13              0.9712        0.7950        0.7918     +  1.4757
# A checkpoint was triggered in epoch 15.
#      14              0.9712        0.7895        0.7868     +  1.4483
#      15              0.9712        0.7856        0.7919        1.4282
# A checkpoint was triggered in epoch 17.
#      16              0.9712        0.7851        0.7801     +  1.4306
#      17              0.9712        0.7739        0.7827        1.4321
#      18              0.9712        0.7694        0.7870        1.4243
#      19              0.9712        0.7645        0.7980        1.4209
# A checkpoint was triggered in epoch 21.
#      20              0.9712        0.7606        0.7796     +  1.4205
#      21              0.9712        0.7551        0.7843        1.4884
#      22              0.9712        0.7468        0.7885        1.4174
#      23              0.9712        0.7409        0.7855        1.4284
#      24              0.9712        0.7352        0.7932        1.4387
#      25              0.9712        0.7285        0.7908        1.4304
#      26              0.9712        0.7226        0.7861        1.4662
#      27              0.9712        0.7176        0.7964        1.4284
#      28              0.9712        0.7128        0.8030        1.4975
#      29              0.9712        0.7044        0.8022        1.4235
#      30              0.9712        0.6991        0.8082        1.4328
#      31              0.9712        0.6933        0.7987        1.4198
# train end
# Loading best checkpoint after training.
# removing ./rtdl_checkpoints/133214065692816params.pt
# #########################
# ### Fold 3
# #########################
# Columns classified as continuous: ['hla_match_c_high', 'hla_high_res_8', 'hla_low_res_6', 'hla_high_res_6', 'hla_high_res_10', 'hla_match_dqb1_high', 'hla_nmdp_6', 'hla_match_c_low', 'hla_match_drb1_low', 'hla_match_dqb1_low', 'year_hct', 'hla_match_a_high', 'donor_age', 'hla_match_b_low', 'age_at_hct', 'hla_match_a_low', 'hla_match_b_high', 'comorbidity_score', 'karnofsky_score', 'hla_low_res_8', 'hla_match_drb1_high', 'hla_low_res_10']
# Columns classified as categorical: ['dri_score', 'psych_disturb', 'cyto_score', 'diabetes', 'tbi_status', 'arrhythmia', 'graft_type', 'vent_hist', 'renal_issue', 'pulm_severe', 'prim_disease_hct', 'cmv_status', 'tce_imm_match', 'rituximab', 'prod_type', 'cyto_score_detail', 'conditioning_intensity', 'ethnicity', 'obesity', 'mrd_hct', 'in_vivo_tcd', 'tce_match', 'hepatic_severe', 'prior_tumor', 'peptic_ulcer', 'gvhd_proph', 'rheum_issue', 'sex_match', 'race_group', 'hepatic_mild', 'tce_div_match', 'donor_related', 'melphalan_dose', 'cardiac', 'pulm_moderate']
# fit(): torch.cuda.is_initialized()=True
# RTDL regressor
# [('epoch_timer', <skorch.callbacks.logging.EpochTimer object at 0x792851190c70>), ('train_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792851193670>), ('valid_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792851193a60>), ('print_log', <skorch.callbacks.logging.PrintLog object at 0x7928511905e0>)]
# Initializing UniquePrefixCheckpoint
# fn_prefix is 133214074290288
# A checkpoint was triggered in epoch 2.
#   epoch    constant_val_mse    train_loss    valid_loss    cp     dur
# -------  ------------------  ------------  ------------  ----  ------
#       1              1.0239        0.9548        0.9120     +  1.4368
# A checkpoint was triggered in epoch 3.
#       2              1.0239        0.8692        0.8707     +  1.4219
# A checkpoint was triggered in epoch 4.
#       3              1.0239        0.8456        0.8593     +  1.4063
# A checkpoint was triggered in epoch 5.
#       4              1.0239        0.8359        0.8434     +  1.4370
# A checkpoint was triggered in epoch 6.
#       5              1.0239        0.8290        0.8381     +  1.4211
#       6              1.0239        0.8210        0.8530        1.4427
# A checkpoint was triggered in epoch 8.
#       7              1.0239        0.8168        0.8360     +  1.4526
#       8              1.0239        0.8114        0.8397        1.4612
# A checkpoint was triggered in epoch 10.
#       9              1.0239        0.8086        0.8237     +  1.4095
#      10              1.0239        0.8006        0.8282        1.4489
# A checkpoint was triggered in epoch 12.
#      11              1.0239        0.7965        0.8144     +  1.4312
#      12              1.0239        0.7950        0.8145        1.5056
#      13              1.0239        0.7868        0.8155        1.4251
# A checkpoint was triggered in epoch 15.
#      14              1.0239        0.7845        0.8142     +  1.4646
#      15              1.0239        0.7773        0.8161        1.4236
# A checkpoint was triggered in epoch 17.
#      16              1.0239        0.7735        0.8137     +  1.4302
# A checkpoint was triggered in epoch 18.
#      17              1.0239        0.7682        0.8048     +  1.5177
#      18              1.0239        0.7647        0.8080        1.4479
# A checkpoint was triggered in epoch 20.
#      19              1.0239        0.7592        0.8026     +  1.4394
#      20              1.0239        0.7521        0.8034        1.4552
#      21              1.0239        0.7453        0.8032        1.4689
#      22              1.0239        0.7388        0.8076        1.4676
#      23              1.0239        0.7347        0.8077        1.4450
#      24              1.0239        0.7271        0.8184        1.4301
#      25              1.0239        0.7247        0.8200        1.3932
#      26              1.0239        0.7184        0.8202        1.4154
#      27              1.0239        0.7108        0.8202        1.4203
#      28              1.0239        0.7085        0.8131        1.4626
#      29              1.0239        0.7002        0.8127        1.4308
#      30              1.0239        0.6905        0.8205        1.4285
#      31              1.0239        0.6880        0.8249        1.4319
#      32              1.0239        0.6842        0.8276        1.4161
#      33              1.0239        0.6743        0.8295        1.4394
#      34              1.0239        0.6643        0.8297        1.4381
#      35              1.0239        0.6601        0.8255        1.4755
#      36              1.0239        0.6529        0.8300        1.4268
#      37              1.0239        0.6492        0.8278        1.4336
#      38              1.0239        0.6393        0.8426        1.4409
# train end
# Loading best checkpoint after training.
# removing ./rtdl_checkpoints/133214074290288params.pt
# fit(): torch.cuda.is_initialized()=True
# RTDL regressor
# [('epoch_timer', <skorch.callbacks.logging.EpochTimer object at 0x79285193ca30>), ('train_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x79285193d9c0>), ('valid_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x79285193c280>), ('print_log', <skorch.callbacks.logging.PrintLog object at 0x79285193e050>)]
# Initializing UniquePrefixCheckpoint
# fn_prefix is 133214065689552
# A checkpoint was triggered in epoch 2.
#   epoch    constant_val_mse    train_loss    valid_loss    cp     dur
# -------  ------------------  ------------  ------------  ----  ------
#       1              1.0239        0.9586        0.9125     +  1.4281
# A checkpoint was triggered in epoch 3.
#       2              1.0239        0.8746        0.8711     +  1.4020
# A checkpoint was triggered in epoch 4.
#       3              1.0239        0.8483        0.8573     +  1.4301
# A checkpoint was triggered in epoch 5.
#       4              1.0239        0.8400        0.8473     +  1.4009
# A checkpoint was triggered in epoch 6.
#       5              1.0239        0.8325        0.8381     +  1.4123
# A checkpoint was triggered in epoch 7.
#       6              1.0239        0.8232        0.8308     +  1.4316
# A checkpoint was triggered in epoch 8.
#       7              1.0239        0.8173        0.8284     +  1.4456
# A checkpoint was triggered in epoch 9.
#       8              1.0239        0.8106        0.8226     +  1.4235
#       9              1.0239        0.8072        0.8236        1.4362
# A checkpoint was triggered in epoch 11.
#      10              1.0239        0.8009        0.8163     +  1.4762
#      11              1.0239        0.7958        0.8174        1.4294
# A checkpoint was triggered in epoch 13.
#      12              1.0239        0.7934        0.8122     +  1.4445
# A checkpoint was triggered in epoch 14.
#      13              1.0239        0.7876        0.8102     +  1.4016
#      14              1.0239        0.7835        0.8105        1.4204
# A checkpoint was triggered in epoch 16.
#      15              1.0239        0.7776        0.8092     +  1.4284
# A checkpoint was triggered in epoch 17.
# ...
#      36              1.0044        0.6541        0.8183        1.4138
#      37              1.0044        0.6496        0.8364        1.4335
#      38              1.0044        0.6397        0.8322        1.4309
#      39              1.0044        0.6367        0.8437        1.4234
# train end
# Loading best checkpoint after training.
# removing ./rtdl_checkpoints/133214074609696params.pt
# fit(): torch.cuda.is_initialized()=True
# RTDL regressor
# [('epoch_timer', <skorch.callbacks.logging.EpochTimer object at 0x7928511241f0>), ('train_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792851126110>), ('valid_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792851125510>), ('print_log', <skorch.callbacks.logging.PrintLog object at 0x792851125b40>)]
# Initializing UniquePrefixCheckpoint
# fn_prefix is 133214065693872
# A checkpoint was triggered in epoch 2.
#   epoch    constant_val_mse    train_loss    valid_loss    cp     dur
# -------  ------------------  ------------  ------------  ----  ------
#       1              1.0044        0.9563        0.8820     +  1.4805
# A checkpoint was triggered in epoch 3.
#       2              1.0044        0.8713        0.8383     +  1.3960
# A checkpoint was triggered in epoch 4.
#       3              1.0044        0.8474        0.8211     +  1.4040
# A checkpoint was triggered in epoch 5.
#       4              1.0044        0.8312        0.8111     +  1.4141
#       5              1.0044        0.8263        0.8144        1.3887
# A checkpoint was triggered in epoch 7.
#       6              1.0044        0.8209        0.8018     +  1.4137
#       7              1.0044        0.8174        0.8052        1.4179
# A checkpoint was triggered in epoch 9.
#       8              1.0044        0.8101        0.7958     +  1.4763
# A checkpoint was triggered in epoch 10.
#       9              1.0044        0.8055        0.7921     +  1.4227
#      10              1.0044        0.8034        0.7956        1.4249
#      11              1.0044        0.7991        0.8011        1.4301
# A checkpoint was triggered in epoch 13.
#      12              1.0044        0.7939        0.7884     +  1.4424
#      13              1.0044        0.7914        0.7970        1.4325
# A checkpoint was triggered in epoch 15.
#      14              1.0044        0.7852        0.7854     +  1.4332
#      15              1.0044        0.7807        0.7929        1.4933
#      16              1.0044        0.7777        0.7887        1.4516
#      17              1.0044        0.7699        0.7858        1.4072
#      18              1.0044        0.7668        0.7972        1.4370
# A checkpoint was triggered in epoch 20.
#      19              1.0044        0.7608        0.7809     +  1.3992
#      20              1.0044        0.7540        0.7910        1.4218
# train end
# Loading best checkpoint after training.
# removing ./rtdl_checkpoints/133214074617232params.pt
# fit(): torch.cuda.is_initialized()=True
# RTDL regressor
# [('epoch_timer', <skorch.callbacks.logging.EpochTimer object at 0x792851126230>), ('train_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792851127340>), ('valid_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792851127c70>), ('print_log', <skorch.callbacks.logging.PrintLog object at 0x792851124ca0>)]
# Initializing UniquePrefixCheckpoint
# fn_prefix is 133214065688976
# A checkpoint was triggered in epoch 2.
#   epoch    constant_val_mse    train_loss    valid_loss    cp     dur
# -------  ------------------  ------------  ------------  ----  ------
#       1              1.0044        0.9520        0.8735     +  1.4248
# A checkpoint was triggered in epoch 3.
#       2              1.0044        0.8703        0.8457     +  1.4068
# A checkpoint was triggered in epoch 4.
#       3              1.0044        0.8479        0.8238     +  1.4068
#       4              1.0044        0.8374        0.8272        1.4274
# A checkpoint was triggered in epoch 6.
#       5              1.0044        0.8325        0.8097     +  1.4188
#       6              1.0044        0.8243        0.8111        1.4342
# A checkpoint was triggered in epoch 8.
#       7              1.0044        0.8175        0.8045     +  1.4683
# A checkpoint was triggered in epoch 9.
#       8              1.0044        0.8127        0.8017     +  1.5122
# A checkpoint was triggered in epoch 10.
#       9              1.0044        0.8089        0.7962     +  1.4553
#      10              1.0044        0.8053        0.8037        1.4960
# A checkpoint was triggered in epoch 12.
#      11              1.0044        0.8021        0.7922     +  1.4407
#      12              1.0044        0.7987        0.7946        1.4647
# A checkpoint was triggered in epoch 14.
#      13              1.0044        0.7923        0.7913     +  1.4466
# A checkpoint was triggered in epoch 15.
#      14              1.0044        0.7875        0.7891     +  1.4589
# A checkpoint was triggered in epoch 16.
#      15              1.0044        0.7826        0.7883     +  1.4347
# A checkpoint was triggered in epoch 17.
#      16              1.0044        0.7785        0.7851     +  1.4235
#      17              1.0044        0.7744        0.7890        1.4179
#      18              1.0044        0.7712        0.7869        1.4300
#      19              1.0044        0.7666        0.7913        1.4522
#      20              1.0044        0.7640        0.7880        1.4253
#      21              1.0044        0.7591        0.7945        1.4554
#      22              1.0044        0.7550        0.7894        1.4116
#      23              1.0044        0.7499        0.8180        1.3949
#      24              1.0044        0.7432        0.7954        1.4033
#      25              1.0044        0.7394        0.7958        1.4136
#      26              1.0044        0.7320        0.7942        1.4082
#      27              1.0044        0.7263        0.7953        1.3936
#      28              1.0044        0.7262        0.7946        1.4378
#      29              1.0044        0.7223        0.7930        1.4284
#      30              1.0044        0.7124        0.8041        1.4368
#      31              1.0044        0.7075        0.8060        1.4095
#      32              1.0044        0.6986        0.8099        1.4670
#      33              1.0044        0.6906        0.8100        1.4404
#      34              1.0044        0.6860        0.8240        1.4304
#      35              1.0044        0.6863        0.8091        1.4680
# train end
# Loading best checkpoint after training.
# removing ./rtdl_checkpoints/133214065688976params.pt
# fit(): torch.cuda.is_initialized()=True
# RTDL regressor
# [('epoch_timer', <skorch.callbacks.logging.EpochTimer object at 0x7928511273a0>), ('train_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x792851124370>), ('valid_loss', <skorch.callbacks.scoring.PassthroughScoring object at 0x7928511264d0>), ('print_log', <skorch.callbacks.logging.PrintLog object at 0x792851125f60>)]
# Initializing UniquePrefixCheckpoint
# fn_prefix is 133214065804240
# A checkpoint was triggered in epoch 2.
#   epoch    constant_val_mse    train_loss    valid_loss    cp     dur
# -------  ------------------  ------------  ------------  ----  ------
#       1              1.0044        0.9513        0.8861     +  1.4108
# A checkpoint was triggered in epoch 3.
#       2              1.0044        0.8716        0.8348     +  1.3964
# A checkpoint was triggered in epoch 4.
#       3              1.0044        0.8544        0.8202     +  1.4160
# A checkpoint was triggered in epoch 5.
#       4              1.0044        0.8391        0.8113     +  1.4224
# A checkpoint was triggered in epoch 6.
#       5              1.0044        0.8283        0.8077     +  1.3881
# A checkpoint was triggered in epoch 7.
#       6              1.0044        0.8221        0.8040     +  1.4407
#       7              1.0044        0.8159        0.8095        1.4391
#       8              1.0044        0.8134        0.8273        1.4185
# A checkpoint was triggered in epoch 10.
#       9              1.0044        0.8100        0.7975     +  1.4213
# A checkpoint was triggered in epoch 11.
#      10              1.0044        0.8056        0.7961     +  1.4153
#      11              1.0044        0.8007        0.7962        1.3993
# A checkpoint was triggered in epoch 13.
#      12              1.0044        0.7981        0.7937     +  1.4410
#      13              1.0044        0.7940        0.7946        1.4858
# A checkpoint was triggered in epoch 15.
#      14              1.0044        0.7919        0.7872     +  1.4142
#      15              1.0044        0.7870        0.7890        1.4297
#      16              1.0044        0.7829        0.7962        1.4050
# A checkpoint was triggered in epoch 18.
#      17              1.0044        0.7772        0.7865     +  1.3906
# A checkpoint was triggered in epoch 19.
#      18              1.0044        0.7729        0.7856     +  1.4692
#      19              1.0044        0.7682        0.7957        1.4652
#      20              1.0044        0.7630        0.7972        1.4415
#      21              1.0044        0.7605        0.7905        1.4047
#      22              1.0044        0.7537        0.7910        1.4289
# A checkpoint was triggered in epoch 24.
#      23              1.0044        0.7528        0.7840     +  1.3974
# A checkpoint was triggered in epoch 25.
#      24              1.0044        0.7443        0.7835     +  1.4199
#      25              1.0044        0.7394        0.7880        1.4203
# A checkpoint was triggered in epoch 27.
#      26              1.0044        0.7285        0.7826     +  1.4044
#      27              1.0044        0.7268        0.7917        1.4408
#      28              1.0044        0.7211        0.7904        1.4137
#      29              1.0044        0.7151        0.7871        1.4247
#      30              1.0044        0.7103        0.7941        1.4289
#      31              1.0044        0.7001        0.7926        1.3969
#      32              1.0044        0.6983        0.7935        1.3967
#      33              1.0044        0.6897        0.7994        1.4180
#      34              1.0044        0.6809        0.8010        1.4618
#      35              1.0044        0.6774        0.8054        1.4362
#      36              1.0044        0.6746        0.7992        1.4328
#      37              1.0044        0.6660        0.8060        1.4189
#      38              1.0044        0.6574        0.8081        1.4305
#      39              1.0044        0.6511        0.8091        1.4407
#      40              1.0044        0.6443        0.8578        1.5600
#      41              1.0044        0.6360        0.8450        1.5066
#      42              1.0044        0.6314        0.8202        1.4183
#      43              1.0044        0.6234        0.8277        1.4254
#      44              1.0044        0.6176        0.8317        1.4203
#      45              1.0044        0.6120        0.8353        1.4328
# train end
# Loading best checkpoint after training.
# removing ./rtdl_checkpoints/133214065804240params.pt
# CPU times: user 47min 54s, sys: 21.7 s, total: 48min 16s
# Wall time: 48min 36s

# %%
y_true = train[["ID", "efs", "efs_time", "race_group"]].copy()
y_pred = train[["ID"]].copy()
y_pred["prediction"] = oof_mlpprl
m_mlpprl = score(y_true.copy(), y_pred.copy(), "ID")
print(f"\nOverall CV for mlpprl KaplanMeier = ", m_mlpprl) # 0.6706938280206677
# Out:
# Overall CV for mlpprl KaplanMeier =  0.6707513719221984

# %%
# %%time
FOLDS = 10
kf = KFold(n_splits=FOLDS, shuffle=True, random_state=52)
    
oof_tabmd = np.zeros(len(train))
pred_tabmd = np.zeros(len(test))

for i, (train_index, test_index) in enumerate(kf.split(train)):
    print("#" * 25)
    print(f"### Fold {i + 1}")
    print("#" * 25)
    
    X_train = train.loc[train_index, FEATURES].copy()
    y_train = train.loc[train_index, "y"]
    X_valid = train.loc[test_index, FEATURES].copy()
    y_valid = train.loc[test_index, "y"]
    X_test = test[FEATURES].copy()

    model_tabmd = TabM_D_Regressor(
        n_cv=5,
        lr=0.0001,
        n_epochs=200,
        patience=20,
        random_state=52, 
        verbosity=0
    )
    model_tabmd.fit(
        X_train, y_train,
        X_valid, y_valid
    )
    os.makedirs('/kaggle/working/tabmd', exist_ok=True)
    joblib.dump(model_tabmd, f'/kaggle/working/tabmd/tabmd_fold_{i}.pkl')

    oof_tabmd[test_index] = model_tabmd.predict(X_valid)
    pred_tabmd += model_tabmd.predict(X_test)

pred_tabmd /= FOLDS
# Out:
# #########################
# ### Fold 1
# #########################
# Setting seed: 1387748341
# Setting seed: 1388881564
# Setting seed: 112175883
# Setting seed: 628153869
# Setting seed: 905253015
# #########################
# ### Fold 2
# #########################
# Setting seed: 1387748341
# Setting seed: 1388881564
# Setting seed: 112175883
# Setting seed: 628153869
# Setting seed: 905253015
# #########################
# ### Fold 3
# #########################
# Setting seed: 1387748341
# Setting seed: 1388881564
# Setting seed: 112175883
# Setting seed: 628153869
# Setting seed: 905253015
# #########################
# ### Fold 4
# #########################
# Setting seed: 1387748341
# Setting seed: 1388881564
# Setting seed: 112175883
# Setting seed: 628153869
# Setting seed: 905253015
# #########################
# ### Fold 5
# #########################
# Setting seed: 1387748341
# Setting seed: 1388881564
# Setting seed: 112175883
# Setting seed: 628153869
# Setting seed: 905253015
# #########################
# ### Fold 6
# #########################
# Setting seed: 1387748341
# Setting seed: 1388881564
# Setting seed: 112175883
# Setting seed: 628153869
# Setting seed: 905253015
# #########################
# ### Fold 7
# #########################
# Setting seed: 1387748341
# Setting seed: 1388881564
# Setting seed: 112175883
# Setting seed: 628153869
# Setting seed: 905253015
# #########################
# ### Fold 8
# #########################
# Setting seed: 1387748341
# Setting seed: 1388881564
# Setting seed: 112175883
# Setting seed: 628153869
# Setting seed: 905253015
# #########################
# ### Fold 9
# #########################
# Setting seed: 1387748341
# Setting seed: 1388881564
# Setting seed: 112175883
# Setting seed: 628153869
# Setting seed: 905253015
# #########################
# ### Fold 10
# #########################
# Setting seed: 1387748341
# Setting seed: 1388881564
# Setting seed: 112175883
# Setting seed: 628153869
# Setting seed: 905253015
# CPU times: user 1h 26min 38s, sys: 39min 27s, total: 2h 6min 5s
# Wall time: 2h 6min 48s

# %%
y_true = train[["ID", "efs", "efs_time", "race_group"]].copy()
y_pred = train[["ID"]].copy()
y_pred["prediction"] = oof_tabmd
m_tabmd = score(y_true.copy(), y_pred.copy(), "ID")
print(f"\nOverall CV for tabmd KaplanMeier = ", m_tabmd) # dolgo, potom na gpu test
# Out:
# Overall CV for tabmd KaplanMeier =  0.6697422578152127
